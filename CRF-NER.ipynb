# %% [markdown]
# # Conditional Random Fields
# ## Named Entity Recognition Tagging

# %%
from itertools import chain

import nltk
import sklearn
import scipy.stats
from sklearn.metrics import make_scorer
from sklearn.cross_validation import cross_val_score
from sklearn.grid_search import RandomizedSearchCV

import sklearn_crfsuite
from sklearn_crfsuite import scorers
from sklearn_crfsuite import metrics
# Out:
# /home/etienne/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/etienne/anaconda2/lib/python2.7/site-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# Here we take words read from the input files and construct features we use to train the CRF.
#
# For every input word we create features for the lower case verison of the word, the last 2 and the last 3 characters of the word, whether the word is in upper case, title case or whether it consists of digits. We also create features for the previous word and the next word in the sentence.

# %%
def word2features(sent, i):
    word = sent[i][0]

    features = [
        'bias',
        'word.lower=' + word.lower(),
        'word[-3:]=' + word[-3:],
        'word[-2:]=' + word[-2:],
        'word.isupper=%s' % word.isupper(),
        'word.istitle=%s' % word.istitle(),
        'word.isdigit=%s' % word.isdigit()
    ]
    if i > 0:
        word1 = sent[i-1][0]
        features.extend([
            '-1:word.lower=' + word1.lower(),
            '-1:word.istitle=%s' % word1.istitle(),
            '-1:word.isupper=%s' % word1.isupper()
        ])
    else:
        features.append('BOS')
        
    if i < len(sent)-1:
        word1 = sent[i+1][0]
        postag1 = sent[i+1][1]
        features.extend([
            '+1:word.lower=' + word1.lower(),
            '+1:word.istitle=%s' % word1.istitle(),
            '+1:word.isupper=%s' % word1.isupper()
        ])
    else:
        features.append('EOS')
                
    return features


def sent2features(sent):
    return [word2features(sent, i) for i in range(len(sent))]

def sent2labels(sent):
    return [postag for token, postag in sent]

def sent2tokens(sent):
    return [token for token, postag in sent]

# %% [markdown]
# Here we open our training and testing files, parse them and pass them to the feature extraction functions to ready them for training.

# %%
def getSentsFromFile(file):
    #all_sents = []

    this_sent = []

    for line in file:
        line= line.strip()
        if line=="":
            #all_sents.extend([this_sent])
            yield(this_sent)
            this_sent=[]
        
            continue
        else:
            parts = line.split("\t")
            this_sent.extend([tuple(parts)])
      
    return


def loadTestTrain(trainFile, testFile):
    train_sents = [s for s in getSentsFromFile(trainFile)]
    test_sents = [s for s in getSentsFromFile(testFile)]

    X_train = [sent2features(s) for s in train_sents]
    y_train = [sent2labels(s) for s in train_sents]

    X_test = [sent2features(s) for s in test_sents]
    y_test = [sent2labels(s) for s in test_sents]

    print "Loaded ", len(X_train), " training instances/", len(X_test), " testing instances."
    
    return (X_train, y_train, X_test, y_test)

trainf_ner = open("Data/ner-pol/train.iob")
testf_ner = open("Data/ner-pol/test.iob")

(X_train, y_train, X_test, y_test) = loadTestTrain(trainf_ner, testf_ner)
# Out:
# Loaded  14987  training instances/ 3684  testing instances.

# %% [markdown]
# Set up model hyperparameters and train the model.

# %%
# %%time
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=1.0,
    c2=0.001,
    max_iterations=50,
    all_possible_transitions=True
)
crf.fit(X_train, y_train)
# Out:
# CPU times: user 25.1 s, sys: 230 ms, total: 25.3 s
# Wall time: 25.6 s

# %% [markdown]
# List the model labels consisting of named entity types - Organisation, person, location and miscellaneous.

# %%
labels = list(crf.classes_)
labels
# Out:
# ['|O',
#  '|B-ORG',
#  '|B-MISC',
#  '|B-PER',
#  '|I-PER',
#  '|B-LOC',
#  '|I-ORG',
#  '|I-MISC',
#  '|I-LOC']

# %% [markdown]
# Process the testing set and print out the f1-score.

# %%
# %%time
y_pred = crf.predict(X_test)
print metrics.flat_f1_score(y_test, y_pred,
                      average='weighted', labels=labels)
# Out:
# 0.9497753323961592
# CPU times: user 1.18 s, sys: 20 µs, total: 1.18 s
# Wall time: 1.17 s

# %% [markdown]
# Print out prediction costs per label

# %%
sorted_labels = sorted(
    labels,
    key=lambda name: (name[1:], name[0])
)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))
# Out:
#              precision    recall  f1-score   support
#
#      |B-LOC      0.846     0.785     0.814      1669
#     |B-MISC      0.806     0.740     0.772       705
#      |B-ORG      0.798     0.667     0.727      1663
#      |B-PER      0.790     0.843     0.816      1617
#      |I-LOC      0.736     0.578     0.648       256
#     |I-MISC      0.634     0.643     0.639       213
#      |I-ORG      0.653     0.701     0.676       833
#      |I-PER      0.838     0.948     0.890      1156
#          |O      0.983     0.988     0.986     38554
#
# avg / total      0.950     0.951     0.950     46666

# %% [markdown]
# List the features by training importance

# %%
for key, value in sorted(crf.state_features_.iteritems(), key=lambda (k,v): (v,k), reverse=True):
    print "%s: %s" % (key, value)
# Out:
# (u'word[-2:]=5M', u'|O'): 7.942236
# (u'word[-2:]=0M', u'|O'): 7.584323
# (u'-1:word.lower=grade', u'|O'): 7.467747
# (u'word.lower=ata-ur-rehman', u'|B-PER'): 7.377029
# (u'word.lower=sungard', u'|B-ORG'): 6.664536
# (u'word[-2:]=6F', u'|O'): 6.550478
# (u'word.lower=minister', u'|O'): 6.19998
# (u'+1:word.lower=1996-08-26', u'|B-LOC'): 5.880611
# (u'word.lower=serb-held', u'|B-MISC'): 5.853415
# (u'word.lower=weston-super-mare', u'|B-LOC'): 5.847896
# (u'word.lower=mcgrath', u'|B-PER'): 5.788491
# (u'word[-2:]=-A', u'|O'): 5.677977
# (u'+1:word.lower=1996-08-23', u'|B-LOC'): 5.531767
# (u'word.lower=england', u'|B-LOC'): 5.348388
# (u'word.lower=mclaren', u'|B-ORG'): 5.332102
# (u'word.lower=parma', u'|B-ORG'): 5.327616
# (u'+1:word.lower=1996-08-28', u'|B-LOC'): 5.295032
# (u'word.lower=german', u'|B-MISC'): 5.289305
# (u'+1:word.lower=1996-08-27', u'|B-LOC'): 5.262556
# (u'+1:word.lower=1996-08-29', u'|B-LOC'): 5.262069
# (u'+1:word.lower=1996-08-25', u'|B-LOC'): 5.257143
# (u'word.lower=clinton', u'|B-PER'): 5.256348
# (u'word.lower=moslem', u'|B-MISC'): 5.175084
# (u'+1:word.lower=1996-08-22', u'|B-LOC'): 5.169393
# (u'-1:word.lower=v', u'|B-ORG'): 5.165884
# (u'word.lower=hungary', u'|B-LOC'): 5.129136
# (u'word.lower=september', u'|O'): 5.063156
# (u'word.lower=zimbabwe', u'|B-LOC'): 5.044667
# (u'word.lower=barrick', u'|B-ORG'): 4.971455
# (u'word.lower=reuters', u'|B-ORG'): 4.958963
# (u'word.lower=britain', u'|B-LOC'): 4.941815
# (u'word[-2:]=80', u'|O'): 4.920466
# (u'word.lower=beijing', u'|B-LOC'): 4.913094
# (u'-1:word.lower=interior', u'|I-ORG'): 4.900577
# (u'word[-3:]=I', u'|O'): 4.813863
# (u'word[-2:]=I', u'|O'): 4.813863
# (u'word.lower=senate', u'|B-ORG'): 4.807698
# (u'+1:word.lower=yr', u'|B-ORG'): 4.764908
# (u'word.lower=zaire', u'|B-LOC'): 4.75715
# (u'word.lower=argentine', u'|B-MISC'): 4.74534
# (u'-1:word.lower=mladost', u'|I-ORG'): 4.720366
# (u'word.lower=chile', u'|B-LOC'): 4.711712
# (u'+1:word.lower=1996-08-24', u'|B-LOC'): 4.63937
# (u'word.lower=florence', u'|B-LOC'): 4.635989
# (u'word.lower=a', u'|O'): 4.567766
# (u'word.lower=greek', u'|B-MISC'): 4.514376
# (u'word.lower=june', u'|O'): 4.506178
# (u'-1:word.lower=no', u'|I-MISC'): 4.499376
# (u'word.lower=france', u'|B-LOC'): 4.495896
# (u'word.lower=british-based', u'|B-MISC'): 4.493313
# (u'word.lower=august', u'|O'): 4.479476
# (u'word[-2:]=S$', u'|B-MISC'): 4.471967
# (u'word.lower=pakistan', u'|B-LOC'): 4.468061
# (u'word[-3:]=day', u'|O'): 4.462762
# (u'word.lower=italy', u'|B-LOC'): 4.458689
# (u'word.lower=ajax', u'|B-ORG'): 4.447577
# (u'word.lower=lens', u'|B-ORG'): 4.438655
# (u'word.lower=women', u'|O'): 4.416747
# (u'word.lower=these', u'|O'): 4.39992
# (u'word.lower=germany', u'|B-LOC'): 4.368285
# (u'+1:word.lower=metres', u'|O'): 4.351313
# (u'-1:word.lower=wisc', u'|I-LOC'): 4.317989
# (u'-1:word.lower=colo', u'|I-LOC'): 4.317987
# (u'word.lower=march', u'|O'): 4.316593
# (u'word.lower=pro-baghdad', u'|B-MISC'): 4.314423
# (u'word.lower=dtb-bund-future', u'|B-MISC'): 4.305414
# (u'word.lower=verisign', u'|B-ORG'): 4.302468
# (u'word.lower=chester-le-street', u'|B-LOC'): 4.295987
# (u'word.lower=tutsi-dominated', u'|B-MISC'): 4.295868
# (u'word.lower=wisconsin', u'|B-LOC'): 4.234745
# (u'word.lower=thai', u'|B-MISC'): 4.225996
# (u'word.lower=balkans', u'|B-LOC'): 4.22293
# (u'word.lower=oakland', u'|B-ORG'): 4.211249
# (u'word.lower=zenith', u'|B-ORG'): 4.202363
# (u'word.lower=islamists', u'|B-MISC'): 4.191122
# (u'word[-3:]=Haq', u'|B-PER'): 4.18966
# (u'word.lower=inzamam-ul-haq', u'|B-PER'): 4.18966
# (u'-1:word.lower=b', u'|B-PER'): 4.173315
# (u'+1:word.lower=0', u'|I-ORG'): 4.1634
# (u'-1:word.lower=scott', u'|I-PER'): 4.158698
# (u'word.lower=chairman', u'|O'): 4.151333
# (u'+1:word.lower=0', u'|B-ORG'): 4.144596
# (u'word.lower=euromark', u'|B-MISC'): 4.138897
# (u'word.lower=u.s.-led', u'|B-MISC'): 4.121094
# (u'-1:word.lower=japan', u'|O'): 4.068548
# (u'word[-3:]=OR', u'|B-LOC'): 4.058512
# (u'-1:word.lower=newspaper', u'|B-ORG'): 4.038308
# (u'-1:word.lower=2.', u'|B-PER'): 4.027281
# (u'word.lower=croft', u'|B-PER'): 4.021626
# (u'word.lower=sweden', u'|B-LOC'): 3.996535
# (u'word.lower=iraq', u'|B-LOC'): 3.96406
# (u'word[-2:]=.5', u'|O'): 3.963457
# (u'word[-3:]=Jul', u'|O'): 3.953814
# (u'word.lower=bangladesh', u'|B-LOC'): 3.945712
# (u'+1:word.lower=4', u'|I-ORG'): 3.922372
# (u'word.lower=stenning', u'|B-PER'): 3.909869
# (u'word.lower=it', u'|O'): 3.906782
# (u'word.lower=briton', u'|B-MISC'): 3.903525
# (u'word.lower=brussels', u'|B-LOC'): 3.899304
# (u'word.lower=wales', u'|B-LOC'): 3.893208
# (u'word.lower=hamas', u'|B-ORG'): 3.886357
# (u'word.lower=yugoslav', u'|B-MISC'): 3.883407
# (u'word[-2:]=A1', u'|O'): 3.875108
# (u'+1:word.lower=3', u'|B-ORG'): 3.873599
# (u'word.lower=day', u'|I-MISC'): 3.861825
# (u'+1:word.lower=fighter', u'|B-MISC'): 3.856245
# (u'+1:word.lower=21', u'|B-ORG'): 3.837281
# (u'word.lower=arch', u'|B-ORG'): 3.835594
# (u'word.lower=ballybunion', u'|B-ORG'): 3.817792
# (u'word.lower=venezuelan', u'|B-MISC'): 3.806056
# (u'+1:word.lower=v', u'|B-ORG'): 3.805656
# (u'word.lower=b', u'|O'): 3.80348
# (u'word[-3:]=ril', u'|O'): 3.796574
# (u'+1:word.lower=hospital', u'|I-LOC'): 3.793637
# (u'word.lower=norway', u'|B-LOC'): 3.793464
# (u'word.lower=seychelles', u'|B-LOC'): 3.757216
# (u'word.lower=greece', u'|B-LOC'): 3.755941
# (u'word.lower=commander', u'|O'): 3.734528
# (u'word.lower=jayasuriya', u'|B-PER'): 3.713099
# (u'word.lower=extras', u'|O'): 3.709618
# (u'-1:word.lower=super', u'|B-MISC'): 3.699524
# (u'word.lower=morocco', u'|B-LOC'): 3.695316
# (u'word.lower=post-soviet', u'|B-MISC'): 3.69182
# (u'word.lower=october', u'|O'): 3.688706
# (u'word.lower=ukraine', u'|B-LOC'): 3.685497
# (u'word.istitle=False', u'|O'): 3.683523
# (u'word.lower=dutch', u'|B-MISC'): 3.676228
# (u'word.lower=prairies', u'|B-LOC'): 3.674019
# (u'word.lower=kent', u'|B-ORG'): 3.66544
# (u'word.lower=faulding', u'|B-ORG'): 3.656147
# (u'word.lower=kevorkian', u'|B-PER'): 3.654706
# (u'word.lower=rwandan', u'|B-MISC'): 3.644969
# (u'-1:word.lower=mclaren', u'|I-MISC'): 3.634658
# (u'word.lower=fiorentina', u'|B-ORG'): 3.633173
# (u'word[-3:]=sed', u'|I-MISC'): 3.630117
# (u'-1:word.lower=6.', u'|B-PER'): 3.627407
# (u'word.lower=after', u'|O'): 3.616368
# (u'-1:word.lower=manchester', u'|I-ORG'): 3.609651
# (u'word.lower=amman', u'|B-LOC'): 3.608448
# (u'+1:word.lower=index', u'|B-MISC'): 3.604423
# (u'word.lower=although', u'|O'): 3.604094
# (u'-1:word.lower=striker', u'|B-PER'): 3.599214
# (u'word.lower=neo-nazism', u'|B-MISC'): 3.586019
# (u'+1:word.lower=mt', u'|B-LOC'): 3.58352
# (u'+1:word.lower=1996-08-26', u'|I-LOC'): 3.583209
# (u'+1:word.lower=1996-08-29', u'|I-LOC'): 3.579934
# (u'word.lower=stansted', u'|B-LOC'): 3.57733
# (u'+1:word.lower=3', u'|I-ORG'): 3.572331
# (u'+1:word.lower=index', u'|I-MISC'): 3.571252
# (u'word.lower=congress', u'|B-ORG'): 3.57025
# (u'-1:word.lower=near', u'|B-LOC'): 3.562832
# (u'word.lower=blackburn', u'|B-ORG'): 3.55498
# (u'-1:word.lower=van', u'|I-PER'): 3.550178
# (u'word.lower=lanka', u'|I-LOC'): 3.549286
# (u'word.lower=cleveland', u'|B-ORG'): 3.54433
# (u'-1:word.lower=moody', u'|I-ORG'): 3.542927
# (u'word.lower=vatican', u'|B-LOC'): 3.539133
# (u'word.lower=they', u'|O'): 3.538595
# (u'word.lower=celsius', u'|B-MISC'): 3.53653
# (u'word.lower=toronto-based', u'|B-MISC'): 3.530976
# (u'word[-2:]=NR', u'|B-ORG'): 3.518553
# (u'word[-2:]=EC', u'|B-ORG'): 3.507839
# (u'word[-2:]=EP', u'|O'): 3.484463
# (u'word.lower=to', u'|O'): 3.482932
# (u'word.lower=gore', u'|B-PER'): 3.482311
# (u'word.lower=sporting', u'|B-ORG'): 3.475418
# (u'word.lower=china', u'|B-LOC'): 3.475388
# (u'word.lower=november', u'|O'): 3.461342
# (u'-1:word.lower=3.', u'|B-PER'): 3.452922
# (u'word.lower=sales', u'|O'): 3.45039
# (u'word.lower=open', u'|I-MISC'): 3.445147
# (u'word.lower=israel', u'|B-LOC'): 3.442564
# (u'word[-3:]=A', u'|O'): 3.439146
# (u'word[-2:]=A', u'|O'): 3.439146
# (u'word.lower=prairie', u'|O'): 3.432423
# (u'word.lower=c', u'|O'): 3.418548
# (u'word.lower=orioles', u'|B-ORG'): 3.418054
# (u'word.lower=javasoft', u'|B-ORG'): 3.415374
# (u'word.lower=mauritius', u'|B-LOC'): 3.411611
# (u'word.lower=ramallah', u'|B-LOC'): 3.410233
# (u'word.lower=dalian', u'|B-LOC'): 3.406781
# (u'-1:word.lower=coach', u'|B-PER'): 3.405656
# (u'-1:word.lower=morinville', u'|I-MISC'): 3.404325
# (u'word.lower=lenzing', u'|B-ORG'): 3.396828
# (u'word.lower=with', u'|O'): 3.394978
# (u'-1:word.lower=des', u'|I-LOC'): 3.391606
# (u'word.lower=korean', u'|I-MISC'): 3.384905
# (u'word.lower=spain', u'|B-LOC'): 3.375787
# (u'+1:word.lower=1996-08-27', u'|I-LOC'): 3.370474
# (u'word.lower=helibor', u'|B-MISC'): 3.367012
# (u'word.lower=greens', u'|B-ORG'): 3.362758
# (u'word.lower=promodes', u'|B-ORG'): 3.361952
# (u'word.lower=speaker', u'|O'): 3.358559
# (u'word[-3:]=ese', u'|B-MISC'): 3.357443
# (u'word.lower=braves', u'|B-ORG'): 3.354096
# (u'word.lower=atlantic', u'|B-LOC'): 3.353977
# (u'word.lower=standings', u'|O'): 3.34922
# (u'word.lower=marseille', u'|B-ORG'): 3.347714
# (u'-1:word.lower=area', u'|I-MISC'): 3.341796
# (u'+1:word.lower=1996-08-28', u'|I-LOC'): 3.341348
# (u'word.lower=mexico', u'|B-LOC'): 3.340936
# (u'+1:word.lower="', u'|I-MISC'): 3.328008
# (u'word.lower=auxerre', u'|B-ORG'): 3.309521
# (u'word.lower=euro', u'|B-MISC'): 3.309015
# (u'+1:word.lower=1996-08-25', u'|I-LOC'): 3.307457
# (u'word.lower=uganda', u'|B-LOC'): 3.302451
# (u'word.lower=java', u'|B-MISC'): 3.293113
# (u'word.lower=v', u'|O'): 3.285262
# (u'-1:word.lower=minister', u'|B-PER'): 3.284997
# (u'word.lower=spaniard', u'|B-MISC'): 3.28431
# (u'word.lower=sampras', u'|B-PER'): 3.283088
# (u'-1:word.lower=agency', u'|B-ORG'): 3.282265
# (u'word.lower=nasdaq', u'|B-MISC'): 3.274913
# (u'-1:word.lower=4.', u'|B-PER'): 3.269809
# (u'word.lower=brisbane', u'|B-ORG'): 3.264959
# (u'word.lower=princess', u'|O'): 3.262309
# (u'word.lower=mideast', u'|B-LOC'): 3.261925
# (u'+1:word.lower=4', u'|B-ORG'): 3.24273
# (u'word[-3:]=GMT', u'|B-MISC'): 3.242419
# (u'word.lower=chechens', u'|B-MISC'): 3.242112
# (u'+1:word.lower=1996-08-22', u'|I-LOC'): 3.224892
# (u'word.lower=budapest', u'|B-LOC'): 3.223732
# (u'word[-3:]=sus', u'|B-PER'): 3.220191
# (u'word.lower=july', u'|O'): 3.216308
# (u'word.lower=gmt', u'|B-MISC'): 3.212671
# (u'word.lower=medvedev', u'|B-PER'): 3.21071
# (u'word.lower=israeli-plo', u'|B-MISC'): 3.208652
# (u'+1:word.lower=n.a', u'|B-LOC'): 3.206087
# (u'+1:word.lower=plains', u'|B-LOC'): 3.204186
# (u'+1:word.lower=lanka', u'|B-LOC'): 3.193377
# (u'word.lower=caribbean', u'|B-LOC'): 3.187674
# (u'word.lower=medicare', u'|B-MISC'): 3.186204
# (u'word[-3:]=bia', u'|I-LOC'): 3.184146
# (u'word.lower=belgium', u'|B-LOC'): 3.170967
# (u'word.lower=president', u'|O'): 3.167331
# (u'-1:word.lower=general', u'|B-PER'): 3.1442
# (u'word.isdigit=True', u'|I-MISC'): 3.144012
# (u'word.lower=hospital', u'|I-LOC'): 3.140671
# (u'word.lower=betaseron', u'|B-MISC'): 3.139617
# (u'word.lower=airbus', u'|B-MISC'): 3.137983
# (u'word[-3:]=dys', u'|B-PER'): 3.118323
# (u'word[-3:]=rry', u'|B-PER'): 3.117436
# (u'word[-3:]=DON', u'|B-LOC'): 3.116282
# (u'word.lower=diana', u'|B-PER'): 3.116033
# (u'word.lower=congo', u'|B-LOC'): 3.113038
# (u'word.lower=bhutto', u'|B-PER'): 3.11295
# (u'word[-3:]=K', u'|O'): 3.104433
# (u'word[-2:]=K', u'|O'): 3.104433
# (u'word.lower=k', u'|O'): 3.104433
# (u'word[-3:]=36C', u'|O'): 3.103332
# (u'word[-2:]=6C', u'|O'): 3.103332
# (u'word.lower=28-36c', u'|O'): 3.103332
# (u'word.lower=hasina', u'|B-PER'): 3.103037
# (u'word.lower=total', u'|O'): 3.097408
# (u'word.lower=tankan', u'|B-ORG'): 3.097252
# (u'word.lower=december', u'|O'): 3.095847
# (u'word.lower=udinese', u'|B-ORG'): 3.089769
# (u'+1:word.lower=22', u'|B-ORG'): 3.085199
# (u'word.isupper=False', u'|O'): 3.084929
# (u'word.lower=aug', u'|O'): 3.081827
# (u'word.lower=amtrak', u'|B-ORG'): 3.072444
# (u'word.lower=stich', u'|B-PER'): 3.07178
# (u'-1:word.lower=queen', u'|B-PER'): 3.065481
# (u'-1:word.lower=7.', u'|B-PER'): 3.06417
# (u'word.lower=stork', u'|B-ORG'): 3.058322
# (u'word.lower=algiers', u'|B-LOC'): 3.057394
# (u'word.lower=vogts', u'|B-PER'): 3.055891
# (u'word[-3:]=har', u'|B-LOC'): 3.050255
# (u'word.lower=bundesliga', u'|B-MISC'): 3.047693
# (u'word.lower=january', u'|O'): 3.047314
# (u'+1:word.lower=told', u'|B-PER'): 3.046535
# (u'word.lower=democrats', u'|B-MISC'): 3.04552
# (u'word.lower=huber', u'|B-PER'): 3.030648
# (u'word.lower=unita', u'|B-ORG'): 3.018264
# (u'word.lower=nepal', u'|B-LOC'): 3.015812
# (u'word.lower=dayton', u'|B-LOC'): 3.012754
# (u'word.lower=cuba', u'|B-LOC'): 3.010621
# (u'word.lower=masters', u'|I-MISC'): 3.009693
# (u'word.lower=moldova', u'|B-LOC'): 3.005712
# (u'word.lower=gujral', u'|B-PER'): 3.005282
# (u'word[-2:]=LA', u'|B-LOC'): 3.003687
# (u'-1:word.lower=capital', u'|B-LOC'): 3.002632
# (u'word.lower=olazabal', u'|B-PER'): 2.995849
# (u'word.lower=sauber', u'|B-ORG'): 2.988693
# (u'word.lower=nicaraguan', u'|B-MISC'): 2.988339
# (u'word.lower=porto', u'|B-ORG'): 2.982931
# (u'word.lower=benfica', u'|B-ORG'): 2.981975
# (u'word.lower=islamist', u'|B-MISC'): 2.979455
# (u'word[-3:]=azi', u'|B-MISC'): 2.977436
# (u'word.lower=manchester', u'|B-LOC'): 2.973879
# (u'word.lower=olympics', u'|B-MISC'): 2.973614
# (u'word.lower=mypa-47', u'|B-ORG'): 2.972931
# (u'word[-3:]=bul', u'|B-LOC'): 2.968725
# (u'word.lower=names', u'|B-MISC'): 2.968006
# (u'word.lower=fleurian', u'|B-PER'): 2.966218
# (u'-1:word.lower=major', u'|I-MISC'): 2.965298
# (u'word.lower=frenchman', u'|B-MISC'): 2.965207
# (u'word[-3:]=vic', u'|B-PER'): 2.964384
# (u'word.lower=match', u'|O'): 2.963862
# (u'word.lower=afghan', u'|B-MISC'): 2.960966
# (u'word.lower=sakigake', u'|B-ORG'): 2.957854
# (u'word.lower=by', u'|O'): 2.954317
# (u'word.lower=tour', u'|B-MISC'): 2.95225
# (u'-1:word.lower=spreading', u'|B-MISC'): 2.952112
# (u'word.lower=costain', u'|B-ORG'): 2.949124
# (u'word.lower=harding', u'|B-PER'): 2.94863
# (u'word.lower=owens', u'|B-PER'): 2.942875
# (u'+1:word.lower=2', u'|I-ORG'): 2.940754
# (u'word.lower=french', u'|B-MISC'): 2.940347
# (u'word.lower=montpellier', u'|B-ORG'): 2.938634
# (u'word.lower=february', u'|O'): 2.938279
# (u'word[-3:]=his', u'|O'): 2.935385
# (u'-1:word.lower=st', u'|I-LOC'): 2.9311
# (u'word.lower=surrey', u'|B-ORG'): 2.930703
# (u'word.lower=neagle', u'|B-PER'): 2.928581
# (u'word[-3:]=DRs', u'|B-MISC'): 2.925921
# (u'word[-2:]=Rs', u'|B-MISC'): 2.925921
# (u'word.lower=adrs', u'|B-MISC'): 2.925921
# (u'word.lower=gov', u'|O'): 2.922847
# (u'word[-3:]=ass', u'|I-MISC'): 2.92133
# (u"word[-3:]='S", u'|O'): 2.920646
# (u"word[-2:]='S", u'|O'): 2.920646
# (u'word.lower=barcelona', u'|B-ORG'): 2.918283
# (u'word.lower=netherlands', u'|B-LOC'): 2.916699
# (u'word.lower=edouard', u'|B-MISC'): 2.913911
# (u'word[-3:]=BIT', u'|B-MISC'): 2.91336
# (u'word.lower=cebit', u'|B-MISC'): 2.91336
# (u'-1:word.lower=midfielder', u'|B-PER'): 2.909918
# (u'word[-3:]=AEK', u'|B-ORG'): 2.906327
# (u'word[-2:]=-1', u'|O'): 2.905166
# (u'+1:word.lower=20', u'|B-ORG'): 2.903087
# (u'word.lower=maoist', u'|B-MISC'): 2.896409
# (u'word[-3:]=May', u'|O'): 2.892369
# (u'word[-3:]=PLO', u'|B-MISC'): 2.892247
# (u'word.lower=dalglish', u'|B-PER'): 2.891553
# (u'+1:word.lower=sultan', u'|O'): 2.890161
# (u'word[-3:]=aus', u'|B-PER'): 2.882969
# (u'-1:word.lower=serie', u'|I-MISC'): 2.881453
# (u'+1:word.lower=9', u'|B-ORG'): 2.880381
# (u'+1:word.lower=2', u'|B-ORG'): 2.877508
# (u'word[-3:]=hat', u'|O'): 2.876008
# (u'-1:word.lower=at', u'|B-LOC'): 2.872825
# (u'-1:word.lower=flight', u'|B-MISC'): 2.869963
# (u'word.lower=neuchatel', u'|B-ORG'): 2.867003
# (u'word.lower=lelouche', u'|B-PER'): 2.865053
# (u'word.lower=bastia', u'|B-ORG'): 2.865025
# (u'word.lower=nantes', u'|B-ORG'): 2.862773
# (u'word[-2:]=45', u'|O'): 2.859702
# (u'word[-3:]=H1', u'|O'): 2.855025
# (u'word[-2:]=H1', u'|O'): 2.855025
# (u'word.lower=h1', u'|O'): 2.855025
# (u'word[-2:]=OJ', u'|B-ORG'): 2.854981
# (u'word.lower=as', u'|O'): 2.854788
# (u'word[-3:]=cor', u'|B-ORG'): 2.851842
# (u'word.lower=pivotal', u'|B-PER'): 2.847795
# (u'word.lower=vanlandingham', u'|B-PER'): 2.845799
# (u'word.lower=when', u'|O'): 2.83011
# (u'word[-3:]=C', u'|O'): 2.829701
# (u'word[-2:]=C', u'|O'): 2.829701
# (u'word.lower=bonds', u'|B-PER'): 2.828594
# (u'word.lower=classic', u'|I-MISC'): 2.828532
# (u'+1:word.lower=cup', u'|B-MISC'): 2.828077
# (u'word.lower=israeli', u'|B-MISC'): 2.822062
# (u'word.lower=feyenoord', u'|B-ORG'): 2.818635
# (u'word[-3:]=200', u'|O'): 2.818629
# (u'word[-3:]=L', u'|O'): 2.812907
# (u'word[-2:]=L', u'|O'): 2.812907
# (u'word.lower=milan', u'|B-ORG'): 2.796886
# (u'-1:word.lower=million', u'|B-MISC'): 2.793598
# (u'word.lower=biogen', u'|B-ORG'): 2.792459
# (u'word.lower=carnival', u'|I-MISC'): 2.789491
# (u'word.lower=he', u'|O'): 2.788759
# (u'word.lower=there', u'|O'): 2.784072
# (u'word.lower=x', u'|O'): 2.783388
# (u'word.lower=yankees', u'|B-ORG'): 2.78257
# (u'word.lower=coupon', u'|O'): 2.78237
# (u'word.lower=benetton', u'|B-ORG'): 2.776498
# (u'word.lower=results', u'|O'): 2.776311
# (u'word.lower=more', u'|O'): 2.775515
# (u'-1:word.lower=captain', u'|B-PER'): 2.774196
# (u'word[-3:]=Q2', u'|O'): 2.773448
# (u'word[-2:]=Q2', u'|O'): 2.773448
# (u'word.lower=q2', u'|O'): 2.773448
# (u'word.lower=slight', u'|B-PER'): 2.772695
# (u'word.lower=frankfurt', u'|B-LOC'): 2.771641
# (u'word.lower=attendance', u'|O'): 2.771374
# (u'word.lower=denmark', u'|B-LOC'): 2.768105
# (u'word.lower=saeed', u'|B-PER'): 2.767384
# (u'-1:word.lower=5.', u'|B-PER'): 2.764935
# (u'word.lower=serb-controlled', u'|B-MISC'): 2.764586
# (u'-1:word.lower=president', u'|B-PER'): 2.764571
# (u'+1:word.lower=ground', u'|B-LOC'): 2.763691
# (u'word.lower=newcombe', u'|B-PER'): 2.761143
# (u'word.lower=in', u'|O'): 2.760321
# (u'word.lower=republic', u'|I-LOC'): 2.757278
# (u'word.lower=however', u'|O'): 2.75381
# (u'+1:word.lower=5', u'|I-ORG'): 2.751406
# (u'word[-3:]=X', u'|O'): 2.750067
# (u'word[-2:]=X', u'|O'): 2.750067
# (u'word.lower=authority', u'|I-ORG'): 2.749598
# (u'-1:word.lower=irish', u'|I-ORG'): 2.748399
# (u'word.lower=golan', u'|B-LOC'): 2.744788
# (u'word[-3:]=IAN', u'|B-MISC'): 2.740738
# (u'word.lower=at', u'|O'): 2.739502
# (u'word[-3:]=W', u'|O'): 2.73901
# (u'word[-2:]=W', u'|O'): 2.73901
# (u'word.lower=w', u'|O'): 2.73901
# (u'+1:word.lower=company', u'|B-MISC'): 2.735449
# (u'word.lower=moada', u'|B-PER'): 2.734808
# (u'word.lower=ocean', u'|I-LOC'): 2.733436
# (u'word.lower=mcewen', u'|B-PER'): 2.728569
# (u'word[-2:]=65', u'|O'): 2.727125
# (u'+1:word.lower=6', u'|B-ORG'): 2.723719
# (u'word.lower=cofinec', u'|B-ORG'): 2.722032
# (u'word.lower=premier', u'|O'): 2.719408
# (u'-1:word.lower=c', u'|B-PER'): 2.712093
# (u'word[-3:]=nc.', u'|I-ORG'): 2.711737
# (u'word.lower=inc.', u'|I-ORG'): 2.711737
# (u'word.lower=bangkok', u'|B-LOC'): 2.709928
# (u'word.lower=warwickshire', u'|B-ORG'): 2.702279
# (u'word.lower=police', u'|O'): 2.699891
# (u'word.lower=cash', u'|O'): 2.696315
# (u'word.lower=i', u'|O'): 2.695342
# (u'word.lower=jerusalem', u'|B-LOC'): 2.68594
# (u'word.lower=tokyo', u'|B-LOC'): 2.683308
# (u'word.lower=brazil', u'|B-LOC'): 2.682465
# (u'word.lower=aberdeen', u'|B-ORG'): 2.672708
# (u'word.lower=gazprom', u'|B-ORG'): 2.670668
# (u'-1:word.lower=chronic', u'|O'): 2.670385
# (u'word.lower=commonwealth', u'|B-ORG'): 2.670178
# (u'+1:word.lower=river', u'|B-LOC'): 2.665475
# (u'word.lower=dole', u'|B-PER'): 2.653851
# (u'word.lower=knup', u'|B-PER'): 2.651839
# (u'word.lower=pakistani', u'|B-MISC'): 2.651465
# (u'word.lower=roma', u'|B-ORG'): 2.649358
# (u'word.lower=last', u'|O'): 2.64742
# (u'word.lower=scoreboard', u'|O'): 2.645442
# (u'word.lower=milwaukee', u'|B-ORG'): 2.640124
# (u'word[-3:]=Air', u'|B-ORG'): 2.639582
# (u'-1:word.lower=daily', u'|B-ORG'): 2.633607
# (u'word[-3:]=Com', u'|B-ORG'): 2.631455
# (u'word.lower=worldcom', u'|B-ORG'): 2.631455
# (u'word.lower=ireland', u'|I-LOC'): 2.63069
# (u'word.lower=year', u'|O'): 2.624434
# (u'word.lower=tigers', u'|B-ORG'): 2.623465
# (u'word.lower=juventus', u'|B-ORG'): 2.62105
# (u'+1:word.lower=1996-08-23', u'|I-LOC'): 2.620562
# (u'word[-2:]=A-', u'|O'): 2.620232
# (u'word.lower=three', u'|O'): 2.619014
# (u'word[-3:]=Aug', u'|O'): 2.614754
# (u'word.lower=gooch', u'|B-PER'): 2.613384
# (u'-1:word.lower=indonesia', u'|O'): 2.6115
# (u'word[-3:]=TRS', u'|B-ORG'): 2.610976
# (u'word.lower=rtrs', u'|B-ORG'): 2.610976
# (u'-1:word.lower=frenchman', u'|B-PER'): 2.610058
# (u'word[-3:]=hio', u'|B-LOC'): 2.609703
# (u'-1:word.lower=champion', u'|B-PER'): 2.608388
# (u'word.lower=from', u'|O'): 2.605178
# (u'word.lower=grasshoppers', u'|B-ORG'): 2.604231
# (u'word.lower=second', u'|O'): 2.602424
# (u'word[-3:]=une', u'|O'): 2.600441
# (u'word.lower=y', u'|O'): 2.598165
# (u'word[-3:]=rus', u'|B-LOC'): 2.597999
# (u'word[-2:]=zi', u'|B-MISC'): 2.596734
# (u'word.lower=seles', u'|B-PER'): 2.587612
# (u'word.lower=chechen', u'|B-MISC'): 2.586254
# (u'word.lower=traders', u'|O'): 2.586168
# (u'word.lower=berlex', u'|B-ORG'): 2.583547
# (u'word[-3:]=The', u'|O'): 2.575555
# (u'word.lower=graf', u'|B-PER'): 2.575072
# (u'word.lower=cooperative', u'|B-ORG'): 2.57441
# (u'+1:word.lower=24', u'|I-ORG'): 2.573792
# (u'+1:word.lower=netherlands', u'|B-LOC'): 2.570742
# (u'word.lower=americast', u'|B-ORG'): 2.569877
# (u'word.lower=mozambique', u'|B-LOC'): 2.56978
# (u'word[-2:]=r.', u'|O'): 2.569567
# (u'-1:word.lower=india', u'|B-ORG'): 2.569119
# (u'word.lower=cincinnati', u'|B-ORG'): 2.568245
# (u'-1:word.lower=world', u'|I-MISC'): 2.565475
# (u'+1:word.lower=mosque', u'|B-LOC'): 2.561437
# (u'word.lower=an', u'|O'): 2.558352
# (u'-1:word.lower=hapoel', u'|I-ORG'): 2.556179
# (u'word.lower=treasury', u'|B-ORG'): 2.553979
# (u'+1:word.lower=21', u'|I-ORG'): 2.553695
# (u'word[-3:]=iet', u'|B-MISC'): 2.551605
# (u'word.lower=chang', u'|B-PER'): 2.549214
# (u'word[-2:]=ez', u'|I-PER'): 2.549076
# (u'+1:word.lower=newspaper', u'|I-ORG'): 2.547826
# (u'word.lower=mentmore', u'|B-ORG'): 2.546367
# (u'word[-3:]=the', u'|I-MISC'): 2.539486
# (u'+1:word.lower=minister', u'|O'): 2.538112
# (u'word.lower=scotland', u'|B-LOC'): 2.53695
# (u'word.lower=seoul', u'|B-LOC'): 2.535887
# (u'word.lower=salang', u'|B-LOC'): 2.534942
# (u'word.lower=u.n.', u'|B-ORG'): 2.534431
# (u'word.lower=colorado', u'|B-LOC'): 2.527601
# (u'word.lower=midwest', u'|B-LOC'): 2.525994
# (u'word[-3:]=ian', u'|B-MISC'): 2.523764
# (u'word.lower=shanghai', u'|B-LOC'): 2.523191
# (u'word.lower=lehman', u'|B-ORG'): 2.521562
# (u'-1:word.lower=azad', u'|I-LOC'): 2.521533
# (u'word.lower=zastava', u'|B-ORG'): 2.521429
# (u'word.lower=egyptair', u'|B-ORG'): 2.52101
# (u'word[-2:]=vo', u'|B-LOC'): 2.520839
# (u'word.lower=his', u'|O'): 2.518453
# (u'+1:word.lower=frankie', u'|O'): 2.517644
# (u'-1:word.lower=cdu', u'|I-ORG'): 2.51703
# (u'word[-3:]=dOn', u'|B-ORG'): 2.515975
# (u'word.lower=adon', u'|B-ORG'): 2.515975
# (u'word[-3:]=Dow', u'|B-MISC'): 2.511246
# (u'word.lower=dow', u'|B-MISC'): 2.511246
# (u'word[-3:]=B', u'|O'): 2.508772
# (u'word[-2:]=B', u'|O'): 2.508772
# (u'word.lower=men', u'|O'): 2.507086
# (u'word.lower=atletico', u'|B-ORG'): 2.506896
# (u'word.lower=rica', u'|I-LOC'): 2.50413
# (u'word.lower=peres', u'|B-PER'): 2.500288
# (u'-1:word.lower=united', u'|I-LOC'): 2.500043
# (u'word.lower=sudan', u'|B-LOC'): 2.499688
# (u'-1:word.lower=frank', u'|I-PER'): 2.498938
# (u'word.lower=samsung', u'|B-ORG'): 2.497102
# (u'word.lower=department', u'|I-ORG'): 2.494709
# (u'word.lower=damascus', u'|B-LOC'): 2.489368
# (u'-1:word.lower=defender', u'|B-PER'): 2.487313
# (u'-1:word.lower=affairs', u'|B-PER'): 2.483867
# (u'+1:word.lower=money', u'|O'): 2.480917
# (u'word.lower=rome', u'|B-LOC'): 2.478974
# (u'word.lower=saudi', u'|B-MISC'): 2.477707
# (u'word.lower=not', u'|O'): 2.476492
# (u'word.lower=sion', u'|B-ORG'): 2.476291
# (u'word.lower=weaver', u'|B-PER'): 2.475678
# (u'word.lower=metro', u'|B-ORG'): 2.474248
# (u'word[-2:]=ct', u'|O'): 2.471532
# (u'word[-3:]=Y', u'|O'): 2.468129
# (u'word[-2:]=Y', u'|O'): 2.468129
# (u'word.lower=times', u'|I-ORG'): 2.463051
# (u'word.lower=implats', u'|B-ORG'): 2.458555
# (u'word[-3:]=cht', u'|B-ORG'): 2.458289
# (u'word.lower=prescott', u'|B-PER'): 2.45607
# (u'word.lower=revised', u'|O'): 2.454096
# (u'word.lower=lockhart', u'|B-ORG'): 2.452638
# (u'word.lower=argentina', u'|B-LOC'): 2.450236
# (u'word.lower=niugini', u'|B-ORG'): 2.449681
# (u'word.lower=batistuta', u'|B-PER'): 2.447719
# (u'word[-2:]=ti', u'|B-PER'): 2.446132
# (u'word.lower=mehrtens', u'|B-PER'): 2.443429
# (u'+1:word.lower=14', u'|B-ORG'): 2.439451
# (u'word[-3:]=ULO', u'|I-PER'): 2.439119
# (u'word[-3:]=led', u'|B-MISC'): 2.436215
# (u'word[-3:]=sas', u'|B-LOC'): 2.435703
# (u'+1:word.lower=league', u'|B-MISC'): 2.435649
# (u'word.lower=palestinians', u'|B-MISC'): 2.431698
# (u'word[-3:]=Q3', u'|O'): 2.430873
# (u'word[-2:]=Q3', u'|O'): 2.430873
# (u'word.lower=q3', u'|O'): 2.430873
# (u'word.lower=post', u'|I-ORG'): 2.429944
# (u'+1:word.lower=ocean', u'|B-LOC'): 2.429442
# (u'word[-3:]=fax', u'|B-ORG'): 2.42777
# (u'word.lower=israelis', u'|B-MISC'): 2.427445
# (u'word.lower=but', u'|O'): 2.426302
# (u'word[-2:]=v.', u'|O'): 2.425774
# (u'word.lower=yeltsin', u'|B-PER'): 2.422432
# (u'word.lower=bunds', u'|B-MISC'): 2.422063
# (u'word.lower=paris', u'|B-LOC'): 2.41857
# (u'word[-3:]=bas', u'|B-ORG'): 2.417014
# (u'word[-2:]=RC', u'|B-ORG'): 2.414216
# (u'word.lower=balkan', u'|B-LOC'): 2.412151
# (u'word.lower=jews', u'|B-MISC'): 2.410653
# (u'+1:word.lower=research', u'|B-ORG'): 2.41033
# (u'+1:word.lower=1', u'|B-ORG'): 2.409856
# (u'word[-2:]=TA', u'|B-ORG'): 2.409155
# (u'word.lower=mostostal', u'|B-ORG'): 2.408491
# (u'word.lower=on', u'|O'): 2.408247
# (u'word.lower=nato', u'|B-ORG'): 2.407338
# (u'word.lower=yemen', u'|B-LOC'): 2.406993
# (u'-1:word.lower=west', u'|I-LOC'): 2.404885
# (u'word.lower=gatwick', u'|B-LOC'): 2.401157
# (u'+1:word.lower=wins', u'|B-PER'): 2.397759
# (u'word.lower=beat', u'|O'): 2.396774
# (u'word.lower=hearts', u'|B-ORG'): 2.392947
# (u'word[-3:]=ien', u'|B-PER'): 2.392489
# (u'word.lower=botham', u'|B-PER'): 2.39133
# (u'-1:word.lower=de', u'|I-PER'): 2.383791
# (u'word.lower=friday', u'|O'): 2.383529
# (u'word.lower=european', u'|B-MISC'): 2.381696
# (u'-1:word.lower=speaker', u'|B-PER'): 2.3793
# (u'word.lower=basic', u'|O'): 2.379009
# (u'+1:word.lower=(', u'|I-PER'): 2.378112
# (u'word[-2:]=ie', u'|B-PER'): 2.375563
# (u'word.lower=newcastle', u'|B-ORG'): 2.374991
# (u'word.lower=karachi', u'|B-LOC'): 2.369219
# (u'word[-2:]=NU', u'|B-ORG'): 2.359572
# (u'word.lower=philippoussis', u'|B-PER'): 2.359144
# (u'-1:word.lower=manager', u'|B-PER'): 2.359072
# (u'word.lower=said', u'|O'): 2.358639
# (u'word.lower=pole', u'|B-MISC'): 2.354971
# (u'word.lower=corp', u'|I-ORG'): 2.354732
# (u'word[-2:]=im', u'|B-PER'): 2.353295
# (u'-1:word.lower=in', u'|B-LOC'): 2.352352
# (u'word.lower=english', u'|B-MISC'): 2.351075
# (u'word[-3:]=ert', u'|B-PER'): 2.350751
# (u'word.lower=mullally', u'|B-PER'): 2.349658
# (u'word[-3:]=D', u'|O'): 2.349473
# (u'word[-2:]=D', u'|O'): 2.349473
# (u'word.lower=d', u'|O'): 2.349473
# (u'word[-3:]=MT', u'|B-LOC'): 2.346958
# (u'word.lower=mt', u'|B-LOC'): 2.346958
# (u'word.lower=cork', u'|B-PER'): 2.341699
# (u'-1:word.lower=san', u'|I-LOC'): 2.338592
# (u'word.lower=poland', u'|B-LOC'): 2.337974
# (u'word.lower=india', u'|B-LOC'): 2.330296
# (u'+1:word.lower=through', u'|I-PER'): 2.327966
# (u'word.lower=swiss', u'|B-MISC'): 2.327088
# (u'-1:word.lower=hassan', u'|I-PER'): 2.326172
# (u'word[-3:]=Q1', u'|O'): 2.326148
# (u'word[-2:]=Q1', u'|O'): 2.326148
# (u'word.lower=q1', u'|O'): 2.326148
# (u'word[-2:]=SV', u'|B-ORG'): 2.325616
# (u'word[-3:]=vak', u'|B-MISC'): 2.323491
# (u'+1:word.lower=school', u'|O'): 2.32314
# (u'word.lower=benin', u'|B-LOC'): 2.317178
# (u'word.lower=serie', u'|B-MISC'): 2.316506
# (u'word.lower=media', u'|O'): 2.316089
# (u'word[-3:]=tar', u'|B-ORG'): 2.313273
# (u'+1:word.lower=6', u'|I-ORG'): 2.312635
# (u'word.lower=massachusetts', u'|B-LOC'): 2.312382
# (u'word.lower=boardman', u'|B-PER'): 2.311534
# (u'word[-2:]=LO', u'|I-PER'): 2.310405
# (u'word[-2:]=AE', u'|B-LOC'): 2.309257
# (u'word.lower=michael', u'|B-PER'): 2.306896
# (u'word.lower=may', u'|O'): 2.305405
# (u'word.lower=lebed', u'|B-PER'): 2.305
# (u'word.lower=togo', u'|B-LOC'): 2.303987
# (u'word.lower=ducati', u'|B-ORG'): 2.303283
# (u'word.lower=marcelo', u'|B-PER'): 2.302381
# (u'-1:word.lower=fdp', u'|B-ORG'): 2.300609
# (u'+1:word.lower=pds', u'|B-ORG'): 2.300609
# (u'word.lower=reuter', u'|B-PER'): 2.297274
# (u'word.lower=death', u'|O'): 2.293264
# (u'word.lower=almere', u'|B-LOC'): 2.289995
# (u'word.lower=moslems', u'|B-MISC'): 2.288734
# (u'-1:word.lower=newsroom', u'|O'): 2.284246
# (u'word.lower=london', u'|B-LOC'): 2.283758
# (u'+1:word.lower=1996-08-21', u'|B-LOC'): 2.283211
# (u'word[-3:]=nya', u'|B-LOC'): 2.281866
# (u'+1:word.lower=added', u'|B-PER'): 2.276129
# (u'+1:word.lower=peace', u'|B-MISC'): 2.27592
# (u'-1:word.lower=firm', u'|B-ORG'): 2.273823
# (u'word.lower=james', u'|B-PER'): 2.273801
# (u'word.lower=officials', u'|O'): 2.271547
# (u'+1:word.lower=1', u'|I-ORG'): 2.271229
# (u'word.lower=both', u'|O'): 2.270712
# (u'word[-3:]=nen', u'|B-PER'): 2.270326
# (u'word.lower=wimbledon', u'|B-MISC'): 2.270174
# (u'word.lower=tutsis', u'|B-MISC'): 2.269982
# (u'word.lower=sampdoria', u'|B-ORG'): 2.269604
# (u'word.lower=lebanon', u'|B-LOC'): 2.267634
# (u'-1:word.lower=leader', u'|B-PER'): 2.266483
# (u'word.lower=sea', u'|I-LOC'): 2.26412
# (u'word.lower=slovak', u'|B-MISC'): 2.260142
# (u'word.lower=kashmir', u'|B-LOC'): 2.256285
# (u'word[-3:]=son', u'|B-PER'): 2.253846
# (u'word.lower=united', u'|B-ORG'): 2.253134
# (u'word.lower=namibian', u'|O'): 2.252892
# (u'word.lower=shell', u'|I-ORG'): 2.251471
# (u'word.lower=med', u'|B-LOC'): 2.248171
# (u'word[-2:]=IA', u'|B-LOC'): 2.244906
# (u'word[-3:]=ish', u'|B-MISC'): 2.243656
# (u'word.lower=russia', u'|B-LOC'): 2.243586
# (u'word.isdigit=True', u'|O'): 2.24303
# (u'word[-2:]=T-', u'|O'): 2.240195
# (u'word.lower=pollock', u'|B-PER'): 2.239859
# (u'+1:word.lower=medical', u'|B-ORG'): 2.23975
# (u'-1:word.lower=hurricane', u'|B-MISC'): 2.239741
# (u'word.lower=arafat', u'|B-PER'): 2.238978
# (u'word.lower=australia', u'|B-LOC'): 2.238382
# (u'word[-3:]=fat', u'|B-PER'): 2.238321
# (u'word.lower=tass', u'|B-ORG'): 2.23566
# (u'+1:word.lower=v', u'|I-ORG'): 2.228932
# (u'word.lower=interior', u'|B-ORG'): 2.227839
# (u'word[-3:]=N', u'|O'): 2.22412
# (u'word[-2:]=N', u'|O'): 2.22412
# (u'word.lower=n', u'|O'): 2.22412
# (u'+1:word.lower=wa', u'|B-LOC'): 2.223458
# (u'word.lower=khmer', u'|B-ORG'): 2.222711
# (u'word.lower=haga', u'|B-PER'): 2.222685
# (u'word.lower=mark', u'|B-PER'): 2.220907
# (u'+1:word.lower=which', u'|I-MISC'): 2.220618
# (u'+1:word.lower=told', u'|I-PER'): 2.219519
# (u'word[-3:]=mmy', u'|B-PER'): 2.219333
# (u'word[-3:]=hey', u'|O'): 2.219162
# (u'word.lower=xinhua', u'|B-ORG'): 2.215523
# (u'-1:word.lower=st', u'|I-ORG'): 2.215188
# (u'+1:word.lower=division', u'|B-MISC'): 2.214061
# (u'-1:word.lower=ogilvy', u'|I-ORG'): 2.213392
# (u'+1:word.lower=mather', u'|I-ORG'): 2.213392
# (u'word.lower=tennis', u'|O'): 2.212806
# (u'word[-3:]=nsa', u'|B-ORG'): 2.212497
# (u'word[-3:]=Men', u'|O'): 2.211219
# (u'word.lower=mccoist', u'|I-PER'): 2.210809
# (u'-1:word.lower=ally', u'|I-PER'): 2.210809
# (u'word[-3:]=ept', u'|O'): 2.210681
# (u'word.lower=durham', u'|B-ORG'): 2.210594
# (u'word.lower=masterkova', u'|B-PER'): 2.210554
# (u'+1:word.lower=5', u'|B-ORG'): 2.205462
# (u'word.lower=third', u'|O'): 2.204688
# (u'word.lower=weizman', u'|B-PER'): 2.203788
# (u'word.lower=mccarthy', u'|B-PER'): 2.202496
# (u'word.lower=alliance', u'|I-ORG'): 2.202182
# (u'+1:word.lower=25', u'|I-ORG'): 2.200781
# (u'+1:word.lower=independent', u'|I-LOC'): 2.197392
# (u'word.lower=bonn', u'|B-LOC'): 2.195761
# (u'word.lower=mather', u'|I-ORG'): 2.195211
# (u'-1:word.lower=group', u'|B-ORG'): 2.194868
# (u'word.lower=mafia', u'|O'): 2.194603
# (u'word[-3:]=oom', u'|I-ORG'): 2.194544
# (u'word.lower=lewis', u'|B-PER'): 2.194357
# (u'word[-3:]=ire', u'|B-ORG'): 2.193522
# (u'word.lower=singer', u'|B-MISC'): 2.192192
# (u'word[-3:]=H2', u'|O'): 2.192166
# (u'word[-2:]=H2', u'|O'): 2.192166
# (u'word.lower=h2', u'|O'): 2.192166
# (u'-1:word.lower=korea', u'|O'): 2.188707
# (u'word.lower=honda', u'|B-ORG'): 2.1861
# (u'+1:word.lower=daily', u'|I-ORG'): 2.184738
# (u'word.lower=melbourne', u'|B-LOC'): 2.183656
# (u'word.lower=kashmir', u'|I-LOC'): 2.182925
# (u'word.lower=checkfree', u'|B-ORG'): 2.181941
# (u'word.lower=burundi', u'|B-LOC'): 2.181062
# (u'+1:word.lower=sets', u'|I-ORG'): 2.178616
# (u'-1:word.lower=tour', u'|I-MISC'): 2.178501
# (u'-1:word.lower=american', u'|B-PER'): 2.177732
# (u'word.lower=berlin', u'|B-LOC'): 2.176522
# (u'word.lower=salamanca', u'|B-LOC'): 2.17498
# (u'-1:word.lower=european', u'|I-ORG'): 2.174059
# (u'word.lower=maleeva', u'|B-PER'): 2.169903
# (u'word.lower=alexandroupolis', u'|B-LOC'): 2.169745
# (u'word[-2:]=TA', u'|B-LOC'): 2.165209
# (u'word.lower=record', u'|O'): 2.164389
# (u'+1:word.lower=7', u'|I-ORG'): 2.163644
# (u'-1:word.lower=1.', u'|B-PER'): 2.163426
# (u'word.lower=newsroom', u'|I-ORG'): 2.162437
# (u'+1:word.lower=flight', u'|I-MISC'): 2.155317
# (u'word.lower=singapore', u'|B-LOC'): 2.15384
# (u'word.lower=edison', u'|I-ORG'): 2.153724
# (u'word[-3:]=SON', u'|I-PER'): 2.152974
# (u'+1:word.lower=born', u'|I-PER'): 2.145636
# (u'-1:word.lower=america', u'|I-ORG'): 2.145196
# (u'word.lower=grand', u'|B-MISC'): 2.145101
# (u'word[-3:]=sed', u'|B-MISC'): 2.144492
# (u'+1:word.lower=korean', u'|B-MISC'): 2.1431
# (u'word[-2:]=ha', u'|I-PER'): 2.142586
# (u'word.lower=this', u'|O'): 2.140539
# (u'word[-3:]=ead', u'|O'): 2.140421
# (u'word.lower=republican', u'|B-MISC'): 2.140202
# (u'word[-2:]=BA', u'|B-ORG'): 2.135184
# (u'-1:word.lower=winners', u'|I-MISC'): 2.134929
# (u'word[-2:]=RG', u'|B-LOC'): 2.131639
# (u'word.lower=sidor', u'|B-ORG'): 2.130756
# (u'-1:word.istitle=True', u'|I-PER'): 2.128972
# (u'+1:word.lower=ceasefire', u'|B-MISC'): 2.128916
# (u'word.lower=cargill', u'|B-ORG'): 2.125582
# (u'word.lower=association', u'|I-ORG'): 2.125379
# (u'-1:word.lower=buducnost', u'|I-ORG'): 2.124726
# (u'word.lower=sidhu', u'|B-PER'): 2.121408
# (u'word[-3:]=chs', u'|I-ORG'): 2.12126
# (u'word.lower=hutus', u'|B-MISC'): 2.118685
# (u'word[-3:]=ndi', u'|B-LOC'): 2.11752
# (u'+1:word.lower=free', u'|I-LOC'): 2.117004
# (u'word.lower=chief', u'|O'): 2.116364
# (u'word.lower=prix', u'|B-MISC'): 2.112403
# (u'word.lower=mariners', u'|B-ORG'): 2.111422
# (u'+1:word.lower=c', u'|I-PER'): 2.110222
# (u'-1:word.lower=commonwealth', u'|I-LOC'): 2.109343
# (u'word[-3:]=nex', u'|B-MISC'): 2.108274
# (u'word.lower=avonex', u'|B-MISC'): 2.108274
# (u'-1:word.lower=brian', u'|I-PER'): 2.107974
# (u'word[-3:]=Day', u'|I-MISC'): 2.107579
# (u'word[-3:]=yan', u'|B-MISC'): 2.106484
# (u'word[-3:]=BAD', u'|B-LOC'): 2.105468
# (u'word.lower=colorado', u'|B-ORG'): 2.103502
# (u'word[-3:]=igh', u'|O'): 2.102404
# (u'-1:word.lower=maker', u'|B-ORG'): 2.10196
# (u'-1:word.lower=human', u'|I-ORG'): 2.09959
# (u'word.lower=open', u'|B-MISC'): 2.097008
# (u'word.lower=vicente', u'|B-PER'): 2.096457
# (u'word.lower=oncins', u'|B-PER'): 2.095237
# (u'word[-3:]=eve', u'|B-PER'): 2.094475
# (u'word.lower=swebus', u'|B-ORG'): 2.090152
# (u'word[-2:]=ac', u'|B-ORG'): 2.087805
# (u'word.lower=brann', u'|B-ORG'): 2.084283
# (u'word.lower=housecall', u'|B-ORG'): 2.081646
# (u'+1:word.lower=beef', u'|B-MISC'): 2.080773
# (u'word.lower=school', u'|O'): 2.079087
# (u'word[-3:]=oft', u'|B-ORG'): 2.078994
# (u'word[-3:]=ons', u'|O'): 2.078389
# (u'word.lower=eco-challenge', u'|B-MISC'): 2.075036
# (u'word.lower=slough', u'|B-ORG'): 2.073896
# (u'word.lower=sale', u'|O'): 2.07304
# (u'word[-2:]=si', u'|B-PER'): 2.071948
# (u'word[-3:]=Jan', u'|O'): 2.071576
# (u'word.lower=jan', u'|O'): 2.071576
# (u'word.lower=amsterdam', u'|B-LOC'): 2.071482
# (u'word[-3:]=ice', u'|I-ORG'): 2.069877
# (u'-1:word.lower=(', u'|I-PER'): 2.06927
# (u'word[-3:]=0-B', u'|O'): 2.066208
# (u'word[-2:]=-B', u'|O'): 2.066208
# (u'word.lower=55,000-b', u'|O'): 2.066208
# (u'word.lower=many', u'|O'): 2.065869
# (u'word.lower=ferencvaros', u'|B-ORG'): 2.061754
# (u'word.lower=kalashnikov', u'|B-MISC'): 2.061431
# (u'word.lower=finland', u'|B-LOC'): 2.061404
# (u'word.lower=bayern', u'|B-ORG'): 2.060584
# (u'word.lower=taiwan', u'|B-LOC'): 2.055415
# (u'word[-2:]=AC', u'|B-ORG'): 2.054238
# (u'word.lower=sept', u'|O'): 2.052329
# (u'word[-3:]=pic', u'|I-MISC'): 2.051202
# (u'+1:word.lower=made', u'|B-PER'): 2.051116
# (u'word.lower=belgrade', u'|B-LOC'): 2.04821
# (u'word[-2:]=ez', u'|B-PER'): 2.047999
# (u'word[-3:]=nny', u'|B-PER'): 2.047145
# (u'word.lower=rangers', u'|B-ORG'): 2.045617
# (u'word[-3:]=iss', u'|B-MISC'): 2.042742
# (u'+1:word.lower=div', u'|O'): 2.041706
# (u'word.lower=agreement', u'|I-MISC'): 2.0401
# (u'word.lower=nijmeh', u'|B-ORG'): 2.038971
# (u'-1:word.lower=finance', u'|B-PER'): 2.037631
# (u'word[-2:]=-2', u'|O'): 2.037266
# (u'word.lower=thousands', u'|O'): 2.035308
# (u'+1:word.lower=leader', u'|B-MISC'): 2.030443
# (u'word.lower=win', u'|O'): 2.028762
# (u'word.lower=peru', u'|B-LOC'): 2.026477
# (u'word.lower=palmans', u'|B-ORG'): 2.024837
# (u'word.lower=beirut', u'|B-LOC'): 2.024597
# (u'word.lower=her', u'|O'): 2.024021
# (u'word.lower=earlier', u'|O'): 2.023006
# (u'word.lower=nice', u'|B-ORG'): 2.02256
# (u'word[-3:]=ont', u'|B-LOC'): 2.019687
# (u'word.lower=supercup', u'|B-MISC'): 2.016912
# (u'+1:word.lower=sea', u'|B-LOC'): 2.01653
# (u'word.lower=squad', u'|O'): 2.016401
# (u'+1:word.lower=19', u'|B-ORG'): 2.016209
# (u'word.lower=olympic', u'|B-MISC'): 2.015626
# (u'word[-2:]=NP', u'|B-ORG'): 2.015589
# (u'+1:word.lower=includes', u'|O'): 2.01523
# (u'word.lower=baltimore', u'|B-ORG'): 2.015137
# (u'word[-3:]=ous', u'|O'): 2.013842
# (u'word.lower=their', u'|O'): 2.010136
# (u'word.lower=gough', u'|B-PER'): 2.008996
# (u'word[-3:]=.K.', u'|B-LOC'): 2.00827
# (u'+1:word.lower=ptt', u'|B-ORG'): 2.008079
# (u'-1:word.lower=conference', u'|I-MISC'): 2.007373
# (u'word.lower=enqvist', u'|B-PER'): 2.006195
# (u'-1:word.lower=windows', u'|I-MISC'): 2.005206
# (u'word.lower=tamils', u'|B-MISC'): 2.001846
# (u'word[-3:]=G', u'|O'): 2.001035
# (u'word[-2:]=G', u'|O'): 2.001035
# (u'word.lower=g', u'|O'): 2.001035
# (u'word.lower=athens', u'|B-LOC'): 2.000995
# (u'word[-3:]=Rep', u'|B-MISC'): 2.000925
# (u'word.lower=rep', u'|B-MISC'): 2.000925
# (u'word[-3:]=wen', u'|B-PER'): 1.999583
# (u'word[-3:]=ANS', u'|B-MISC'): 1.999506
# (u'word[-3:]=FOR', u'|O'): 1.998883
# (u'word.lower=weld', u'|B-PER'): 1.998761
# (u'word.lower=canada', u'|B-LOC'): 1.997699
# (u'word[-2:]=ia', u'|B-LOC'): 1.997601
# (u'word[-3:]=gon', u'|B-ORG'): 1.994795
# (u'word[-3:]=ial', u'|O'): 1.994788
# (u'word[-3:]=SCE', u'|B-ORG'): 1.992599
# (u'word.lower=osce', u'|B-ORG'): 1.992599
# (u'word.lower=washington', u'|B-LOC'): 1.991178
# (u'+1:word.lower=party', u'|I-ORG'): 1.989494
# (u'word.lower=celtic', u'|B-ORG'): 1.988786
# (u'word.lower=rennes', u'|B-ORG'): 1.986387
# (u'word[-3:]=M4', u'|O'): 1.98371
# (u'word[-2:]=M4', u'|O'): 1.98371
# (u'word.lower=m4', u'|O'): 1.98371
# (u'word.lower=grozny', u'|B-LOC'): 1.983679
# (u'BOS', u'|B-ORG'): 1.981498
# (u'word[-3:]=bed', u'|B-PER'): 1.981273
# (u'word[-3:]=ral', u'|O'): 1.981189
# (u'word[-3:]=uly', u'|O'): 1.975519
# (u'word.lower=medicaid', u'|B-MISC'): 1.972273
# (u'word[-3:]=rew', u'|B-PER'): 1.970614
# (u'word.lower=shares', u'|O'): 1.970562
# (u'-1:word.lower=spanish', u'|B-MISC'): 1.969886
# (u'word.lower=texas', u'|B-ORG'): 1.969572
# (u'word.lower=spokesman', u'|O'): 1.967123
# (u'word.lower=states', u'|I-LOC'): 1.966909
# (u'word.lower=ruutel', u'|B-PER'): 1.966593
# (u'word.lower=cairo', u'|B-LOC'): 1.965854
# (u'word.lower=somerset', u'|B-ORG'): 1.9646
# (u'word.lower=one', u'|O'): 1.961217
# (u'word.lower=florida', u'|B-LOC'): 1.958581
# (u'word.lower=up', u'|O'): 1.954517
# (u'word.lower=escort', u'|I-MISC'): 1.954446
# (u'word[-2:]=ya', u'|B-LOC'): 1.951028
# (u'word.lower=popov', u'|B-PER'): 1.950391
# (u'word.lower=everton', u'|B-ORG'): 1.950302
# (u'word.lower=bailey', u'|B-PER'): 1.948255
# (u'-1:word.lower=u.s.', u'|I-MISC'): 1.947767
# (u'word.lower=ecuador', u'|B-LOC'): 1.945264
# (u'word.lower=japan', u'|B-LOC'): 1.944976
# (u'word[-2:]=tt', u'|B-PER'): 1.943716
# (u'word.lower=reagan', u'|B-PER'): 1.943592
# (u'word[-3:]=A$', u'|B-MISC'): 1.942317
# (u'word[-2:]=A$', u'|B-MISC'): 1.942317
# (u'word.lower=a$', u'|B-MISC'): 1.942317
# (u'word.lower=portugal', u'|B-LOC'): 1.942154
# (u'word.lower=brunswijk', u'|B-PER'): 1.941518
# (u'+1:word.lower=commissioner', u'|O'): 1.940288
# (u'word[-3:]=E', u'|O'): 1.937452
# (u'word[-2:]=E', u'|O'): 1.937452
# (u'word.lower=e', u'|O'): 1.937452
# (u'-1:word.lower=0', u'|B-ORG'): 1.937225
# (u'word.lower=philadelphia', u'|B-ORG'): 1.935975
# (u'word.lower=takeda', u'|B-PER'): 1.935839
# (u'word[-3:]=Cup', u'|B-MISC'): 1.93583
# (u'word[-2:]=lo', u'|I-LOC'): 1.933569
# (u'word.lower=dutchman', u'|B-MISC'): 1.933269
# (u'word.lower=bridge', u'|I-LOC'): 1.933124
# (u'word.lower=guinea', u'|B-LOC'): 1.932595
# (u'word[-2:]=DA', u'|B-ORG'): 1.93197
# (u'word[-3:]=lin', u'|B-LOC'): 1.931454
# (u'word.lower=ing', u'|B-ORG'): 1.929947
# (u'word.lower=detroit', u'|B-ORG'): 1.928297
# (u'word.lower=mitchell', u'|B-PER'): 1.927641
# (u'word.lower=republic', u'|B-LOC'): 1.927498
# (u'+1:word.lower=not', u'|I-PER'): 1.922392
# (u'word.lower=yedioth', u'|B-ORG'): 1.92227
# (u'word.lower=alberta', u'|B-LOC'): 1.921715
# (u'word.lower=commissioner', u'|O'): 1.921708
# (u'word.lower=czech', u'|B-MISC'): 1.92073
# (u'word[-3:]=For', u'|O'): 1.920293
# (u'word[-3:]=lli', u'|B-PER'): 1.918858
# (u'word[-3:]=gal', u'|B-LOC'): 1.916254
# (u'word.lower=manly', u'|B-ORG'): 1.915952
# (u'word[-3:]=pan', u'|B-LOC'): 1.912077
# (u'+1:word.lower=signs', u'|B-PER'): 1.911943
# (u'word[-3:]=sea', u'|B-ORG'): 1.909179
# (u'word.lower=former', u'|O'): 1.908793
# (u'-1:word.lower=spokesman', u'|B-PER'): 1.907801
# (u'word.lower=zurich', u'|B-LOC'): 1.907653
# (u'word[-3:]=Mia', u'|B-PER'): 1.906279
# (u'word.lower=mia', u'|B-PER'): 1.906279
# (u'word.lower=burma', u'|B-LOC'): 1.905808
# (u'word[-3:]=He', u'|O'): 1.905453
# (u'word[-2:]=He', u'|O'): 1.905453
# (u'word[-3:]=PDS', u'|B-ORG'): 1.904768
# (u'word.lower=pds', u'|B-ORG'): 1.904768
# (u'word[-2:]=LO', u'|B-ORG'): 1.904098
# (u'word.lower=turnover', u'|O'): 1.903584
# (u'-1:word.lower=humanitarian', u'|I-ORG'): 1.903233
# (u'word.lower=sharpe', u'|B-PER'): 1.902831
# (u'word.lower=stock', u'|O'): 1.902805
# (u'word[-3:]=RT-', u'|O'): 1.902638
# (u'word.lower=-docstart-', u'|O'): 1.902638
# (u'-1:word.lower=greens', u'|B-ORG'): 1.902163
# (u'word.lower=paul', u'|B-PER'): 1.900795
# (u'word.lower=scores', u'|O'): 1.900767
# (u'word.lower=turkey', u'|B-LOC'): 1.899696
# (u'word.lower=sydney', u'|B-LOC'): 1.896571
# (u'+1:word.lower=rally', u'|B-MISC'): 1.89448
# (u'word.lower=union', u'|I-ORG'): 1.893837
# (u'+1:word.lower=manager', u'|B-ORG'): 1.893698
# (u'word[-3:]=eli', u'|B-MISC'): 1.89301
# (u'word[-3:]=eri', u'|B-PER'): 1.890438
# (u'word.lower=best', u'|B-ORG'): 1.888486
# (u'word.lower=smicer', u'|B-PER'): 1.887901
# (u'word.lower=bessemer', u'|B-ORG'): 1.88784
# (u'word.lower=calcutta', u'|B-LOC'): 1.885115
# (u'-1:word.lower=sheffield', u'|I-ORG'): 1.883357
# (u'word.lower=bugno', u'|B-PER'): 1.881707
# (u'word.lower=park', u'|I-LOC'): 1.880632
# (u'word[-3:]=P', u'|O'): 1.880616
# (u'word[-2:]=P', u'|O'): 1.880616
# (u'word.lower=p', u'|O'): 1.880616
# (u'word.lower=1,000', u'|B-MISC'): 1.880506
# (u'-1:word.istitle=False', u'|I-PER'): 1.880433
# (u'-1:word.lower=stephen', u'|I-PER'): 1.877401
# (u"word.lower=o'neal", u'|B-PER'): 1.877328
# (u'+1:word.lower=news', u'|B-ORG'): 1.876154
# (u'word[-3:]=iti', u'|I-PER'): 1.874261
# (u'word[-3:]=ang', u'|B-PER'): 1.874153
# (u'word.lower=and', u'|O'): 1.872606
# (u'word.lower=partizan', u'|B-ORG'): 1.872173
# (u'-1:word.lower=)', u'|B-ORG'): 1.870962
# (u'word.lower=edberg', u'|B-PER'): 1.870409
# (u'word.lower=order', u'|O'): 1.868629
# (u'word.lower=co', u'|I-ORG'): 1.868542
# (u'word.lower=bucharest', u'|B-LOC'): 1.867757
# (u'word[-3:]=ans', u'|B-MISC'): 1.866143
# (u'word.lower=moscow', u'|B-LOC'): 1.86601
# (u'word[-2:]=-0', u'|O'): 1.863958
# (u'word.lower=front', u'|I-ORG'): 1.861008
# (u'+1:word.lower=party', u'|B-ORG'): 1.860777
# (u'word.lower=regulation', u'|I-MISC'): 1.859961
# (u'word.lower=labour', u'|B-ORG'): 1.854627
# (u'-1:word.isupper=True', u'|I-PER'): 1.853836
# (u'word.lower=sheet', u'|O'): 1.851441
# (u'word[-2:]=RT', u'|B-LOC'): 1.850169
# (u'word[-3:]=can', u'|I-MISC'): 1.849186
# (u'word.lower=heerenveen', u'|B-ORG'): 1.846816
# (u'word[-3:]=RBI', u'|B-MISC'): 1.8439
# (u'word.lower=rbi', u'|B-MISC'): 1.8439
# (u'-1:word.lower=ambassador', u'|B-PER'): 1.843828
# (u'-1:word.lower=side', u'|B-ORG'): 1.843807
# (u'-1:word.lower=latest', u'|O'): 1.843785
# (u'-1:word.lower=maria', u'|I-PER'): 1.842188
# (u'-1:word.lower=coupon', u'|O'): 1.841335
# (u'word[-3:]=los', u'|B-PER'): 1.83741
# (u'word[-3:]=tts', u'|B-LOC'): 1.837023
# (u'word.lower=pacific', u'|B-LOC'): 1.836755
# (u'-1:word.lower=south', u'|I-LOC'): 1.834575
# (u'word.lower=khartoum', u'|B-LOC'): 1.833123
# (u'word.lower=italian', u'|B-MISC'): 1.832288
# (u'+1:word.lower=takes', u'|B-PER'): 1.830564
# (u'word.lower=grobbelaar', u'|B-PER'): 1.828168
# (u'word[-3:]=F', u'|O'): 1.826595
# (u'word[-2:]=F', u'|O'): 1.826595
# (u'word.lower=f', u'|O'): 1.826595
# (u'word.lower=fairmont', u'|B-LOC'): 1.82562
# (u'+1:word.lower=1996-08-24', u'|I-LOC'): 1.825515
# (u'word[-3:]=qis', u'|B-MISC'): 1.824613
# (u'word.lower=iraqis', u'|B-MISC'): 1.824613
# (u'+1:word.lower=open', u'|B-MISC'): 1.824219
# (u'-1:word.lower=tue', u'|B-ORG'): 1.823528
# (u'-1:word.lower=in', u'|I-ORG'): 1.821351
# (u'+1:word.lower=newsroom', u'|B-LOC'): 1.821243
# (u'word[-3:]=raq', u'|B-LOC'): 1.81954
# (u'word[-3:]=rra', u'|B-ORG'): 1.817514
# (u'word[-3:]=UK', u'|B-LOC'): 1.816614
# (u'word.lower=uk', u'|B-LOC'): 1.816614
# (u'word.lower=kurds', u'|B-MISC'): 1.816573
# (u'word.lower=roest', u'|B-PER'): 1.816565
# (u'-1:word.lower=local', u'|B-MISC'): 1.815512
# (u'word.lower=fowler', u'|B-PER'): 1.815397
# (u'word[-3:]=nor', u'|O'): 1.815171
# (u'word.lower=coast', u'|I-ORG'): 1.814653
# (u'+1:word.lower=b', u'|I-PER'): 1.813353
# (u'word[-3:]=V', u'|O'): 1.811909
# (u'word[-2:]=V', u'|O'): 1.811909
# (u'-1:word.lower=atlanta', u'|B-MISC'): 1.811849
# (u'word[-3:]=But', u'|O'): 1.808799
# (u'word.lower=pembroke', u'|B-LOC'): 1.808648
# (u'+1:word.lower=1996', u'|O'): 1.805377
# (u'word[-3:]=ssi', u'|B-PER'): 1.805193
# (u'+1:word.lower=regulation', u'|B-MISC'): 1.801801
# (u'-1:word.lower=secretary', u'|B-PER'): 1.801392
# (u'word.lower=midwest', u'|I-LOC'): 1.800953
# (u'word.lower=glamorgan', u'|B-ORG'): 1.800808
# (u'word.lower=telecom', u'|I-ORG'): 1.800534
# (u'word.lower=sosa', u'|B-PER'): 1.799101
# (u'+1:word.lower=said', u'|B-PER'): 1.797233
# (u'word.lower=hurricane', u'|O'): 1.796849
# (u'word.lower=cyprus', u'|B-LOC'): 1.795366
# (u'word[-3:]=ypt', u'|B-LOC'): 1.795258
# (u'word.lower=egypt', u'|B-LOC'): 1.795258
# (u'+1:word.lower=price', u'|O'): 1.794019
# (u'word.lower=l', u'|O'): 1.791226
# (u'word.lower=boland', u'|B-ORG'): 1.790075
# (u'word.lower=tibetan', u'|B-MISC'): 1.789346
# (u'-1:word.lower=thu', u'|B-ORG'): 1.78876
# (u'word.lower=anatolian', u'|B-ORG'): 1.788013
# (u'-1:word.lower=mark', u'|I-PER'): 1.78787
# (u'word.lower=sep', u'|O'): 1.78777
# (u'word.lower=ferrigato', u'|B-PER'): 1.786063
# (u'word.lower=xhosa', u'|B-MISC'): 1.785555
# (u'word.lower=meri', u'|B-PER'): 1.785098
# (u'-1:word.lower=cooperation', u'|I-ORG'): 1.781802
# (u'word.lower=judge', u'|O'): 1.781747
# (u'word[-3:]=dra', u'|B-PER'): 1.779984
# (u'word.lower=seat', u'|B-ORG'): 1.779892
# (u'word[-3:]=uty', u'|O'): 1.778927
# (u'word.lower=internet', u'|B-MISC'): 1.778163
# (u'+1:word.lower=declined', u'|B-PER'): 1.7766
# (u'word[-3:]=wan', u'|B-LOC'): 1.775522
# (u'-1:word.lower=310', u'|B-MISC'): 1.775423
# (u'+1:word.lower=called', u'|B-PER'): 1.774714
# (u'-1:word.lower=w145', u'|B-ORG'): 1.772924
# (u'+1:word.lower=provincial', u'|B-LOC'): 1.772772
# (u'-1:word.lower=social', u'|I-MISC'): 1.770951
# (u'word[-2:]=ME', u'|B-ORG'): 1.770313
# (u'-1:word.lower=diario', u'|I-ORG'): 1.770087
# (u'word.lower=iliescu', u'|B-PER'): 1.768394
# (u'word[-3:]=bin', u'|B-PER'): 1.768256
# (u'word.lower=nations', u'|I-MISC'): 1.767017
# (u'word.lower=atria', u'|B-ORG'): 1.76507
# (u'word.lower=richard', u'|B-PER'): 1.76448
# (u'word.lower=czech', u'|B-LOC'): 1.762828
# (u'+1:word.lower=black', u'|B-MISC'): 1.762467
# (u'word[-3:]=Inc', u'|I-ORG'): 1.760972
# (u'word.lower=inc', u'|I-ORG'): 1.760972
# (u'+1:word.lower=55', u'|B-ORG'): 1.760427
# (u'word[-3:]=PUK', u'|B-ORG'): 1.756672
# (u'word.lower=puk', u'|B-ORG'): 1.756672
# (u'word[-2:]=ER', u'|B-PER'): 1.756529
# (u'word.lower=150', u'|B-MISC'): 1.75465
# (u'word.lower=angels', u'|B-ORG'): 1.753758
# (u'word.lower=dinamo', u'|B-ORG'): 1.753349
# (u'word[-3:]=sex', u'|B-ORG'): 1.752362
# (u'word.lower=swede', u'|B-MISC'): 1.751767
# (u'word.lower=heathrow', u'|B-LOC'): 1.751468
# (u'word[-2:]=op', u'|O'): 1.750467
# (u'word.lower=gulf', u'|I-LOC'): 1.749958
# (u'word.lower=cup', u'|I-MISC'): 1.749433
# (u'-1:word.lower=pakistan', u'|O'): 1.748993
# (u'-1:word.lower=atlanta', u'|I-MISC'): 1.748112
# (u'word[-3:]=DEM', u'|B-MISC'): 1.747983
# (u'word.lower=dem', u'|B-MISC'): 1.747983
# (u'word.lower=iran', u'|B-LOC'): 1.747928
# (u'word[-3:]=War', u'|I-MISC'): 1.747706
# (u'word[-2:]=Z$', u'|B-MISC'): 1.746502
# (u'word[-3:]=ere', u'|O'): 1.746421
# (u'+1:word.lower=unit', u'|B-ORG'): 1.741848
# (u'-1:word.lower=edge', u'|B-ORG'): 1.741671
# (u'word.lower=dealers', u'|O'): 1.741455
# (u'-1:word.lower=chg', u'|O'): 1.740389
# (u'word[-3:]=mir', u'|I-LOC'): 1.739774
# ...
# (u'word[-3:]=ins', u'|B-MISC'): -0.595199
# (u'word[-2:]=te', u'|B-MISC'): -0.595961
# (u'word.istitle=False', u'|I-ORG'): -0.596523
# (u'-1:word.lower=former', u'|O'): -0.600398
# (u'word[-2:]=ss', u'|I-PER'): -0.60244
# (u'word[-3:]=TON', u'|O'): -0.604339
# (u'-1:word.isupper=False', u'|B-LOC'): -0.609113
# (u'word[-2:]=et', u'|B-ORG'): -0.611014
# (u'-1:word.lower=euro', u'|O'): -0.611641
# (u'-1:word.lower=in', u'|B-ORG'): -0.612985
# (u'word[-3:]=cia', u'|B-LOC'): -0.614337
# (u'+1:word.lower=with', u'|B-MISC'): -0.617007
# (u'-1:word.istitle=True', u'|B-MISC'): -0.61844
# (u'-1:word.isupper=True', u'|B-MISC'): -0.624063
# (u'+1:word.lower=at', u'|B-MISC'): -0.628326
# (u'+1:word.lower=1', u'|B-PER'): -0.628437
# (u'word[-2:]=ai', u'|I-PER'): -0.628952
# (u'-1:word.lower=affairs', u'|I-ORG'): -0.629449
# (u'word[-2:]=ca', u'|I-ORG'): -0.630773
# (u'word[-3:]=dge', u'|B-PER'): -0.631632
# (u'+1:word.lower=was', u'|I-ORG'): -0.631913
# (u'+1:word.lower=0', u'|B-PER'): -0.633234
# (u'+1:word.lower=3', u'|O'): -0.637899
# (u'word[-3:]=rie', u'|B-PER'): -0.641135
# (u'-1:word.lower="', u'|B-LOC'): -0.642455
# (u'-1:word.lower=0', u'|B-PER'): -0.643356
# (u'word[-3:]=ent', u'|I-PER'): -0.644096
# (u'word[-2:]=of', u'|B-PER'): -0.644928
# (u'+1:word.lower=1', u'|B-LOC'): -0.647155
# (u'word[-2:]=an', u'|I-ORG'): -0.650606
# (u'word[-3:]=ONG', u'|O'): -0.656811
# (u'-1:word.lower=(', u'|B-MISC'): -0.66228
# (u'word[-2:]=up', u'|I-PER'): -0.665758
# (u'word[-2:]=ws', u'|B-PER'): -0.666034
# (u'word[-2:]=ss', u'|B-LOC'): -0.666235
# (u'word[-3:]=ice', u'|B-PER'): -0.668144
# (u'+1:word.lower=to', u'|B-MISC'): -0.668574
# (u'+1:word.lower=golf', u'|O'): -0.671351
# (u'-1:word.lower=visit', u'|O'): -0.671502
# (u'word[-2:]=te', u'|B-LOC'): -0.671504
# (u"+1:word.lower='", u'|O'): -0.671748
# (u'+1:word.lower=4', u'|O'): -0.672211
# (u'word[-2:]=AM', u'|O'): -0.674481
# (u'word[-2:]=AL', u'|O'): -0.674698
# (u'-1:word.lower=trinidad', u'|O'): -0.675532
# (u'word[-3:]=ess', u'|I-PER'): -0.677508
# (u'word[-2:]=er', u'|I-ORG'): -0.677881
# (u'-1:word.lower=bank', u'|O'): -0.680051
# (u'word[-2:]=er', u'|B-LOC'): -0.685106
# (u'word[-3:]=lia', u'|O'): -0.68603
# (u'word[-3:]=led', u'|O'): -0.688084
# (u'word[-3:]=ard', u'|B-LOC'): -0.688514
# (u'word[-3:]=ISS', u'|O'): -0.689053
# (u'word[-3:]=rth', u'|B-PER'): -0.691478
# (u'word[-2:]=se', u'|I-PER'): -0.692688
# (u'+1:word.lower=had', u'|O'): -0.695017
# (u'word[-3:]=man', u'|B-LOC'): -0.695909
# (u'+1:word.lower=win', u'|O'): -0.695941
# (u'word.isupper=False', u'|B-LOC'): -0.698742
# (u'-1:word.lower=german', u'|I-MISC'): -0.69901
# (u'+1:word.lower=,', u'|B-ORG'): -0.699406
# (u'word[-3:]=95', u'|O'): -0.699946
# (u'word.lower=95', u'|O'): -0.699946
# (u'word[-3:]=nia', u'|B-PER'): -0.700521
# (u'+1:word.lower=-', u'|B-ORG'): -0.701862
# (u'+1:word.lower=by', u'|B-MISC'): -0.702519
# (u'word.lower=united', u'|O'): -0.705185
# (u'word[-2:]=bs', u'|O'): -0.711755
# (u'+1:word.lower=scored', u'|O'): -0.713679
# (u'word[-3:]=nel', u'|B-PER'): -0.721503
# (u'+1:word.lower=c', u'|O'): -0.722863
# (u'word[-3:]=ish', u'|B-LOC'): -0.725062
# (u'+1:word.lower=5', u'|B-LOC'): -0.725464
# (u'+1:word.lower=disarmament', u'|O'): -0.729694
# (u'word.lower=swiss', u'|O'): -0.731699
# (u'word[-2:]=ky', u'|O'): -0.731983
# (u'+1:word.lower=(', u'|B-ORG'): -0.732073
# (u'+1:word.lower=has', u'|B-MISC'): -0.736879
# (u'-1:word.lower=york', u'|I-LOC'): -0.737602
# (u'word[-3:]=ian', u'|B-LOC'): -0.739281
# (u'word[-2:]=NK', u'|O'): -0.739632
# (u'+1:word.lower=and', u'|O'): -0.740593
# (u'+1:word.lower=1', u'|I-LOC'): -0.742273
# (u'word[-3:]=ler', u'|O'): -0.746797
# (u'word[-3:]=zer', u'|O'): -0.749343
# (u'-1:word.lower=while', u'|O'): -0.75026
# (u'word.istitle=False', u'|I-LOC'): -0.753784
# (u'+1:word.lower=(', u'|O'): -0.7563
# (u'word[-2:]=ly', u'|B-LOC'): -0.756715
# (u'+1:word.lower=said', u'|B-LOC'): -0.757302
# (u'-1:word.lower=said', u'|O'): -0.757715
# (u'-1:word.lower=on', u'|B-PER'): -0.759285
# (u'word[-2:]=st', u'|I-PER'): -0.759524
# (u'-1:word.istitle=True', u'|B-LOC'): -0.764422
# (u'word.isdigit=True', u'|B-ORG'): -0.771351
# (u'-1:word.lower=attend', u'|O'): -0.772806
# (u'+1:word.lower=at', u'|B-LOC'): -0.775195
# (u'word[-3:]=ISH', u'|O'): -0.777992
# (u'-1:word.lower=but', u'|O'): -0.780165
# (u'-1:word.istitle=True', u'|B-PER'): -0.785439
# (u'+1:word.lower=v', u'|O'): -0.786043
# (u'word[-2:]=lo', u'|I-PER'): -0.789986
# (u'+1:word.lower=has', u'|O'): -0.792159
# (u'word[-3:]=den', u'|O'): -0.797906
# (u'-1:word.lower=by', u'|O'): -0.800268
# (u'+1:word.lower=on', u'|B-MISC'): -0.802006
# (u'word[-2:]=na', u'|B-MISC'): -0.80345
# (u'-1:word.lower=new', u'|B-PER'): -0.808511
# (u'word[-3:]=les', u'|O'): -0.808976
# (u'-1:word.lower=told', u'|O'): -0.810749
# (u'word[-2:]=bo', u'|O'): -0.814122
# (u'+1:word.lower=73', u'|O'): -0.814605
# (u'word[-2:]=ce', u'|B-MISC'): -0.814865
# (u'-1:word.lower=for', u'|O'): -0.815967
# (u'word[-2:]=PA', u'|O'): -0.821569
# (u'word[-2:]=ie', u'|O'): -0.821882
# (u'word[-2:]=OM', u'|O'): -0.824004
# (u'+1:word.lower=fighter', u'|O'): -0.824708
# (u'word[-3:]=ean', u'|B-LOC'): -0.827073
# (u'word[-3:]=ist', u'|B-ORG'): -0.82736
# (u'word[-2:]=ca', u'|I-PER'): -0.830064
# (u'word[-3:]=002', u'|O'): -0.830983
# (u'word[-2:]=am', u'|B-MISC'): -0.835745
# (u'+1:word.lower=in', u'|B-MISC'): -0.838634
# (u'-1:word.istitle=True', u'|B-ORG'): -0.83882
# (u'word[-2:]=lo', u'|O'): -0.842164
# (u'word[-2:]=me', u'|B-ORG'): -0.847914
# (u'word[-3:]=LES', u'|O'): -0.848446
# (u'+1:word.lower=and', u'|I-MISC'): -0.848909
# (u'word[-2:]=RI', u'|O'): -0.851506
# (u'word.lower=the', u'|B-MISC'): -0.854079
# (u'word[-3:]=tts', u'|O'): -0.857672
# (u'word[-3:]=uth', u'|B-PER'): -0.86723
# (u'word.lower=north', u'|O'): -0.86737
# (u'word[-3:]=TLE', u'|O'): -0.867907
# (u'-1:word.lower=,', u'|O'): -0.870087
# (u'-1:word.lower=the', u'|O'): -0.870543
# (u'word[-3:]=ine', u'|O'): -0.87217
# (u'-1:word.isupper=False', u'|O'): -0.873725
# (u'word[-3:]=ain', u'|B-PER'): -0.874547
# (u'+1:word.lower=of', u'|B-MISC'): -0.876523
# (u'word[-2:]=IX', u'|O'): -0.877618
# (u'+1:word.lower=wins', u'|O'): -0.878228
# (u'word[-3:]=ANS', u'|O'): -0.879698
# (u'word[-2:]=ES', u'|B-LOC'): -0.879891
# (u'word[-2:]=ak', u'|O'): -0.880051
# (u'+1:word.lower=last', u'|I-ORG'): -0.886329
# (u'word[-2:]=ae', u'|O'): -0.893914
# (u'word[-3:]=ang', u'|O'): -0.90065
# (u'+1:word.lower=said', u'|I-LOC'): -0.90161
# (u'+1:word.lower=lakes', u'|O'): -0.903979
# (u'-1:word.lower=ftse', u'|O'): -0.904431
# (u"+1:word.lower='s", u'|O'): -0.905269
# (u'word[-3:]=ris', u'|O'): -0.905365
# (u'word[-3:]=een', u'|B-LOC'): -0.908541
# (u'word.lower=french', u'|O'): -0.911077
# (u'+1:word.lower=al', u'|O'): -0.911204
# (u'+1:word.lower=territory', u'|O'): -0.912917
# (u'word[-2:]=rs', u'|B-LOC'): -0.918118
# (u'word[-2:]=UR', u'|O'): -0.920562
# (u'word[-3:]=sus', u'|O'): -0.92275
# (u'word[-3:]=way', u'|O'): -0.92379
# (u'+1:word.lower=party', u'|O'): -0.927276
# (u'word[-2:]=ow', u'|B-PER'): -0.927567
# (u'-1:word.lower=st', u'|O'): -0.928518
# (u'+1:word.lower=farmers', u'|O'): -0.928695
# (u'word[-2:]=IC', u'|O'): -0.929057
# (u'+1:word.isupper=True', u'|I-ORG'): -0.935452
# (u'-1:word.lower=,', u'|B-MISC'): -0.935548
# (u'word[-2:]=ns', u'|B-LOC'): -0.943378
# (u'word[-2:]=in', u'|B-ORG'): -0.947296
# (u'word[-3:]=ome', u'|I-PER'): -0.948758
# (u'word.istitle=False', u'|B-PER'): -0.952039
# (u'+1:word.lower=,', u'|B-MISC'): -0.952702
# (u'+1:word.lower=1', u'|O'): -0.956147
# (u'word[-2:]=SA', u'|O'): -0.957585
# (u'-1:word.lower=south', u'|O'): -0.961723
# (u'word.lower=county', u'|O'): -0.963309
# (u'word[-3:]=ica', u'|I-ORG'): -0.963594
# (u'-1:word.lower=--', u'|B-MISC'): -0.964188
# (u'word[-3:]=ass', u'|O'): -0.969483
# (u'+1:word.lower=yr', u'|O'): -0.969514
# (u'word[-2:]=ir', u'|I-ORG'): -0.9705
# (u'word[-2:]=GO', u'|O'): -0.972164
# (u'word.lower=prix', u'|O'): -0.974667
# (u'word[-3:]=hia', u'|B-LOC'): -0.979022
# (u'word[-2:]=ts', u'|B-PER'): -0.989322
# (u'word[-2:]=he', u'|B-LOC'): -0.99149
# (u'word[-2:]=do', u'|O'): -0.992871
# (u'word[-2:]=RE', u'|O'): -0.997089
# (u'word[-3:]=nne', u'|O'): -0.998942
# (u'+1:word.lower=miss', u'|O'): -1.00074
# (u'+1:word.lower=:', u'|B-ORG'): -1.002978
# (u'-1:word.lower=with', u'|O'): -1.01081
# (u'word[-3:]=ank', u'|I-PER'): -1.014711
# (u'word[-3:]=sed', u'|O'): -1.018383
# (u'+1:word.isupper=True', u'|I-LOC'): -1.023166
# (u'+1:word.lower=cup', u'|O'): -1.026609
# (u'word[-2:]=ia', u'|B-PER'): -1.043467
# (u'-1:word.lower=:', u'|B-MISC'): -1.047203
# (u'+1:word.lower=2', u'|O'): -1.047611
# (u'EOS', u'|I-ORG'): -1.056498
# (u'-1:word.lower=5', u'|B-PER'): -1.05776
# (u'word[-3:]=sen', u'|O'): -1.063684
# (u'word[-2:]=al', u'|B-PER'): -1.066005
# (u'-1:word.lower=and', u'|O'): -1.070529
# (u'word[-2:]=ev', u'|I-ORG'): -1.073311
# (u'word[-3:]=ing', u'|B-PER'): -1.082834
# (u'word[-3:]=nta', u'|B-PER'): -1.085116
# (u'+1:word.lower=gold', u'|O'): -1.085578
# (u'+1:word.lower=)', u'|I-PER'): -1.08675
# (u'word.lower=nice', u'|O'): -1.0869
# (u'word[-2:]=47', u'|O'): -1.093111
# (u'word[-3:]=can', u'|B-PER'): -1.097303
# (u'word[-2:]=ew', u'|B-PER'): -1.101364
# (u'word[-2:]=nt', u'|B-PER'): -1.101521
# (u'word[-2:]=ds', u'|B-PER'): -1.107183
# (u'+1:word.lower=3', u'|B-PER'): -1.107527
# (u'-1:word.lower=official', u'|O'): -1.114772
# (u'word[-2:]=es', u'|B-LOC'): -1.123553
# (u'word[-2:]=au', u'|O'): -1.127113
# (u'word.lower=1,000', u'|O'): -1.129951
# (u'-1:word.lower=cooperation', u'|O'): -1.131812
# (u'word[-2:]=an', u'|O'): -1.131998
# (u'word[-2:]=hy', u'|O'): -1.137486
# (u'+1:word.lower=said', u'|I-MISC'): -1.146647
# (u'-1:word.lower=interior', u'|O'): -1.151355
# (u'-1:word.lower=)', u'|B-PER'): -1.159568
# (u'+1:word.lower=,', u'|O'): -1.160072
# (u'+1:word.lower=won', u'|O'): -1.172838
# (u'+1:word.lower=netherlands', u'|O'): -1.176436
# (u'+1:word.lower=restaurant', u'|O'): -1.178257
# (u'word[-3:]=ana', u'|B-ORG'): -1.183065
# (u'word[-2:]=pe', u'|O'): -1.188434
# (u'-1:word.lower=russian', u'|I-MISC'): -1.190808
# (u'word[-2:]=om', u'|I-LOC'): -1.190927
# (u'-1:word.lower=from', u'|O'): -1.197362
# (u'EOS', u'|B-MISC'): -1.198497
# (u'-1:word.lower=people', u'|O'): -1.206809
# (u'word[-3:]=don', u'|B-PER'): -1.210715
# (u'-1:word.isupper=True', u'|B-LOC'): -1.217522
# (u'word[-3:]=uth', u'|O'): -1.222954
# (u'word[-2:]=ia', u'|B-MISC'): -1.223129
# (u'word[-3:]=run', u'|O'): -1.225203
# (u'+1:word.lower=2', u'|B-LOC'): -1.226354
# (u'word[-2:]=ty', u'|I-PER'): -1.227966
# (u'word[-2:]=IT', u'|O'): -1.229279
# (u'word[-3:]=orn', u'|O'): -1.231373
# (u'word[-2:]=ei', u'|O'): -1.243964
# (u'word[-3:]=ent', u'|B-LOC'): -1.249169
# (u'word[-3:]=ray', u'|O'): -1.250057
# (u'word[-3:]=Air', u'|O'): -1.252235
# (u'-1:word.lower=central', u'|O'): -1.255039
# (u'-1:word.lower=beat', u'|B-MISC'): -1.25652
# (u'-1:word.lower=of', u'|B-PER'): -1.260297
# (u'+1:word.lower=:', u'|I-ORG'): -1.260329
# (u'word[-3:]=de', u'|O'): -1.262446
# (u'word.lower=commission', u'|O'): -1.26686
# (u'-1:word.lower=commission', u'|I-ORG'): -1.268774
# (u'word[-2:]=ka', u'|O'): -1.269594
# (u'word[-2:]=ry', u'|B-MISC'): -1.274604
# (u'+1:word.lower=(', u'|B-MISC'): -1.275428
# (u'-1:word.lower=a', u'|B-PER'): -1.280313
# (u'+1:word.lower=cut', u'|O'): -1.280472
# (u'-1:word.lower=l', u'|O'): -1.290803
# (u'+1:word.lower=van', u'|O'): -1.302759
# (u'word[-3:]=tte', u'|O'): -1.302948
# (u'-1:word.lower=/', u'|B-ORG'): -1.305724
# (u'word.lower=wall', u'|O'): -1.320925
# (u'word[-3:]=ton', u'|O'): -1.323567
# (u'word[-2:]=he', u'|B-PER'): -1.340337
# (u'word[-2:]=ER', u'|B-ORG'): -1.341494
# (u'+1:word.lower=rally', u'|O'): -1.353387
# (u'word[-2:]=ma', u'|O'): -1.357965
# (u'+1:word.lower=1', u'|B-MISC'): -1.358929
# (u'+1:word.lower=island', u'|O'): -1.360906
# (u'+1:word.lower=york', u'|O'): -1.361058
# (u'word[-2:]=ia', u'|O'): -1.367828
# (u'word[-2:]=ta', u'|O'): -1.370067
# (u'word[-2:]=GH', u'|O'): -1.381042
# (u'word[-3:]=her', u'|B-ORG'): -1.395066
# (u'-1:word.lower=of', u'|O'): -1.399837
# (u'word[-2:]=ue', u'|I-PER'): -1.406797
# (u'word.lower=coast', u'|O'): -1.411498
# (u'word[-3:]=van', u'|O'): -1.416689
# (u'-1:word.isupper=True', u'|B-ORG'): -1.417303
# (u'word[-3:]=ura', u'|B-LOC'): -1.434868
# (u'word[-2:]=NA', u'|O'): -1.446393
# (u'word[-3:]=ham', u'|O'): -1.448694
# (u'-1:word.lower=buducnost', u'|O'): -1.457924
# (u'+1:word.lower="', u'|I-PER'): -1.462483
# (u'+1:word.lower=free', u'|O'): -1.462876
# (u'word[-2:]=se', u'|B-LOC'): -1.463725
# (u'word[-3:]=ley', u'|O'): -1.465175
# (u'+1:word.lower=said', u'|O'): -1.474004
# (u'-1:word.lower=at', u'|O'): -1.474589
# (u'+1:word.lower=(', u'|B-LOC'): -1.47847
# (u'word[-2:]=IS', u'|O'): -1.479542
# (u'word[-2:]=ts', u'|B-LOC'): -1.492996
# (u'word[-3:]=ans', u'|B-PER'): -1.494445
# (u'word[-2:]=ki', u'|O'): -1.496022
# (u'word[-2:]=IO', u'|O'): -1.507341
# (u'word[-2:]=ca', u'|O'): -1.514176
# (u'-1:word.lower=in', u'|B-PER'): -1.518001
# (u'-1:word.lower=morinville', u'|O'): -1.528937
# (u'word[-3:]=tas', u'|O'): -1.529739
# (u'-1:word.lower=county', u'|O'): -1.54694
# (u'word[-3:]=yle', u'|O'): -1.554664
# (u'-1:word.lower=against', u'|O'): -1.558644
# (u'word[-2:]=os', u'|O'): -1.566561
# (u'word[-2:]=UP', u'|O'): -1.582863
# (u'word.istitle=False', u'|I-PER'): -1.584713
# (u'word[-2:]=st', u'|B-PER'): -1.594046
# (u'-1:word.lower=diario', u'|O'): -1.596083
# (u'word[-2:]=92', u'|O'): -1.602031
# (u'-1:word.lower=new', u'|O'): -1.64313
# (u'word[-3:]=don', u'|O'): -1.647289
# (u'word[-2:]=ue', u'|B-PER'): -1.65708
# (u'-1:word.lower=1', u'|B-PER'): -1.663599
# (u'word[-2:]=hi', u'|O'): -1.668294
# (u'word[-3:]=ion', u'|B-LOC'): -1.677595
# (u'+1:word.lower=flight', u'|O'): -1.688692
# (u'word[-3:]=rry', u'|O'): -1.697854
# (u'+1:word.lower=ceasefire', u'|O'): -1.70144
# (u'word[-3:]=can', u'|I-PER'): -1.710099
# (u'word[-2:]=TO', u'|O'): -1.730859
# (u'+1:word.lower=collective', u'|O'): -1.746129
# (u'word[-2:]=IA', u'|O'): -1.755513
# (u'-1:word.lower=university', u'|O'): -1.761008
# (u'word[-3:]=ath', u'|O'): -1.762923
# (u'word[-3:]=ury', u'|O'): -1.817241
# (u'-1:word.lower=hold', u'|O'): -1.823684
# (u'-1:word.lower=new', u'|B-LOC'): -1.826287
# (u'word[-3:]=iet', u'|O'): -1.828966
# (u'word[-3:]=.S.', u'|B-PER'): -1.832479
# (u'word[-2:]=TT', u'|O'): -1.835591
# (u'word.isupper=True', u'|O'): -1.83857
# (u'word[-3:]=eld', u'|O'): -1.85889
# (u'-1:word.lower=van', u'|O'): -1.86031
# (u'word[-2:]=AN', u'|O'): -1.865564
# (u'+1:word.lower=peace', u'|O'): -1.867171
# (u'word.lower=serie', u'|O'): -1.887828
# (u'word[-2:]=zi', u'|O'): -1.893611
# (u'+1:word.lower=congress', u'|O'): -1.905152
# (u'-1:word.lower=moody', u'|O'): -1.918716
# (u'+1:word.lower=said', u'|B-MISC'): -1.948161
# (u'+1:word.lower=radio', u'|O'): -1.960788
# (u'+1:word.lower=unit', u'|O'): -1.961831
# (u'word[-3:]=oft', u'|O'): -1.974162
# (u'-1:word.lower=)', u'|B-LOC'): -1.980007
# (u'word[-2:]=la', u'|O'): -1.9853
# (u'-1:word.lower=u.s.', u'|I-LOC'): -2.000343
# (u'-1:word.lower=at', u'|B-PER'): -2.018267
# (u'word[-2:]=AR', u'|O'): -2.033277
# (u'-1:word.lower=the', u'|B-PER'): -2.035026
# (u'word[-2:]=OS', u'|O'): -2.066396
# (u'word[-3:]=ren', u'|O'): -2.072527
# (u'-1:word.lower=cdu', u'|O'): -2.103716
# (u"+1:word.lower='s", u'|B-MISC'): -2.105159
# (u'word.lower=central', u'|O'): -2.121354
# (u'-1:word.lower=conference', u'|O'): -2.122584
# (u'word[-2:]=am', u'|O'): -2.126824
# (u'word[-2:]=AS', u'|O'): -2.224279
# (u'-1:word.lower=french', u'|I-MISC'): -2.232078
# (u'word.lower=de', u'|O'): -2.250846
# (u'+1:word.lower=india', u'|O'): -2.26278
# (u'word[-3:]=thy', u'|O'): -2.312283
# (u'word[-3:]=and', u'|B-PER'): -2.320989
# (u'word[-3:]=ion', u'|B-PER'): -2.33056
# (u'word[-2:]=da', u'|O'): -2.373803
# (u'word[-2:]=EN', u'|O'): -2.408321
# (u'word.isdigit=True', u'|I-ORG'): -2.440403
# (u'word.istitle=True', u'|O'): -2.458631
# (u'word[-2:]=ni', u'|O'): -2.497911
# (u'-1:word.lower=rugby', u'|O'): -2.559097
# (u'word[-2:]=ra', u'|O'): -2.612194
# (u'word[-2:]=mi', u'|O'): -2.617315
# (u'-1:word.lower=queen', u'|O'): -2.671588
# (u'word[-2:]=na', u'|O'): -2.68933
# (u'-1:word.lower=small', u'|O'): -2.750672
# (u'word[-2:]=li', u'|O'): -2.836295
# (u'-1:word.lower=beat', u'|O'): -2.930154
# (u'word[-3:]=ion', u'|I-PER'): -2.942737
# (u'+1:word.lower=missionary', u'|O'): -2.980494
# (u'+1:word.lower=welfare', u'|O'): -2.982082
# (u'-1:word.lower=de', u'|O'): -3.078883
# (u'word[-3:]=iff', u'|O'): -3.092703
# (u'word[-2:]=ai', u'|O'): -3.119691
# (u'word.isupper=True', u'|I-PER'): -3.172176
# (u'+1:word.lower=)', u'|B-PER'): -3.176116
# (u'word[-3:]=860', u'|O'): -4.301467
# (u'-1:word.lower=lloyd', u'|O'): -4.940157

# %% [markdown]
# Set up a grid search and 3-fold cross-validation.
#
# This will take HOURS to run. Note that max_iterations has been decreased to 20 (from 50) in order to expedite the task. This however causes a decrease in prediction performance compared to the previous cells.

# %%
# %%time
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=20,
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.05),
}

# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score,
                        average='weighted', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=50,
                        scoring=f1_scorer)
rs.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 23.7min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed: 82.9min finished
# CPU times: user 1h 21min 32s, sys: 1min 1s, total: 1h 22min 33s
# Wall time: 1h 23min 7s

# %% [markdown]
# Inspect the scores from the grid search. Note that the f1-score doesn't vary very much with the c1/c2 parameters and is more dependent on max_iterations.

# %%
rs.grid_scores_
# Out:
# [mean: 0.93933, std: 0.00517, params: {'c2': 0.05224537719245085, 'c1': 0.1552505912922396},
#  mean: 0.93920, std: 0.00486, params: {'c2': 0.014664972677450788, 'c1': 0.2181638197432444},
#  mean: 0.93563, std: 0.00529, params: {'c2': 0.058159123627147515, 'c1': 0.4849499133987302},
#  mean: 0.93755, std: 0.00339, params: {'c2': 0.05878669973066139, 'c1': 0.28935072323291616},
#  mean: 0.93915, std: 0.00312, params: {'c2': 0.027818150565818295, 'c1': 0.5510471061891358},
#  mean: 0.93560, std: 0.00508, params: {'c2': 0.08667614497770654, 'c1': 0.40032222000802303},
#  mean: 0.93943, std: 0.00361, params: {'c2': 0.08686049015897769, 'c1': 0.5662766651417782},
#  mean: 0.93858, std: 0.00452, params: {'c2': 0.2121673953171459, 'c1': 0.41193448415135336},
#  mean: 0.94031, std: 0.00454, params: {'c2': 0.04348195360013139, 'c1': 0.06138733444418406},
#  mean: 0.93568, std: 0.00357, params: {'c2': 0.003559452214544051, 'c1': 1.21303629583201},
#  mean: 0.93579, std: 0.00539, params: {'c2': 0.06606988307597234, 'c1': 0.4579073040618},
#  mean: 0.93359, std: 0.00394, params: {'c2': 0.0014076335582743143, 'c1': 1.531810357571399},
#  mean: 0.94043, std: 0.00431, params: {'c2': 0.010008992559494563, 'c1': 0.009469682425995725},
#  mean: 0.93686, std: 0.00360, params: {'c2': 0.016687577099499112, 'c1': 0.7723635179965032},
#  mean: 0.93769, std: 0.00346, params: {'c2': 0.10064522990141567, 'c1': 0.2547527308190315},
#  mean: 0.93914, std: 0.00306, params: {'c2': 0.0561460205047426, 'c1': 0.5471269382787364},
#  mean: 0.94034, std: 0.00453, params: {'c2': 0.05043937385497327, 'c1': 0.058382805853233584},
#  mean: 0.93593, std: 0.00374, params: {'c2': 0.08040975722743944, 'c1': 1.0182278889295227},
#  mean: 0.93546, std: 0.00505, params: {'c2': 0.07095752886588647, 'c1': 0.30520328471862773},
#  mean: 0.94046, std: 0.00453, params: {'c2': 0.027256235427481068, 'c1': 0.03153365787378851},
#  mean: 0.93653, std: 0.00353, params: {'c2': 0.0378800533276084, 'c1': 0.839789425512923},
#  mean: 0.93645, std: 0.00361, params: {'c2': 0.16966847824655798, 'c1': 0.8667056328313554},
#  mean: 0.93794, std: 0.00295, params: {'c2': 0.15020842158422296, 'c1': 0.6745812070452015},
#  mean: 0.93357, std: 0.00551, params: {'c2': 0.006308490840297211, 'c1': 1.356837717311185},
#  mean: 0.93524, std: 0.00366, params: {'c2': 0.03448309904168413, 'c1': 1.2675320275433726},
#  mean: 0.93802, std: 0.00277, params: {'c2': 0.0300310785837151, 'c1': 0.6775112704901867},
#  mean: 0.93931, std: 0.00498, params: {'c2': 0.059257413672169336, 'c1': 0.13136127507840492},
#  mean: 0.93531, std: 0.00477, params: {'c2': 0.006718981621141905, 'c1': 0.4468189970937998},
#  mean: 0.93563, std: 0.00340, params: {'c2': 0.040781131787253684, 'c1': 1.0695491473064138},
#  mean: 0.93527, std: 0.00464, params: {'c2': 0.07186734533561566, 'c1': 0.4311437535104564},
#  mean: 0.93576, std: 0.00546, params: {'c2': 0.02246837187352567, 'c1': 0.47373360056480507},
#  mean: 0.94065, std: 0.00424, params: {'c2': 0.025601748972799855, 'c1': 0.11303458841011417},
#  mean: 0.93913, std: 0.00511, params: {'c2': 0.026549604686289474, 'c1': 0.18351390751207536},
#  mean: 0.93932, std: 0.00510, params: {'c2': 0.00896149203245509, 'c1': 0.1656207244680392},
#  mean: 0.93653, std: 0.00357, params: {'c2': 0.010053900537581893, 'c1': 0.8709743955768999},
#  mean: 0.94057, std: 0.00444, params: {'c2': 0.0098325593231628, 'c1': 0.0051257917311506055},
#  mean: 0.93584, std: 0.00497, params: {'c2': 0.009489676387266326, 'c1': 0.3768913357546258},
#  mean: 0.93958, std: 0.00491, params: {'c2': 0.022715359180057963, 'c1': 0.12269201561905149},
#  mean: 0.93549, std: 0.00499, params: {'c2': 0.07355663593373807, 'c1': 0.3348331981636994},
#  mean: 0.93872, std: 0.00460, params: {'c2': 0.10776089882192774, 'c1': 0.21203106984015585},
#  mean: 0.93862, std: 0.00365, params: {'c2': 0.07298420700208293, 'c1': 0.6439534187225452},
#  mean: 0.93949, std: 0.00518, params: {'c2': 0.08013587005648094, 'c1': 0.11793265727172406},
#  mean: 0.94045, std: 0.00454, params: {'c2': 0.004386504250731849, 'c1': 0.0356593734585658},
#  mean: 0.93789, std: 0.00281, params: {'c2': 0.24251789468378626, 'c1': 0.36996050884104714},
#  mean: 0.93352, std: 0.00511, params: {'c2': 0.039109047050060915, 'c1': 1.729202428172893},
#  mean: 0.93590, std: 0.00483, params: {'c2': 0.06403496010425173, 'c1': 0.3498943985188234},
#  mean: 0.93934, std: 0.00505, params: {'c2': 0.012668946148647298, 'c1': 0.14574667662885055},
#  mean: 0.93766, std: 0.00344, params: {'c2': 0.05950780956398044, 'c1': 0.2669723589765533},
#  mean: 0.93934, std: 0.00358, params: {'c2': 0.0040612238866231465, 'c1': 0.6030948008035106},
#  mean: 0.93909, std: 0.00340, params: {'c2': 0.08674406737876998, 'c1': 0.6132176586621758}]

# %%
# crf = rs.best_estimator_
print('best params:', rs.best_params_)
print('best CV score:', rs.best_score_)
print('model size: {:0.2f}M'.format(rs.best_estimator_.size_ / 1000000))
# Out:
# ('best params:', {'c2': 0.025601748972799855, 'c1': 0.11303458841011417})
# ('best CV score:', 0.9406488963420524)
# model size: 3.00M

# %% [markdown]
# Print the per-label scores and the features ordered by importance for the best model found by the grid search.

# %%
crf = rs.best_estimator_
y_pred = crf.predict(X_test)
print(metrics.flat_classification_report(
    y_test, y_pred, labels=sorted_labels, digits=3
))

for key, value in sorted(crf.state_features_.iteritems(), key=lambda (k,v): (v,k), reverse=True):
    print "%s: %s" % (key, value)
# Out:
#              precision    recall  f1-score   support
#
#      |B-LOC      0.728     0.664     0.694      1669
#     |B-MISC      0.654     0.671     0.662       705
#      |B-ORG      0.746     0.435     0.549      1663
#      |B-PER      0.728     0.776     0.751      1617
#      |I-LOC      0.592     0.492     0.537       256
#     |I-MISC      0.236     0.671     0.349       213
#      |I-ORG      0.688     0.517     0.591       833
#      |I-PER      0.787     0.912     0.845      1156
#          |O      0.971     0.981     0.976     38554
#
# avg / total      0.926     0.924     0.922     46666
#
# (u'word[-3:]=I', u'|O'): 4.600259
# (u'word[-2:]=I', u'|O'): 4.600259
# (u'word.lower=i', u'|O'): 4.583866
# (u'word.lower=a', u'|O'): 4.203804
# (u'-1:word.lower=at', u'|B-LOC'): 3.583158
# (u'word.isupper=False', u'|O'): 3.145201
# (u'word[-3:]=A', u'|O'): 3.115499
# (u'word[-2:]=A', u'|O'): 3.115499
# (u'word.istitle=False', u'|O'): 3.102066
# (u'+1:word.lower=3', u'|B-ORG'): 2.800347
# (u'word[-2:]=T-', u'|O'): 2.755228
# (u'word[-3:]=RT-', u'|O'): 2.745734
# (u'word.lower=-docstart-', u'|O'): 2.745734
# (u'+1:word.lower=(', u'|I-PER'): 2.697492
# (u'word[-3:]=day', u'|O'): 2.595709
# (u'-1:word.lower=)', u'|B-ORG'): 2.335527
# (u'+1:word.lower=1', u'|B-ORG'): 2.325971
# (u'+1:word.lower=2', u'|B-ORG'): 2.300146
# (u'-1:word.istitle=True', u'|I-PER'): 2.277758
# (u'word[-2:]=ay', u'|O'): 2.187312
# (u'word.lower=london', u'|B-LOC'): 2.186259
# (u'+1:word.lower=1996-08-28', u'|B-LOC'): 2.130134
# (u'word.lower=in', u'|O'): 2.125583
# (u'word.lower=it', u'|O'): 2.076712
# (u'word.lower=at', u'|O'): 2.054312
# (u'word[-2:]=ut', u'|O'): 2.047169
# (u'+1:word.lower=0', u'|B-ORG'): 2.038406
# (u'word.lower=he', u'|O'): 2.033585
# (u'+1:word.lower=said', u'|B-PER'): 1.994162
# (u'word[-2:]=ia', u'|B-LOC'): 1.991143
# (u'word.isdigit=True', u'|O'): 1.942963
# (u'word[-3:]=ian', u'|B-MISC'): 1.891613
# (u'-1:word.lower=in', u'|B-LOC'): 1.874874
# (u'word[-3:]=He', u'|O'): 1.848723
# (u'word[-2:]=He', u'|O'): 1.848723
# (u'word[-2:]=an', u'|B-MISC'): 1.833855
# (u'word[-3:]=It', u'|O'): 1.833217
# (u'word[-2:]=It', u'|O'): 1.833217
# (u'word.lower=england', u'|B-LOC'): 1.823404
# (u'+1:word.lower=league', u'|B-MISC'): 1.798998
# (u'word[-3:]=ish', u'|B-MISC'): 1.791514
# (u'-1:word.isupper=True', u'|I-PER'): 1.782432
# (u'word.lower=thursday', u'|O'): 1.7803
# (u'word[-2:]=sh', u'|B-MISC'): 1.765244
# (u'word[-2:]=me', u'|O'): 1.764779
# (u'word.lower=minister', u'|O'): 1.725269
# (u'-1:word.lower="', u'|O'): 1.723413
# (u'word.lower=but', u'|O'): 1.7211
# (u'+1:word.lower=3', u'|I-ORG'): 1.666324
# (u'BOS', u'|B-ORG'): 1.656837
# (u'-1:word.lower=the', u'|B-MISC'): 1.64943
# (u'+1:word.lower=:', u'|O'): 1.637284
# (u'word.lower=on', u'|O'): 1.632112
# (u'+1:word.lower=1996-08-29', u'|B-LOC'): 1.625181
# (u'+1:word.lower=-', u'|O'): 1.616155
# (u'word.lower=to', u'|O'): 1.604811
# (u'word[-2:]=nt', u'|O'): 1.588112
# (u'word[-3:]=ber', u'|O'): 1.575203
# (u'+1:word.lower=1996-08-22', u'|B-LOC'): 1.566305
# (u'BOS', u'|O'): 1.566257
# (u'word[-3:]=But', u'|O'): 1.548485
# (u'+1:word.lower=1996-08-27', u'|B-LOC'): 1.544014
# (u'+1:word.lower=minister', u'|O'): 1.541217
# (u'word.lower=cup', u'|I-MISC'): 1.529219
# (u'word.lower=president', u'|O'): 1.498732
# (u'-1:word.lower=0', u'|B-ORG'): 1.484228
# (u'-1:word.lower=minister', u'|B-PER'): 1.481261
# (u'-1:word.lower=to', u'|B-LOC'): 1.479401
# (u'word[-3:]=DON', u'|B-LOC'): 1.479262
# (u'word[-2:]=ch', u'|B-MISC'): 1.47796
# (u'word[-3:]=ain', u'|B-LOC'): 1.468781
# (u'+1:word.lower=the', u'|O'): 1.456082
# (u'word[-3:]=ese', u'|B-MISC'): 1.454545
# (u'-1:word.lower=president', u'|B-PER'): 1.450205
# (u'+1:word.lower=1996-08-23', u'|B-LOC'): 1.44808
# (u'word[-2:]=ON', u'|B-LOC'): 1.423134
# (u'word[-3:]=ent', u'|O'): 1.420884
# (u'word.lower=pakistan', u'|B-LOC'): 1.415269
# (u'-1:word.lower=a', u'|B-MISC'): 1.411469
# (u'word.lower=german', u'|B-MISC'): 1.410809
# (u'word.lower=germany', u'|B-LOC'): 1.409955
# (u'+1:word.lower=1996-08-26', u'|B-LOC'): 1.402303
# (u'word[-3:]=ire', u'|B-ORG'): 1.388786
# (u'word.lower=britain', u'|B-LOC'): 1.386155
# (u'word.lower=tuesday', u'|O'): 1.378526
# (u'word.lower=open', u'|I-MISC'): 1.369283
# (u'+1:word.lower=0', u'|I-ORG'): 1.345408
# (u'-1:word.lower=,', u'|B-PER'): 1.345253
# (u'word.lower=we', u'|O'): 1.336426
# (u'word[-2:]=ny', u'|B-LOC'): 1.33271
# (u'word[-2:]=er', u'|O'): 1.322858
# (u'word[-3:]="', u'|O'): 1.31901
# (u'word[-2:]="', u'|O'): 1.31901
# (u'word.lower="', u'|O'): 1.31901
# (u'-1:word.lower=the', u'|B-ORG'): 1.317197
# (u'-1:word.lower=said', u'|B-PER'): 1.314414
# (u'word[-3:]=to', u'|O'): 1.311879
# (u'word[-3:]=In', u'|O'): 1.310094
# (u'word[-2:]=In', u'|O'): 1.310094
# (u'-1:word.lower=1', u'|B-ORG'): 1.309034
# (u'word[-3:]=tan', u'|B-LOC'): 1.298652
# (u'word[-2:]=in', u'|B-PER'): 1.297656
# (u'word.lower=results', u'|O'): 1.297461
# (u'word[-3:]=and', u'|B-LOC'): 1.296201
# (u'word.lower=monday', u'|O'): 1.29598
# (u'+1:word.lower=1', u'|I-ORG'): 1.28972
# (u'-1:word.lower=new', u'|I-LOC'): 1.274605
# (u'+1:word.lower=4', u'|B-ORG'): 1.263735
# (u'word[-3:]=We', u'|O'): 1.263171
# (u'word[-2:]=We', u'|O'): 1.263171
# (u'word[-2:]=er', u'|I-PER'): 1.253476
# (u'+1:word.lower=open', u'|B-MISC'): 1.249749
# (u'-1:word.lower=-', u'|B-PER'): 1.24466
# (u'word.lower=france', u'|B-LOC'): 1.238034
# (u'word[-2:]=se', u'|B-MISC'): 1.237957
# (u'word[-3:]=The', u'|O'): 1.231152
# (u'BOS', u'|B-LOC'): 1.227295
# (u'word[-2:]=ic', u'|B-MISC'): 1.227255
# (u'word[-3:]=Cup', u'|I-MISC'): 1.226382
# (u'+1:word.lower=of', u'|O'): 1.225591
# (u'word.lower=french', u'|B-MISC'): 1.218625
# (u'+1:word.lower=2', u'|I-ORG'): 1.214301
# (u'word[-2:]=up', u'|I-MISC'): 1.213521
# (u'+1:word.lower=cup', u'|B-MISC'): 1.199925
# (u'word.lower=friday', u'|O'): 1.197156
# (u'word.lower=u.s.', u'|B-LOC'): 1.192739
# (u'word[-3:]=.S.', u'|B-LOC'): 1.189286
# (u'word.lower=australia', u'|B-LOC'): 1.184549
# (u'word[-3:]=ing', u'|O'): 1.164355
# (u'-1:word.lower=on', u'|O'): 1.158222
# (u'word.lower=reuters', u'|B-ORG'): 1.152332
# (u'+1:word.lower=4', u'|I-ORG'): 1.140372
# (u'word[-3:]=ime', u'|O'): 1.139759
# (u'word[-3:]=ion', u'|I-ORG'): 1.130785
# (u'word.lower=china', u'|B-LOC'): 1.121404
# (u'+1:word.lower=1996-08-25', u'|B-LOC'): 1.11918
# (u'word.lower=new', u'|B-LOC'): 1.115031
# (u'+1:word.lower=first', u'|B-MISC'): 1.114459
# (u'word[-3:]=ust', u'|O'): 1.11006
# (u'word[-2:]=ly', u'|O'): 1.107344
# (u'word[-3:]=son', u'|I-PER'): 1.106982
# (u'-1:word.lower=beat', u'|B-PER'): 1.104252
# (u'word.lower=august', u'|O'): 1.104075
# (u'word[-2:]=na', u'|B-LOC'): 1.086626
# (u'word[-3:]=a', u'|O'): 1.086332
# (u'word[-2:]=a', u'|O'): 1.086332
# (u'word[-3:]=uly', u'|O'): 1.084599
# (u'-1:word.lower=v', u'|B-ORG'): 1.084081
# (u'word.lower=july', u'|O'): 1.075637
# (u'word[-3:]=ans', u'|B-MISC'): 1.058931
# (u'word.lower=clinton', u'|B-PER'): 1.057317
# (u'word[-2:]=ie', u'|B-PER'): 1.051562
# (u'word[-2:]=in', u'|B-LOC'): 1.048266
# (u'word[-2:]=ta', u'|B-LOC'): 1.043248
# (u'word[-2:]=st', u'|O'): 1.032288
# (u'word[-2:]=he', u'|O'): 1.030054
# (u'word.lower=sunday', u'|O'): 1.027781
# (u'-1:word.lower=3', u'|B-ORG'): 1.0254
# (u'-1:word.lower=told', u'|B-ORG'): 1.024854
# (u'word[-2:]=AN', u'|B-MISC'): 1.020526
# (u'word[-3:]=nch', u'|B-MISC'): 1.006162
# (u'-1:word.lower=2', u'|B-ORG'): 1.006069
# (u'word[-3:]=une', u'|O'): 1.001646
# (u'word[-3:]=ina', u'|B-LOC'): 0.998619
# (u'-1:word.istitle=True', u'|I-ORG'): 0.995818
# (u'word.lower=the', u'|O'): 0.991279
# (u'-1:word.lower=from', u'|B-LOC'): 0.990772
# (u'word[-2:]=ts', u'|O'): 0.982582
# (u'word.lower=dutch', u'|B-MISC'): 0.98218
# (u'word[-2:]=im', u'|B-PER'): 0.980286
# (u'-1:word.istitle=False', u'|O'): 0.978928
# (u'word[-2:]=ns', u'|B-MISC'): 0.976189
# (u'word.lower=kong', u'|I-LOC'): 0.971904
# (u'-1:word.lower=hong', u'|I-LOC'): 0.971654
# (u'word.lower=spain', u'|B-LOC'): 0.969347
# (u'word[-3:]=pen', u'|I-MISC'): 0.967089
# (u'-1:word.lower=united', u'|I-LOC'): 0.966534
# (u'word.istitle=True', u'|B-LOC'): 0.959445
# (u'word.lower=june', u'|O'): 0.9577
# (u'word.lower=they', u'|O'): 0.956983
# (u'word.lower=said', u'|O'): 0.954284
# (u'word[-3:]=At', u'|O'): 0.952669
# (u'word[-2:]=At', u'|O'): 0.952669
# (u'word[-3:]=aid', u'|O'): 0.949009
# (u'word[-3:]=ica', u'|I-LOC'): 0.946083
# (u'word.lower=italy', u'|B-LOC'): 0.944415
# (u'word[-3:]=hey', u'|O'): 0.94411
# (u'-1:word.lower=st', u'|I-ORG'): 0.942725
# (u'word.istitle=True', u'|B-MISC'): 0.942281
# (u'word.lower=iraq', u'|B-LOC'): 0.941412
# (u'word.lower=africa', u'|I-LOC'): 0.939233
# (u'word[-3:]=lic', u'|I-LOC'): 0.93755
# (u'word.lower=league', u'|I-MISC'): 0.936474
# (u'word.lower=september', u'|O'): 0.936048
# (u'word[-2:]=ca', u'|I-LOC'): 0.93416
# (u'word.lower=republic', u'|I-LOC'): 0.93321
# (u'word[-3:]=aly', u'|B-LOC'): 0.932272
# (u'word.lower=states', u'|I-LOC'): 0.930174
# (u"+1:word.lower='s", u'|B-PER'): 0.928922
# (u'EOS', u'|O'): 0.924882
# (u'+1:word.lower=1996-08-24', u'|B-LOC'): 0.923882
# (u'word[-3:]=tes', u'|I-LOC'): 0.922183
# (u'word.lower=japan', u'|B-LOC'): 0.918645
# (u'+1:word.lower=a', u'|O'): 0.916508
# (u'word[-3:]=pan', u'|B-LOC'): 0.914224
# (u'word.lower=english', u'|B-MISC'): 0.913281
# (u'+1:word.lower=kong', u'|B-LOC'): 0.912886
# (u'+1:word.lower=at', u'|B-ORG'): 0.908059
# (u'word[-3:]=raq', u'|B-LOC'): 0.90756
# (u'word.isupper=True', u'|B-ORG'): 0.904658
# (u'word.lower=hong', u'|B-LOC'): 0.903457
# (u'word[-3:]=any', u'|B-LOC'): 0.900384
# (u'+1:word.lower=division', u'|B-MISC'): 0.89589
# (u'-1:word.lower=b', u'|B-PER'): 0.895458
# (u'-1:word.lower=(', u'|B-LOC'): 0.884984
# (u'word[-3:]=of', u'|I-ORG'): 0.882796
# (u'word[-2:]=of', u'|I-ORG'): 0.881548
# (u'+1:word.lower=states', u'|B-LOC'): 0.873815
# (u'word[-2:]=ty', u'|I-ORG'): 0.872527
# (u'word[-2:]=en', u'|I-MISC'): 0.872411
# (u'-1:word.lower=world', u'|I-MISC'): 0.871215
# (u'word[-3:]=ere', u'|O'): 0.87112
# (u'+1:word.lower=on', u'|B-LOC'): 0.870016
# (u'-1:word.lower=czech', u'|I-LOC'): 0.868159
# (u'+1:word.lower=africa', u'|B-LOC'): 0.867732
# (u'word[-3:]=son', u'|B-PER'): 0.862542
# (u'word.lower=russia', u'|B-LOC'): 0.862341
# (u'word[-3:]=,', u'|O'): 0.860791
# (u'word[-2:]=,', u'|O'): 0.860791
# (u'word.lower=,', u'|O'): 0.860791
# (u'+1:word.lower=,', u'|I-PER'): 0.858535
# (u'word.lower=india', u'|B-LOC'): 0.857325
# (u'word[-2:]=ya', u'|B-LOC'): 0.856391
# (u'word[-2:]=S.', u'|B-LOC'): 0.854794
# (u'word[-2:]=aq', u'|B-LOC'): 0.846163
# (u'+1:word.lower=)', u'|B-LOC'): 0.83967
# (u'word.lower=american', u'|B-MISC'): 0.834506
# (u'word.lower=czech', u'|B-LOC'): 0.834492
# (u'word.lower=israel', u'|B-LOC'): 0.833566
# (u'word[-3:]=on', u'|O'): 0.833522
# (u'-1:word.lower="', u'|B-PER'): 0.829361
# (u'word.lower=saturday', u'|O'): 0.826783
# (u'word[-3:]=-', u'|O'): 0.825096
# (u'word[-2:]=-', u'|O'): 0.825096
# (u'word.lower=-', u'|O'): 0.825096
# (u'word[-2:]=nc', u'|I-ORG'): 0.821451
# (u'word[-2:]=AT', u'|O'): 0.816549
# (u'word[-3:]=Inc', u'|I-ORG'): 0.815866
# (u'word.lower=inc', u'|I-ORG'): 0.815866
# (u'word.lower=moscow', u'|B-LOC'): 0.812921
# (u"word.lower='s", u'|O'): 0.80924
# (u'word[-3:]=ech', u'|B-LOC'): 0.805324
# (u'word[-3:]=GMT', u'|B-MISC'): 0.803469
# (u'word.lower=gmt', u'|B-MISC'): 0.803381
# (u'-1:word.lower=prime', u'|O'): 0.803055
# (u'word.lower=sweden', u'|B-LOC'): 0.800296
# (u'word[-2:]=um', u'|B-LOC'): 0.797436
# (u'word[-2:]=rs', u'|O'): 0.797324
# (u'-1:word.lower=3.', u'|B-PER'): 0.796914
# (u'word[-2:]=MT', u'|B-MISC'): 0.796869
# (u'word.lower=prime', u'|O'): 0.796006
# (u'+1:word.lower=republic', u'|B-LOC'): 0.791817
# (u'-1:word.lower=2.', u'|B-PER'): 0.791636
# (u'-1:word.lower=1.', u'|B-PER'): 0.790214
# (u'word[-3:]=oom', u'|I-ORG'): 0.788937
# (u'word[-3:]=aqi', u'|B-MISC'): 0.788703
# (u'word[-2:]=qi', u'|B-MISC'): 0.788703
# (u'word.lower=iraqi', u'|B-MISC'): 0.788703
# (u'word.lower=russian', u'|B-MISC'): 0.787446
# (u'word.lower=york', u'|I-LOC'): 0.785251
# (u"+1:word.lower='s", u'|B-LOC'): 0.781361
# (u'word[-3:]=den', u'|B-LOC'): 0.779216
# (u'word.lower=newsroom', u'|I-ORG'): 0.778251
# (u'word.lower=israeli', u'|B-MISC'): 0.777631
# (u'word[-3:]=lts', u'|O'): 0.7768
# (u'+1:word.lower=,', u'|B-PER'): 0.775771
# (u'word[-2:]=ax', u'|B-ORG'): 0.774869
# (u'word.lower=and', u'|O'): 0.770471
# (u'word[-2:]=er', u'|B-PER'): 0.769771
# (u'word.lower=st', u'|B-ORG'): 0.769516
# (u'word[-3:]=his', u'|O'): 0.761555
# (u'-1:word.isupper=False', u'|I-ORG'): 0.76042
# (u'word[-3:]=hat', u'|O'): 0.759468
# (u'word[-3:]=eli', u'|B-MISC'): 0.758864
# (u'word[-2:]=li', u'|B-MISC'): 0.757441
# (u'word[-3:]=ium', u'|B-LOC'): 0.756757
# (u'word[-3:]=tch', u'|B-MISC'): 0.749464
# (u'word[-2:]=om', u'|I-ORG'): 0.748671
# (u'word.istitle=True', u'|B-PER'): 0.748451
# (u'word.lower=chicago', u'|B-LOC'): 0.747153
# (u'word[-3:]=ael', u'|B-LOC'): 0.74461
# (u'word[-2:]=ce', u'|O'): 0.738484
# (u'word[-2:]=re', u'|B-ORG'): 0.736667
# (u'word[-3:]=)', u'|O'): 0.730943
# (u'word[-2:]=)', u'|O'): 0.730943
# (u'word.lower=)', u'|O'): 0.730943
# (u'word.lower=belgium', u'|B-LOC'): 0.723979
# (u'word[-3:]=can', u'|B-MISC'): 0.721661
# (u'+1:word.lower=told', u'|B-PER'): 0.720897
# (u'word[-3:]=ord', u'|B-ORG'): 0.717757
# (u'-1:word.istitle=False', u'|I-ORG'): 0.717639
# (u'word[-3:]=AT', u'|O'): 0.716662
# (u'word[-3:]=nya', u'|B-LOC'): 0.716546
# (u'word.lower=australian', u'|B-MISC'): 0.716193
# (u'-1:word.lower=of', u'|I-ORG'): 0.712306
# (u'word.lower=lanka', u'|I-LOC'): 0.711671
# (u'word[-3:]=nce', u'|B-LOC'): 0.71067
# (u'word.lower=paris', u'|B-LOC'): 0.708566
# (u'+1:word.lower=york', u'|B-LOC'): 0.708275
# (u'word[-3:]=ong', u'|I-LOC'): 0.704034
# (u'-1:word.lower=sri', u'|I-LOC'): 0.703425
# (u'-1:word.lower=:', u'|B-ORG'): 0.70283
# (u'word[-3:]=.', u'|O'): 0.700373
# (u'word[-2:]=.', u'|O'): 0.700373
# (u'word.lower=.', u'|O'): 0.700373
# (u'word[-3:]=ary', u'|O'): 0.693687
# (u'-1:word.istitle=True', u'|I-MISC'): 0.693262
# (u'+1:word.lower=21', u'|B-ORG'): 0.692314
# (u'word[-2:]=nd', u'|B-LOC'): 0.689534
# (u'word.lower=york', u'|I-ORG'): 0.688621
# (u'word[-2:]=IA', u'|B-LOC'): 0.688151
# (u'+1:word.isupper=False', u'|B-ORG'): 0.686222
# (u'-1:word.lower=west', u'|I-LOC'): 0.682782
# (u'word[-3:]=est', u'|B-LOC'): 0.682019
# (u'+1:word.isupper=True', u'|B-MISC'): 0.681788
# (u'word.lower=division', u'|I-MISC'): 0.676901
# (u'-1:word.istitle=True', u'|I-LOC'): 0.675458
# (u'+1:word.lower=v', u'|B-ORG'): 0.672778
# (u'+1:word.lower=lanka', u'|B-LOC'): 0.672763
# (u'word[-2:]=ka', u'|I-LOC'): 0.667489
# (u'word.lower=corp', u'|I-ORG'): 0.666607
# (u'word[-3:]=orp', u'|I-ORG'): 0.664343
# (u'word.lower=party', u'|I-ORG'): 0.663916
# (u'+1:word.lower=that', u'|O'): 0.660867
# (u'word[-2:]=rp', u'|I-ORG'): 0.658216
# (u'word.lower=sri', u'|B-LOC'): 0.654679
# (u'word[-3:]=ton', u'|I-PER'): 0.654672
# (u'word[-2:]=al', u'|O'): 0.650184
# (u'word[-2:]=AN', u'|B-LOC'): 0.648413
# (u'word[-2:]=ol', u'|B-ORG'): 0.647342
# (u'word[-3:]=ers', u'|B-ORG'): 0.646396
# (u'word[-3:]=rty', u'|I-ORG'): 0.645759
# (u'word.lower=united', u'|B-LOC'): 0.644491
# (u'word[-2:]=TS', u'|O'): 0.643903
# (u'word[-2:]=ic', u'|I-LOC'): 0.641424
# (u'word[-3:]=ted', u'|B-LOC'): 0.641181
# (u'word[-3:]=gue', u'|I-MISC'): 0.640564
# (u'word[-2:]=is', u'|B-PER'): 0.638987
# (u'word.lower=west', u'|B-LOC'): 0.637825
# (u'+1:word.lower=,', u'|B-LOC'): 0.635415
# (u'word.isupper=True', u'|B-MISC'): 0.628994
# (u'word[-2:]=ue', u'|I-MISC'): 0.626803
# (u'word[-3:]=nka', u'|I-LOC'): 0.625485
# (u'-1:word.lower=san', u'|I-LOC'): 0.625077
# (u'word.lower=union', u'|I-ORG'): 0.623982
# (u'word.lower=an', u'|O'): 0.622901
# (u'word.lower=world', u'|B-MISC'): 0.621919
# (u'-1:word.lower=of', u'|B-LOC'): 0.621753
# (u'word.lower=that', u'|O'): 0.619168
# (u'+1:word.lower=it', u'|O'): 0.618231
# (u'word[-3:]=ton', u'|B-PER'): 0.61779
# (u'word.lower=standings', u'|O'): 0.616479
# (u'word.lower=washington', u'|B-LOC'): 0.615526
# (u'word.lower=with', u'|O'): 0.613761
# (u'word[-3:]=ong', u'|B-LOC'): 0.613522
# (u'-1:word.lower=south', u'|I-LOC'): 0.612713
# (u'word[-3:]=New', u'|B-LOC'): 0.612167
# (u'word.lower=olympic', u'|B-MISC'): 0.611087
# (u'word[-3:]=pic', u'|B-MISC'): 0.609842
# (u'+1:word.lower=was', u'|B-PER'): 0.607825
# (u'-1:word.isupper=True', u'|I-MISC'): 0.606716
# (u'word.lower=netherlands', u'|B-LOC'): 0.598888
# (u'+1:word.lower=are', u'|O'): 0.598879
# (u'word[-2:]=ne', u'|O'): 0.59405
# (u'word.lower=men', u'|O'): 0.593458
# (u'word.lower=first', u'|O'): 0.593127
# (u'word.lower=of', u'|I-ORG'): 0.592712
# (u'word[-3:]=ter', u'|O'): 0.591182
# (u'word[-2:]=ew', u'|B-LOC'): 0.589736
# (u'word.lower=amsterdam', u'|B-LOC'): 0.589037
# (u'BOS', u'|B-MISC'): 0.588503
# (u'-1:word.lower=the', u'|B-LOC'): 0.587321
# (u'word.lower=there', u'|O'): 0.584822
# (u'word.lower=women', u'|O'): 0.584068
# (u'word[-2:]=es', u'|I-LOC'): 0.581671
# (u'word[-2:]=SV', u'|B-ORG'): 0.575957
# (u'word[-3:]=Sri', u'|B-LOC'): 0.575513
# (u'word.lower=soccer', u'|O'): 0.573972
# (u'-1:word.istitle=False', u'|B-LOC'): 0.57307
# (u'word[-3:]=3', u'|O'): 0.570915
# (u'word[-2:]=3', u'|O'): 0.570915
# (u'word.lower=3', u'|O'): 0.570915
# (u'word.lower=british', u'|B-MISC'): 0.570798
# (u'word[-2:]=id', u'|O'): 0.570781
# (u'word.lower=italian', u'|B-MISC'): 0.569093
# (u'-1:word.lower=south', u'|I-MISC'): 0.566856
# (u'word[-3:]=ham', u'|B-ORG'): 0.566526
# (u'word[-3:]=can', u'|I-MISC'): 0.564452
# (u'word[-3:]=Men', u'|O'): 0.563682
# (u'-1:word.lower=but', u'|B-PER'): 0.563566
# (u'word[-3:]=ISH', u'|B-MISC'): 0.563061
# (u'-1:word.lower=last', u'|O'): 0.562268
# (u'word[-3:]=ion', u'|O'): 0.561977
# (u'-1:word.lower=6.', u'|B-PER'): 0.561363
# (u'word[-3:]=2', u'|O'): 0.56123
# (u'word[-2:]=2', u'|O'): 0.56123
# (u'word.lower=2', u'|O'): 0.56123
# (u'-1:word.lower=u.s.', u'|I-MISC'): 0.561131
# (u'word[-3:]=0', u'|O'): 0.560985
# (u'word[-2:]=0', u'|O'): 0.560985
# (u'word.lower=0', u'|O'): 0.560985
# (u'word.lower=brazil', u'|B-LOC'): 0.559729
# (u'word[-2:]=SH', u'|B-MISC'): 0.559365
# (u'+1:word.lower=newsroom', u'|B-LOC'): 0.557292
# (u'word.lower=city', u'|I-LOC'): 0.556958
# (u'+1:word.lower=union', u'|B-ORG'): 0.555021
# (u'+1:word.lower=)', u'|I-LOC'): 0.552779
# (u'word.lower=co', u'|I-ORG'): 0.549524
# (u'word[-2:]=TA', u'|B-ORG'): 0.547297
# (u'-1:word.lower=an', u'|B-MISC'): 0.547079
# (u'word.lower=this', u'|O'): 0.546702
# (u'word[-2:]=ex', u'|B-ORG'): 0.545964
# (u'word.lower=was', u'|O'): 0.544914
# (u'word[-3:]=ole', u'|B-PER'): 0.544332
# (u'word.lower=chicago', u'|B-ORG'): 0.542777
# (u'word[-3:]=sin', u'|B-PER'): 0.542038
# (u'word[-3:]=ate', u'|O'): 0.539482
# (u'word[-3:]=nds', u'|B-LOC'): 0.538089
# (u'word[-3:]=rld', u'|B-MISC'): 0.537939
# (u'word[-3:]=was', u'|O'): 0.537187
# (u'+1:word.lower=government', u'|B-MISC'): 0.536883
# (u'word[-3:]=May', u'|O'): 0.535262
# (u'word[-3:]=ign', u'|O'): 0.534248
# (u'word[-2:]=gn', u'|O'): 0.534248
# (u'word[-3:]=men', u'|O'): 0.534065
# (u'word.lower=arafat', u'|B-PER'): 0.533588
# (u'word[-3:]=St', u'|B-ORG'): 0.533508
# (u'word[-2:]=St', u'|B-ORG'): 0.533508
# (u'word[-3:]=fat', u'|B-PER'): 0.533444
# (u'word[-3:]=cow', u'|B-LOC'): 0.53308
# (u'-1:word.lower=4.', u'|B-PER'): 0.533022
# (u'word[-3:]=Co', u'|I-ORG'): 0.533005
# (u'word[-2:]=Co', u'|I-ORG'): 0.533005
# (u'word.lower=for', u'|O'): 0.531767
# (u'word[-3:]=ERN', u'|B-MISC'): 0.531735
# (u'word.lower=ajax', u'|B-ORG'): 0.531473
# (u'word.lower=foreign', u'|O'): 0.530354
# (u'+1:word.lower=inc', u'|I-ORG'): 0.530307
# (u'+1:word.lower=from', u'|O'): 0.528273
# (u'-1:word.lower=major', u'|I-MISC'): 0.528205
# (u'word[-2:]=RN', u'|B-MISC'): 0.528128
# (u'word.lower=may', u'|O'): 0.527555
# (u'word.lower=dole', u'|B-PER'): 0.527133
# (u'word.lower=after', u'|O'): 0.526745
# (u'+1:word.istitle=True', u'|B-PER'): 0.526438
# (u'word.lower=san', u'|B-LOC'): 0.523946
# (u'word[-2:]=IS', u'|B-LOC'): 0.522388
# (u'-1:word.isupper=True', u'|I-ORG'): 0.521953
# (u'-1:word.lower=m.', u'|I-PER'): 0.521926
# (u'-1:word.lower=mark', u'|I-PER'): 0.521741
# (u'word.lower=mark', u'|B-PER'): 0.521701
# (u'word[-2:]=ez', u'|I-PER'): 0.521588
# (u'-1:word.lower=5.', u'|B-PER'): 0.521399
# (u"-1:word.lower='s", u'|B-MISC'): 0.521049
# (u'word[-2:]=gs', u'|O'): 0.520102
# (u'-1:word.lower=de', u'|I-PER'): 0.517955
# (u'word[-2:]=at', u'|O'): 0.516669
# (u'word[-2:]=EC', u'|B-ORG'): 0.516499
# (u'word[-2:]=is', u'|I-PER'): 0.515473
# (u'word[-3:]=LTS', u'|O'): 0.515382
# (u'word[-2:]=co', u'|B-ORG'): 0.514756
# (u'word.lower=as', u'|O'): 0.514297
# (u'BOS', u'|B-PER'): 0.513529
# (u'word[-3:]=NEW', u'|B-LOC'): 0.513434
# (u'-1:word.lower=john', u'|I-PER'): 0.513353
# (u'word[-3:]=ang', u'|B-PER'): 0.513179
# (u'word[-2:]=EW', u'|B-LOC'): 0.512351
# (u'word[-3:]=zil', u'|B-LOC'): 0.512213
# (u'word[-3:]=ngs', u'|O'): 0.511011
# (u'-1:word.lower=c', u'|B-PER'): 0.508584
# (u'word.lower=police', u'|O'): 0.507057
# (u'word[-3:]=ana', u'|B-PER'): 0.506651
# (u'word.lower=bank', u'|I-LOC'): 0.504648
# (u'word.lower=u.n.', u'|B-ORG'): 0.503979
# (u'word[-3:]=ORK', u'|I-LOC'): 0.503672
# (u'word[-2:]=RK', u'|I-LOC'): 0.503553
# (u'word[-2:]=ri', u'|B-LOC'): 0.502238
# (u'word.lower=south', u'|B-LOC'): 0.502101
# (u'-1:word.lower=van', u'|I-PER'): 0.501991
# (u'+1:word.lower=he', u'|O'): 0.50164
# (u'word[-3:]=.N.', u'|B-ORG'): 0.500923
# (u'word.isupper=True', u'|B-LOC'): 0.49993
# (u'word[-2:]=ck', u'|B-PER'): 0.49968
# (u'word.lower=major', u'|B-MISC'): 0.499336
# (u'word.lower=two', u'|O'): 0.498864
# (u'-1:word.lower=former', u'|B-MISC'): 0.498488
# (u'+1:word.lower=york', u'|B-ORG'): 0.498142
# (u'word[-3:]=ohn', u'|B-PER'): 0.497362
# (u'word.lower=moslem', u'|B-MISC'): 0.496627
# (u'word[-3:]=ION', u'|I-MISC'): 0.496296
# (u'word[-3:]=uth', u'|B-LOC'): 0.494764
# (u'word[-2:]=rs', u'|B-ORG'): 0.49475
# (u'word[-3:]=ank', u'|I-LOC'): 0.494695
# (u'word[-2:]=ST', u'|O'): 0.493969
# (u'word.lower=attendance', u'|O'): 0.493415
# (u'word.lower=south', u'|B-MISC'): 0.492902
# (u'word[-2:]=wo', u'|O'): 0.492088
# (u'word[-3:]=IAN', u'|B-MISC'): 0.492014
# (u'word.lower=belgian', u'|B-MISC'): 0.491803
# (u'+1:word.lower=president', u'|B-MISC'): 0.491208
# (u'+1:word.lower=bank', u'|B-LOC'): 0.490972
# (u'word.lower=zealand', u'|I-LOC'): 0.489676
# (u'word[-3:]=ice', u'|O'): 0.489558
# (u'word[-2:]=va', u'|I-PER'): 0.488559
# (u'word[-3:]=RIS', u'|B-LOC'): 0.48836
# (u'word[-3:]=CER', u'|O'): 0.488358
# (u'word[-3:]=ert', u'|B-PER'): 0.488282
# (u'word[-2:]=rk', u'|B-PER'): 0.487199
# (u'word[-2:]=hn', u'|B-PER'): 0.486076
# (u'word[-3:]=1', u'|O'): 0.485764
# (u'word[-2:]=1', u'|O'): 0.485764
# (u'word.lower=1', u'|O'): 0.485764
# (u'word[-3:]=jax', u'|B-ORG'): 0.485601
# (u'-1:word.lower=san', u'|I-ORG'): 0.485599
# (u'word[-3:]=aul', u'|B-PER'): 0.485479
# (u'-1:word.lower=grand', u'|I-MISC'): 0.485002
# (u'+1:word.lower=u.s.', u'|O'): 0.484538
# (u'word[-2:]=nk', u'|I-LOC'): 0.483432
# (u'+1:word.lower=6', u'|B-ORG'): 0.481902
# (u'word[-2:]=GO', u'|B-LOC'): 0.480041
# (u'word.lower=yeltsin', u'|B-PER'): 0.478898
# (u'word[-3:]=M.', u'|B-PER'): 0.4788
# (u'word.lower=m.', u'|B-PER'): 0.4788
# (u'word[-2:]=M.', u'|B-PER'): 0.476623
# (u'word[-3:]=TON', u'|B-LOC'): 0.474728
# (u'word[-3:]=tic', u'|B-MISC'): 0.47161
# (u'word.lower=oakland', u'|B-ORG'): 0.470797
# (u'word.lower=ukraine', u'|B-LOC'): 0.470448
# (u'word[-3:]=oux', u'|B-PER'): 0.469288
# (u'word[-2:]=TO', u'|B-ORG'): 0.467945
# (u'word[-2:]=ow', u'|B-LOC'): 0.467944
# (u'-1:word.lower=michael', u'|I-PER'): 0.466608
# (u'+1:word.lower=newsroom', u'|B-ORG'): 0.466016
# (u'word[-2:]=AC', u'|B-ORG'): 0.465561
# (u'-1:word.lower=foreign', u'|O'): 0.464837
# (u'+1:word.lower=do', u'|O'): 0.46434
# (u'word.lower=brussels', u'|B-LOC'): 0.463374
# (u'word[-3:]=nia', u'|B-LOC'): 0.462536
# (u'word[-3:]=dan', u'|B-LOC'): 0.461306
# (u'-1:word.lower=first', u'|O'): 0.460931
# (u'word[-2:]=ON', u'|I-MISC'): 0.460786
# (u'+1:word.lower=city', u'|B-LOC'): 0.459698
# (u'word.lower=dutroux', u'|B-PER'): 0.45779
# (u'word[-3:]=ome', u'|O'): 0.45764
# (u'word[-3:]=try', u'|I-ORG'): 0.457573
# (u'-1:word.lower=4', u'|B-ORG'): 0.457118
# (u'word[-2:]=TA', u'|B-LOC'): 0.456741
# (u'word.lower=lebed', u'|B-PER'): 0.456647
# (u'+1:word.lower=5', u'|B-ORG'): 0.455598
# (u'word[-3:]=ice', u'|I-ORG'): 0.454082
# (u'+1:word.lower=zealand', u'|B-LOC'): 0.453456
# (u'word.lower=democratic', u'|B-MISC'): 0.453359
# (u'-1:word.lower=capital', u'|B-LOC'): 0.453178
# (u'word[-3:]=bed', u'|B-PER'): 0.452662
# (u'-1:word.lower=paul', u'|I-PER'): 0.451324
# (u'word[-2:]=te', u'|O'): 0.450994
# (u'word[-2:]=ry', u'|O'): 0.450636
# (u'+1:word.lower=had', u'|B-PER'): 0.450294
# (u'+1:word.lower=co', u'|I-ORG'): 0.449772
# (u'word.lower=michael', u'|B-PER'): 0.449516
# (u'+1:word.lower=c', u'|I-PER'): 0.449499
# (u'word[-2:]=AS', u'|B-ORG'): 0.448508
# (u'word[-2:]=ux', u'|B-PER'): 0.448396
# (u'EOS', u'|I-MISC'): 0.446992
# (u'word.lower=paul', u'|B-PER'): 0.446984
# (u'word[-2:]=AM', u'|B-LOC'): 0.446251
# (u'word[-3:]=ORK', u'|I-ORG'): 0.445332
# (u'word.lower=african', u'|I-MISC'): 0.445327
# (u'word[-2:]=RK', u'|I-ORG'): 0.445018
# (u'word.lower=de', u'|I-PER'): 0.443714
# (u'word[-3:]=ran', u'|B-LOC'): 0.443497
# (u'word.lower=david', u'|B-PER'): 0.442605
# (u'-1:word.lower=national', u'|I-MISC'): 0.442413
# (u'word.lower=japanese', u'|B-MISC'): 0.441844
# (u'word.lower=from', u'|O'): 0.441568
# (u'word[-3:]=(', u'|O'): 0.441534
# (u'word[-2:]=(', u'|O'): 0.441534
# (u'word.lower=(', u'|O'): 0.441534
# (u'word[-3:]=vid', u'|B-PER'): 0.441031
# (u'word[-3:]=lin', u'|B-LOC'): 0.440381
# (u'word[-3:]=On', u'|O'): 0.44035
# (u'-1:word.lower=david', u'|I-PER'): 0.440253
# (u'word[-3:]=DAM', u'|B-LOC'): 0.439975
# (u'word[-2:]=or', u'|O'): 0.439519
# (u'+1:word.lower=party', u'|I-ORG'): 0.439479
# (u'word[-3:]=ril', u'|O'): 0.439468
# (u'word.lower=bonn', u'|B-LOC'): 0.439385
# (u'word[-3:]=bia', u'|B-LOC'): 0.438582
# (u'word[-2:]=na', u'|B-PER'): 0.438036
# (u'word[-3:]=L', u'|O'): 0.437962
# (u'word[-2:]=L', u'|O'): 0.437962
# (u'word[-2:]=on', u'|B-ORG'): 0.43747
# (u'word.lower=aug', u'|O'): 0.435926
# (u'word[-3:]=lem', u'|B-MISC'): 0.435768
# (u'word.lower=commission', u'|I-ORG'): 0.435315
# (u'word.lower=john', u'|B-PER'): 0.435016
# (u'word[-2:]=DA', u'|B-ORG'): 0.434934
# (u'word.lower=bosnian', u'|B-MISC'): 0.432761
# (u'+1:word.lower=b', u'|I-PER'): 0.431501
# (u'word[-2:]=ki', u'|B-PER'): 0.43119
# (u'+1:word.lower=african', u'|B-MISC'): 0.428007
# (u'word.lower=european', u'|B-MISC'): 0.427817
# (u'word.lower=his', u'|O'): 0.427599
# (u'+1:word.lower=have', u'|O'): 0.427587
# (u'word[-3:]=AGO', u'|B-LOC'): 0.427292
# (u'word[-2:]=CH', u'|B-MISC'): 0.426021
# (u'word[-2:]=ve', u'|O'): 0.425936
# (u'+1:word.lower=police', u'|B-MISC'): 0.425537
# (u'word.lower=finland', u'|B-LOC'): 0.425222
# (u'word[-3:]=GUE', u'|I-MISC'): 0.425208
# (u'word.lower=jerusalem', u'|B-LOC'): 0.425206
# (u'+1:word.lower=i', u'|O'): 0.424104
# (u'word[-2:]=UE', u'|I-MISC'): 0.423549
# (u'word.lower=cincinnati', u'|B-ORG'): 0.423404
# (u'word.lower=chechnya', u'|B-LOC'): 0.423249
# (u'word[-3:]=uth', u'|B-MISC'): 0.423092
# (u'+1:word.lower=results', u'|O'): 0.422852
# (u'word.lower=canada', u'|B-LOC'): 0.422508
# (u'word.lower=l', u'|O'): 0.420921
# (u'word[-3:]=ell', u'|I-PER'): 0.420197
# (u'+1:word.istitle=True', u'|O'): 0.418893
# (u'word[-3:]=AND', u'|B-LOC'): 0.418839
# (u'word.lower=grand', u'|B-MISC'): 0.417618
# (u'word[-2:]=ra', u'|I-PER'): 0.417453
# (u'word.lower=ministry', u'|I-ORG'): 0.417119
# (u'word.lower=ahmed', u'|I-PER'): 0.414171
# (u'word.lower=by', u'|O'): 0.413829
# (u'-1:word.lower=between', u'|B-LOC'): 0.413826
# (u'word[-2:]=rn', u'|B-ORG'): 0.413736
# (u'word[-3:]=don', u'|B-LOC'): 0.411941
# (u'word[-3:]=ens', u'|B-ORG'): 0.41176
# (u'+1:word.lower=told', u'|I-PER'): 0.411528
# (u'word[-3:]=sex', u'|B-ORG'): 0.410865
# (u'-1:word.lower=champion', u'|B-PER'): 0.410636
# (u'word[-3:]=in', u'|O'): 0.409979
# (u'-1:word.lower=7.', u'|B-PER'): 0.408926
# (u'word[-2:]=nk', u'|B-ORG'): 0.408857
# (u'word[-3:]=ley', u'|I-PER'): 0.408083
# (u'word[-2:]=ra', u'|B-PER'): 0.407687
# (u'word.lower=western', u'|B-MISC'): 0.407568
# (u'word[-2:]=em', u'|B-MISC'): 0.406534
# (u'bias', u'|O'): 0.40628
# (u'word[-2:]=On', u'|O'): 0.40623
# (u'+1:word.lower=is', u'|B-PER'): 0.406101
# (u'word[-3:]=ton', u'|B-ORG'): 0.404257
# (u'word[-2:]=ER', u'|O'): 0.404178
# (u"word[-3:]='S", u'|O'): 0.403664
# (u"word[-2:]='S", u'|O'): 0.403664
# (u'word[-3:]=lly', u'|B-PER'): 0.403631
# (u'word[-3:]=ank', u'|B-ORG'): 0.40329
# (u'word[-3:]=rch', u'|O'): 0.402888
# (u'word.lower=march', u'|O'): 0.402718
# (u'+1:word.lower=ministry', u'|B-ORG'): 0.402449
# (u'+1:word.lower=and', u'|B-LOC'): 0.40196
# (u'word[-3:]=iss', u'|B-MISC'): 0.400861
# (u'word[-3:]=ral', u'|O'): 0.400032
# (u'word[-3:]=PSV', u'|B-ORG'): 0.3999
# (u'word.lower=psv', u'|B-ORG'): 0.3999
# (u'-1:word.istitle=False', u'|B-ORG'): 0.398473
# (u'word[-3:]=sia', u'|B-LOC'): 0.398376
# (u'word.lower=turkey', u'|B-LOC'): 0.39815
# (u'word[-3:]=PEN', u'|I-MISC'): 0.397191
# (u'word[-2:]=tt', u'|B-PER'): 0.39692
# (u'+1:word.istitle=True', u'|B-ORG'): 0.395697
# (u'-1:word.lower=,', u'|B-LOC'): 0.39538
# (u'word[-3:]=ada', u'|B-LOC'): 0.395007
# (u'word[-2:]=N.', u'|B-ORG'): 0.394533
# (u'word[-3:]=dam', u'|I-ORG'): 0.393683
# (u'+1:word.lower=news', u'|B-ORG'): 0.393648
# (u'word[-3:]=ool', u'|B-ORG'): 0.393272
# (u'word.lower=milwaukee', u'|B-ORG'): 0.392669
# (u'word[-3:]=urg', u'|I-ORG'): 0.392153
# (u'word[-3:]=Aug', u'|O'): 0.391835
# (u'+1:word.lower=has', u'|B-PER'): 0.39178
# (u'word[-2:]=EN', u'|I-MISC'): 0.391593
# (u'word[-3:]=med', u'|I-PER'): 0.390983
# (u'-1:word.lower=costa', u'|I-LOC'): 0.389694
# (u'word[-2:]=NN', u'|B-LOC'): 0.389646
# (u'+1:word.lower=b', u'|B-PER'): 0.387838
# (u'word.lower=seattle', u'|B-ORG'): 0.387728
# (u'word.lower=april', u'|O'): 0.386007
# (u'+1:word.lower=pct', u'|O'): 0.385618
# (u'word[-3:]=key', u'|B-LOC'): 0.385584
# (u'word[-2:]=ld', u'|B-MISC'): 0.3847
# (u'word.lower=texas', u'|B-ORG'): 0.384497
# (u'+1:word.lower=cup', u'|I-MISC'): 0.384346
# (u'word[-3:]=W', u'|O'): 0.384296
# (u'word[-2:]=W', u'|O'): 0.384296
# (u'word.lower=w', u'|O'): 0.384296
# (u'word[-2:]=go', u'|B-LOC'): 0.383159
# (u'word.lower=chinese', u'|B-MISC'): 0.382319
# (u'word[-3:]=tle', u'|B-ORG'): 0.382238
# (u'-1:word.lower=a.', u'|I-PER'): 0.381983
# (u'word[-3:]=ram', u'|I-PER'): 0.381948
# (u'word[-2:]=A.', u'|B-PER'): 0.381715
# (u'-1:word.lower=it', u'|O'): 0.381111
# (u'-1:word.lower=w', u'|O'): 0.37995
# (u'word[-3:]=ity', u'|I-ORG'): 0.379201
# (u'-1:word.lower=he', u'|O'): 0.378391
# (u'word[-3:]=ova', u'|I-PER'): 0.377787
# (u'word.lower=one', u'|O'): 0.37778
# (u'word[-3:]=ypt', u'|B-LOC'): 0.377333
# (u'word.lower=egypt', u'|B-LOC'): 0.377333
# (u'word.lower=turkish', u'|B-MISC'): 0.376814
# (u'word.lower=rica', u'|I-LOC'): 0.376575
# (u'word.lower=baghdad', u'|B-LOC'): 0.376242
# (u'word.lower=austria', u'|B-LOC'): 0.376044
# (u'word.lower=swiss', u'|B-MISC'): 0.375791
# (u'word.lower=wednesday', u'|O'): 0.375543
# (u'word.lower=mexico', u'|B-LOC'): 0.375493
# (u'word.lower=leading', u'|O'): 0.375257
# (u'+1:word.lower=prime', u'|B-MISC'): 0.374646
# (u'word[-2:]=ug', u'|O'): 0.374552
# (u'word[-3:]=PUK', u'|B-ORG'): 0.37432
# (u'word.lower=puk', u'|B-ORG'): 0.37432
# (u'word[-2:]=AL', u'|B-MISC'): 0.374128
# (u"+1:word.lower='m", u'|O'): 0.373862
# (u'word[-3:]=de', u'|I-PER'): 0.373822
# (u'word.lower=van', u'|I-PER'): 0.373574
# (u'-1:word.istitle=False', u'|B-MISC'): 0.37339
# (u'word[-3:]=ith', u'|O'): 0.373063
# (u'word.lower=philadelphia', u'|B-ORG'): 0.372242
# (u'word.lower=akram', u'|I-PER'): 0.37208
# (u'-1:word.lower=--', u'|B-LOC'): 0.372049
# (u'word[-3:]=SCE', u'|B-ORG'): 0.372009
# (u'word.lower=osce', u'|B-ORG'): 0.372009
# (u'word[-3:]=man', u'|I-PER'): 0.371227
# (u'word[-3:]=&', u'|I-ORG'): 0.370694
# (u'word[-2:]=&', u'|I-ORG'): 0.370694
# (u'word.lower=&', u'|I-ORG'): 0.370694
# (u'word.lower=republican', u'|B-MISC'): 0.370144
# (u'word[-3:]=wan', u'|B-LOC'): 0.370124
# (u'word[-2:]=el', u'|B-PER'): 0.369534
# (u'word[-2:]=el', u'|B-LOC'): 0.369526
# (u'word[-3:]=ear', u'|O'): 0.369225
# (u'word[-3:]=4', u'|O'): 0.369139
# (u'word[-2:]=4', u'|O'): 0.369139
# (u'word.lower=4', u'|O'): 0.369139
# (u'-1:word.lower=8.', u'|B-PER'): 0.368127
# (u'word[-2:]=ng', u'|I-LOC'): 0.368005
# (u'-1:word.lower=&', u'|I-ORG'): 0.367903
# (u'word[-2:]=ar', u'|B-PER'): 0.36681
# (u'word.lower=bosnia', u'|B-LOC'): 0.366733
# (u'word[-2:]=de', u'|I-PER'): 0.366724
# (u'word[-2:]=rd', u'|B-ORG'): 0.366709
# (u'word[-3:]=Ltd', u'|I-ORG'): 0.366452
# (u'word[-2:]=td', u'|I-ORG'): 0.36616
# (u'word.lower=ltd', u'|I-ORG'): 0.36616
# (u'word.lower=iran', u'|B-LOC'): 0.366041
# (u'+1:word.lower=on', u'|I-LOC'): 0.365697
# (u'word.lower=polish', u'|B-MISC'): 0.365139
# (u'+1:word.isupper=True', u'|O'): 0.363818
# (u'+1:word.lower=ahmed', u'|B-PER'): 0.363438
# (u'word.lower=last', u'|O'): 0.362726
# (u'+1:word.lower=corp', u'|B-ORG'): 0.362458
# (u'+1:word.lower=they', u'|O'): 0.361206
# (u'word.lower=if', u'|O'): 0.360503
# (u'word.lower=costa', u'|B-LOC'): 0.358476
# (u'word[-3:]=A.', u'|B-PER'): 0.358073
# (u'word.lower=a.', u'|B-PER'): 0.358073
# (u'word[-2:]=ND', u'|B-LOC'): 0.357798
# (u'-1:word.lower=vs.', u'|B-PER'): 0.356974
# (u'word[-2:]=OW', u'|B-LOC'): 0.356861
# (u'word.lower=canadian', u'|B-MISC'): 0.356791
# (u'+1:word.lower=rica', u'|B-LOC'): 0.356625
# (u'word.lower=taiwan', u'|B-LOC'): 0.356092
# (u'word.lower=detroit', u'|B-ORG'): 0.356086
# (u'word.lower=cleveland', u'|B-ORG'): 0.356059
# (u'word[-3:]=TON', u'|B-ORG'): 0.354774
# (u'+1:word.lower=1996-08-28', u'|I-LOC'): 0.354722
# (u'word[-2:]=ey', u'|I-PER'): 0.354631
# (u'+1:word.lower=22', u'|B-ORG'): 0.35386
# (u'word.lower=beijing', u'|B-LOC'): 0.3527
# (u'word[-3:]=EU', u'|B-ORG'): 0.352312
# (u'word.lower=eu', u'|B-ORG'): 0.352312
# (u'word[-2:]=on', u'|I-PER'): 0.352167
# (u'word[-2:]=EU', u'|B-ORG'): 0.352086
# (u'word[-2:]=DP', u'|B-ORG'): 0.351111
# (u'word[-3:]=ard', u'|B-PER'): 0.350152
# (u'word[-2:]=am', u'|B-ORG'): 0.34939
# (u'word.lower=sudanese', u'|B-MISC'): 0.349135
# (u'+1:word.lower=think', u'|O'): 0.349099
# (u'word[-2:]=rg', u'|I-ORG'): 0.348376
# (u'word[-2:]=UK', u'|B-ORG'): 0.348194
# (u'word.lower=colombo', u'|B-LOC'): 0.347935
# (u'word[-2:]=am', u'|B-PER'): 0.347371
# (u'word.lower=baltimore', u'|B-ORG'): 0.347351
# (u'+1:word.lower=ltd', u'|I-ORG'): 0.345984
# (u'word[-3:]=eld', u'|B-ORG'): 0.345319
# (u'word.lower=romania', u'|B-LOC'): 0.345069
# (u'+1:word.lower=l', u'|O'): 0.344983
# (u'word[-3:]=ine', u'|B-LOC'): 0.344973
# (u'word.lower=is', u'|O'): 0.344726
# (u'word[-2:]=ge', u'|I-ORG'): 0.344723
# (u'word[-2:]=--', u'|O'): 0.344306
# (u'-1:word.lower=against', u'|B-LOC'): 0.343908
# (u'word[-2:]=an', u'|I-MISC'): 0.343665
# (u'word[-3:]=dad', u'|B-LOC'): 0.343376
# (u'-1:word.isupper=False', u'|I-MISC'): 0.343312
# (u'word[-3:]=ner', u'|I-PER'): 0.343108
# (u'-1:word.lower=european', u'|I-ORG'): 0.342405
# (u'-1:word.lower=central', u'|I-MISC'): 0.341919
# (u'word.lower=wasim', u'|B-PER'): 0.34133
# (u'word.lower=october', u'|O'): 0.340919
# (u'word[-3:]=yed', u'|O'): 0.340889
# (u'word.lower=europe', u'|B-LOC'): 0.340775
# (u'+1:word.lower=louis', u'|B-ORG'): 0.340396
# (u'word[-2:]=ll', u'|I-PER'): 0.339753
# (u'+1:word.istitle=True', u'|B-MISC'): 0.337616
# (u'word.lower=exchange', u'|I-ORG'): 0.337488
# (u'word.lower=when', u'|O'): 0.336504
# (u'+1:word.istitle=False', u'|B-PER'): 0.336109
# (u'-1:word.lower=results', u'|O'): 0.336076
# (u'word[-2:]=ad', u'|B-LOC'): 0.335654
# (u'word.lower=grozny', u'|B-LOC'): 0.335379
# (u'word[-3:]=Two', u'|O'): 0.335136
# (u'word.lower=no', u'|O'): 0.335049
# (u'word[-3:]=sta', u'|B-LOC'): 0.334917
# (u'word.lower=poland', u'|B-LOC'): 0.334442
# (u'word.lower=california', u'|B-ORG'): 0.333769
# (u'word.lower=nato', u'|B-ORG'): 0.333267
# (u'word[-2:]=la', u'|B-ORG'): 0.333253
# (u'word[-3:]=lia', u'|B-LOC'): 0.332682
# (u'word[-3:]=by', u'|O'): 0.332237
# (u'word.lower=korean', u'|I-MISC'): 0.332225
# (u'+1:word.lower=after', u'|O'): 0.331722
# (u'word[-3:]=han', u'|I-PER'): 0.331102
# (u'word[-2:]=st', u'|I-LOC'): 0.330772
# (u'+1:word.lower=akram', u'|B-PER'): 0.330542
# (u'word[-3:]=ATO', u'|B-ORG'): 0.330532
# (u'word[-2:]=ct', u'|O'): 0.329847
# (u'word[-3:]=ris', u'|B-PER'): 0.329678
# (u'word[-3:]=rus', u'|B-LOC'): 0.328653
# (u'word[-3:]=led', u'|B-MISC'): 0.328184
# (u'word[-2:]=CE', u'|B-ORG'): 0.327592
# (u'word[-3:]=ONN', u'|B-LOC'): 0.326742
# (u'word[-3:]=fax', u'|B-ORG'): 0.325871
# (u'-1:word.lower=northern', u'|B-LOC'): 0.325866
# (u'word[-2:]=di', u'|B-LOC'): 0.325317
# (u'-1:word.lower=division', u'|O'): 0.324933
# (u'word.lower=total', u'|O'): 0.324366
# (u'word[-3:]=nge', u'|I-ORG'): 0.324286
# (u'word[-3:]=sim', u'|B-PER'): 0.324042
# (u'word[-2:]=pt', u'|B-LOC'): 0.323985
# (u'word[-3:]=tin', u'|B-PER'): 0.323676
# (u'word[-3:]=C$', u'|B-MISC'): 0.323361
# (u'word[-2:]=C$', u'|B-MISC'): 0.323361
# (u'word.lower=c$', u'|B-MISC'): 0.323361
# (u'+1:word.lower=party', u'|B-ORG'): 0.323098
# (u'word.lower=montreal', u'|B-ORG'): 0.323036
# (u'word[-3:]=is', u'|O'): 0.322772
# (u'word[-3:]=RST', u'|O'): 0.322268
# (u'word[-3:]=ney', u'|B-ORG'): 0.321536
# (u'word[-3:]=ark', u'|B-PER'): 0.321494
# (u'word.lower=toronto', u'|B-ORG'): 0.321324
# (u'+1:word.lower=korean', u'|B-MISC'): 0.320919
# (u'+1:word.lower=peace', u'|B-MISC'): 0.320829
# (u'word.lower=played', u'|O'): 0.319719
# (u'word[-2:]=do', u'|B-PER'): 0.319612
# (u'word.lower=minnesota', u'|B-ORG'): 0.319528
# (u'-1:word.lower=/', u'|O'): 0.319461
# (u'word[-3:]=zny', u'|B-LOC'): 0.319211
# (u'word[-3:]=ope', u'|B-LOC'): 0.319128
# (u'word[-2:]=an', u'|B-LOC'): 0.318498
# (u'word[-3:]=rry', u'|B-PER'): 0.318037
# (u'word[-3:]=CUP', u'|I-MISC'): 0.317943
# (u'word[-3:]=een', u'|B-ORG'): 0.317853
# (u'word[-3:]=ast', u'|I-LOC'): 0.317565
# (u'word[-2:]=ng', u'|O'): 0.317227
# (u'+1:word.lower=1996-08-26', u'|I-LOC'): 0.317172
# (u'word[-3:]=an', u'|O'): 0.317156
# (u'word.lower=second', u'|O'): 0.316851
# (u'word[-2:]=ha', u'|B-ORG'): 0.316358
# (u'-1:word.lower=los', u'|I-ORG'): 0.315557
# (u'word.lower=boston', u'|B-ORG'): 0.315509
# (u'word[-2:]=UP', u'|I-MISC'): 0.315367
# (u'+1:word.lower=foreign', u'|B-MISC'): 0.315306
# (u'word[-3:]=lle', u'|B-ORG'): 0.315191
# (u'word.lower=pittsburgh', u'|B-ORG'): 0.315125
# (u'word[-3:]=TAN', u'|B-LOC'): 0.314893
# (u'+1:word.lower=commission', u'|I-ORG'): 0.314283
# (u'word.lower=thai', u'|B-MISC'): 0.313632
# (u'+1:word.lower=exchange', u'|I-ORG'): 0.313295
# (u'+1:word.lower=not', u'|O'): 0.313118
# (u'word[-2:]=hu', u'|B-PER'): 0.312717
# (u'+1:word.lower=an', u'|O'): 0.312706
# (u'word[-3:]=ial', u'|O'): 0.312515
# (u'word.lower=result', u'|O'): 0.311437
# (u'+1:word.lower=his', u'|O'): 0.311157
# (u'word.lower=florida', u'|B-ORG'): 0.310826
# (u'+1:word.lower=and', u'|I-PER'): 0.310777
# (u'word.lower=croft', u'|B-PER'): 0.310187
# (u'word[-3:]=out', u'|O'): 0.30994
# (u'word[-3:]=van', u'|I-PER'): 0.309637
# (u'word.lower=v', u'|O'): 0.308305
# (u'word[-3:]=If', u'|O'): 0.306436
# (u'word[-2:]=If', u'|O'): 0.306436
# (u'+1:word.lower=van', u'|B-PER'): 0.306052
# (u'word[-3:]=sed', u'|B-MISC'): 0.305752
# (u'word[-2:]=ea', u'|I-LOC'): 0.30564
# (u'word[-3:]=gen', u'|B-ORG'): 0.304996
# (u'+1:word.lower=we', u'|O'): 0.30465
# (u'word[-3:]=ago', u'|B-LOC'): 0.304423
# (u'word[-3:]=has', u'|O'): 0.304184
# (u'word[-2:]=ir', u'|B-PER'): 0.303776
# (u'word[-3:]=An', u'|O'): 0.303771
# (u'word[-2:]=An', u'|O'): 0.303771
# (u'word[-2:]=da', u'|B-LOC'): 0.303745
# (u'+1:word.lower=de', u'|B-PER'): 0.303528
# (u'word[-2:]=al', u'|I-LOC'): 0.303467
# (u'word[-3:]=kia', u'|B-LOC'): 0.303459
# (u'word.lower=chechen', u'|B-MISC'): 0.303141
# (u'word[-3:]=als', u'|O'): 0.30277
# (u'+1:word.lower=21', u'|I-ORG'): 0.302325
# (u'word[-2:]=rk', u'|I-LOC'): 0.302251
# (u'word.lower=brazilian', u'|B-MISC'): 0.301785
# (u'-1:word.lower=by', u'|B-MISC'): 0.301216
# (u'word[-2:]=el', u'|I-PER'): 0.301038
# (u'word[-2:]=ot', u'|O'): 0.300675
# (u'word[-2:]=le', u'|B-ORG'): 0.299576
# (u'word.lower=series', u'|I-MISC'): 0.299187
# (u'-1:word.lower=wasim', u'|I-PER'): 0.299165
# (u'word.lower=has', u'|O'): 0.298738
# (u'word.lower=san', u'|B-ORG'): 0.298566
# (u'word.lower=berlin', u'|B-LOC'): 0.297813
# (u'word.lower=louis', u'|I-ORG'): 0.297539
# (u'word[-2:]=RE', u'|B-LOC'): 0.297175
# (u'word.lower=argentina', u'|B-LOC'): 0.296354
# (u'word[-3:]=gan', u'|B-ORG'): 0.296019
# (u'word.lower=diego', u'|I-ORG'): 0.295934
# (u'-1:word.lower=million', u'|B-MISC'): 0.295439
# (u'+1:word.lower=capital', u'|B-MISC'): 0.294984
# (u'word.lower=nigeria', u'|B-LOC'): 0.294786
# (u'word[-3:]=ity', u'|I-LOC'): 0.294176
# (u'word.lower=honda', u'|B-ORG'): 0.293596
# (u'word[-2:]=RE', u'|B-ORG'): 0.293575
# (u'word[-3:]=--', u'|O'): 0.293552
# (u'word.lower=--', u'|O'): 0.293552
# (u'word.lower=colorado', u'|B-ORG'): 0.293335
# (u'word.lower=palestinians', u'|B-MISC'): 0.292748
# (u'word.lower=angeles', u'|I-LOC'): 0.292737
# (u'word[-3:]=uld', u'|O'): 0.292593
# (u'-1:word.lower=los', u'|I-LOC'): 0.29244
# (u'word[-3:]=SAN', u'|B-LOC'): 0.292347
# (u'word.lower=slovakia', u'|B-LOC'): 0.292333
# (u'word.lower=net', u'|O'): 0.292306
# (u'word[-2:]=rt', u'|B-PER'): 0.292164
# (u'word.lower=zimbabwe', u'|B-LOC'): 0.292079
# (u'word[-3:]=A$', u'|B-MISC'): 0.292076
# (u'word[-2:]=A$', u'|B-MISC'): 0.292076
# (u'word.lower=a$', u'|B-MISC'): 0.292076
# (u'word.lower=jordan', u'|B-LOC'): 0.291986
# (u'-1:word.lower=9.', u'|B-PER'): 0.291783
# (u'word.lower=tokyo', u'|B-LOC'): 0.291224
# (u'word[-3:]=hai', u'|B-MISC'): 0.290298
# (u'-1:word.lower=bill', u'|I-PER'): 0.29029
# (u'word.lower=bill', u'|B-PER'): 0.290257
# (u'-1:word.lower=5', u'|B-ORG'): 0.290032
# (u'word[-3:]=hen', u'|B-MISC'): 0.289796
# (u'+1:word.lower=1996', u'|O'): 0.288914
# (u'word[-3:]=ght', u'|O'): 0.288247
# (u'word.lower=ireland', u'|B-LOC'): 0.287932
# (u'+1:word.lower=were', u'|O'): 0.28757
# (u'-1:word.lower=sydney', u'|I-ORG'): 0.287476
# (u'-1:word.lower=near', u'|B-LOC'): 0.287396
# (u'+1:word.lower=troops', u'|B-MISC'): 0.28724
# (u'word.lower=serb', u'|B-MISC'): 0.287019
# (u'word[-3:]=erb', u'|B-MISC'): 0.286737
# (u'word[-3:]=ser', u'|B-PER'): 0.286623
# (u'+1:word.lower=7', u'|I-ORG'): 0.286239
# (u'-1:word.lower=peter', u'|I-PER'): 0.286209
# (u'word.lower=central', u'|B-MISC'): 0.286181
# (u'word.lower=beat', u'|O'): 0.286174
# (u'word[-2:]=ow', u'|I-ORG'): 0.285882
# (u'word[-2:]=rb', u'|B-MISC'): 0.285474
# (u'+1:word.istitle=False', u'|B-ORG'): 0.285277
# (u'word[-2:]=ev', u'|B-PER'): 0.284756
# (u'word[-3:]=ott', u'|B-PER'): 0.284751
# (u'word[-3:]=mas', u'|B-PER'): 0.284518
# (u'+1:word.lower=,', u'|I-LOC'): 0.284296
# (u'+1:word.lower=airport', u'|B-LOC'): 0.283882
# (u'-1:word.lower=thomas', u'|I-PER'): 0.283511
# (u'word.lower=not', u'|O'): 0.283194
# (u'word.lower=had', u'|O'): 0.282713
# (u'word.lower=year', u'|O'): 0.282518
# (u'word.lower=iranian', u'|B-MISC'): 0.282453
# (u'word.lower=kenya', u'|B-LOC'): 0.28237
# (u'-1:word.lower=eastern', u'|I-MISC'): 0.28229
# (u'word.lower=hungary', u'|B-LOC'): 0.281521
# (u'word.lower=angeles', u'|I-ORG'): 0.281511
# (u'word[-2:]=aq', u'|B-PER'): 0.281251
# (u'word.lower=francisco', u'|I-ORG'): 0.281091
# (u'+1:word.lower=rebels', u'|B-MISC'): 0.280915
# (u'word[-3:]=nis', u'|I-PER'): 0.280562
# (u'-1:word.lower=england', u'|O'): 0.279697
# (u'word[-3:]=eve', u'|B-PER'): 0.279513
# (u'+1:word.lower=index', u'|B-MISC'): 0.279467
# (u'word[-2:]=ed', u'|B-MISC'): 0.279258
# (u'word.lower=pct', u'|O'): 0.279173
# (u'word.lower=some', u'|O'): 0.278714
# (u'word.lower=association', u'|I-ORG'): 0.278689
# (u'-1:word.lower=g.', u'|I-PER'): 0.2786
# (u'word[-2:]=id', u'|B-PER'): 0.278492
# (u'-1:word.lower=--', u'|B-ORG'): 0.27817
# (u'word[-2:]=SE', u'|B-MISC'): 0.277703
# (u'word[-2:]=ss', u'|B-MISC'): 0.277357
# (u'-1:word.lower=western', u'|I-MISC'): 0.276725
# (u'word.lower=united', u'|I-ORG'): 0.276675
# (u'-1:word.isupper=False', u'|I-LOC'): 0.276627
# (u'word[-3:]=COW', u'|B-LOC'): 0.27659
# (u'word[-2:]=ke', u'|B-ORG'): 0.276127
# (u'word[-3:]=ork', u'|I-LOC'): 0.276017
# (u'word[-2:]=ra', u'|B-ORG'): 0.275832
# (u'+1:word.lower=not', u'|I-PER'): 0.275784
# (u'word[-3:]=urg', u'|B-ORG'): 0.275149
# (u'-1:word.lower=security', u'|I-ORG'): 0.274675
# (u'word[-3:]=ati', u'|B-ORG'): 0.274657
# (u'+1:word.lower=premier', u'|B-MISC'): 0.274309
# (u'+1:word.isupper=False', u'|B-LOC'): 0.274106
# (u'-1:word.lower=spokesman', u'|B-PER'): 0.272942
# (u'word.lower=peter', u'|B-PER'): 0.272634
# (u'word.lower=cup', u'|B-MISC'): 0.272135
# (u'-1:word.lower=robert', u'|I-PER'): 0.271026
# (u'word[-3:]=bia', u'|I-LOC'): 0.270663
# (u'word[-3:]=Cup', u'|B-MISC'): 0.270536
# (u'word[-2:]=sk', u'|I-ORG'): 0.270343
# (u'+1:word.lower=united', u'|B-ORG'): 0.270073
# (u'-1:word.lower=i', u'|O'): 0.269685
# (u'word[-3:]=ons', u'|O'): 0.269608
# (u'word[-2:]=rg', u'|B-ORG'): 0.269393
# (u'word.lower=she', u'|O'): 0.269322
# (u'word[-2:]=S.', u'|B-MISC'): 0.268751
# (u'word.lower=houston', u'|B-ORG'): 0.268749
# (u'word[-3:]=as', u'|O'): 0.268617
# (u'word.lower=interfax', u'|B-ORG'): 0.267575
# (u'word[-3:]=ler', u'|B-PER'): 0.267201
# (u'word.lower=atlanta', u'|B-LOC'): 0.26696
# (u'+1:word.lower=champion', u'|B-MISC'): 0.266903
# (u'word[-3:]=ave', u'|O'): 0.266686
# (u'word[-2:]=ft', u'|B-PER'): 0.266532
# (u'word[-3:]=RAL', u'|B-MISC'): 0.265995
# (u'word[-2:]=AY', u'|O'): 0.265986
# (u'+1:word.lower=diego', u'|B-ORG'): 0.265896
# (u'word.lower=prix', u'|I-MISC'): 0.26564
# (u'word[-2:]=li', u'|I-PER'): 0.265434
# (u'+1:word.lower=31', u'|O'): 0.265252
# (u'word[-3:]=had', u'|O'): 0.265017
# (u'word[-3:]=ist', u'|B-MISC'): 0.264497
# (u'word.lower=mullally', u'|B-PER'): 0.264193
# (u'word.lower=slovak', u'|B-MISC'): 0.264134
# (u'word[-2:]=gh', u'|B-ORG'): 0.263894
# (u'word[-2:]=pe', u'|B-LOC'): 0.263807
# (u'word[-3:]=oft', u'|B-PER'): 0.263294
# (u'word.istitle=True', u'|B-ORG'): 0.262665
# (u'word[-3:]=ded', u'|O'): 0.26257
# (u'word[-2:]=at', u'|B-PER'): 0.262556
# (u'word.lower=johannesburg', u'|B-LOC'): 0.262423
# (u'+1:word.lower=tennis', u'|I-MISC'): 0.262373
# (u'word[-2:]=na', u'|B-ORG'): 0.262236
# (u'word[-3:]=val', u'|I-LOC'): 0.262124
# (u'-1:word.lower=of', u'|B-MISC'): 0.262068
# (u'word[-3:]=ive', u'|O'): 0.261818
# (u'word.lower=wimbledon', u'|B-MISC'): 0.261774
# (u'word.lower=eastern', u'|B-MISC'): 0.261626
# (u'word[-3:]=eri', u'|B-PER'): 0.261499
# (u'word[-2:]=ai', u'|B-MISC'): 0.261412
# (u'word.lower=east', u'|I-LOC'): 0.261252
# (u'-1:word.lower=east', u'|I-LOC'): 0.261149
# (u'word[-2:]=sa', u'|I-PER'): 0.261055
# (u'word[-2:]=rs', u'|I-ORG'): 0.261005
# (u'word[-2:]=BO', u'|B-LOC'): 0.26076
# (u'-1:word.lower=fc', u'|I-ORG'): 0.260564
# (u'+1:word.lower=year', u'|O'): 0.260489
# (u'+1:word.lower=two', u'|O'): 0.260281
# (u'word[-2:]=bs', u'|B-MISC'): 0.260143
# (u'word[-2:]=ul', u'|B-PER'): 0.260135
# (u'word.lower=amman', u'|B-LOC'): 0.260111
# (u'+1:word.lower=reported', u'|I-ORG'): 0.259957
# (u'word[-3:]=No', u'|O'): 0.259899
# (u'word[-2:]=No', u'|O'): 0.259899
# (u'+1:word.lower=through', u'|I-PER'): 0.259888
# (u'word[-3:]=G.', u'|B-PER'): 0.259805
# (u'word.lower=g.', u'|B-PER'): 0.259805
# (u'word[-2:]=ed', u'|O'): 0.259439
# (u'word.lower=scotland', u'|B-LOC'): 0.259305
# (u'+1:word.lower=30', u'|O'): 0.258757
# (u'word[-3:]=ELS', u'|B-LOC'): 0.258015
# (u'word[-3:]=ahu', u'|B-PER'): 0.25774
# (u'word.lower=kdp', u'|B-ORG'): 0.257424
# (u'word.lower=c', u'|O'): 0.25731
# (u'word[-2:]=BC', u'|B-ORG'): 0.256969
# (u'word[-2:]=ti', u'|B-PER'): 0.256901
# (u'word.lower=thomas', u'|B-PER'): 0.25649
# (u'word.lower=atlanta', u'|B-ORG'): 0.25593
# (u'word[-3:]=rea', u'|I-LOC'): 0.255803
# (u'word.lower=halftime', u'|O'): 0.255705
# (u'word[-2:]=dy', u'|B-PER'): 0.255547
# (u'word.lower=argentine', u'|B-MISC'): 0.255006
# (u'word[-2:]=ov', u'|I-PER'): 0.254835
# (u'word[-3:]=KDP', u'|B-ORG'): 0.254332
# (u'-1:word.lower=new', u'|I-ORG'): 0.253818
# (u'word[-2:]=CO', u'|I-ORG'): 0.25378
# (u'word[-2:]=CT', u'|O'): 0.253563
# (u'word[-3:]=ept', u'|O'): 0.253283
# (u'word[-2:]=OR', u'|B-MISC'): 0.253089
# (u'word[-2:]=IA', u'|B-ORG'): 0.25288
# (u'word[-3:]=jor', u'|B-MISC'): 0.252606
# (u'word.lower=stansted', u'|B-LOC'): 0.252497
# (u'word[-3:]=bin', u'|B-PER'): 0.252383
# (u'word[-3:]=ned', u'|O'): 0.25237
# (u'word.lower=former', u'|O'): 0.252291
# (u"+1:word.lower='", u'|I-MISC'): 0.252281
# (u'+1:word.lower=to', u'|O'): 0.252053
# (u'word[-2:]=ty', u'|I-LOC'): 0.252038
# (u'word[-3:]=AGO', u'|B-ORG'): 0.251722
# (u'word[-2:]=ti', u'|B-ORG'): 0.251683
# (u'word[-3:]=nts', u'|O'): 0.25167
# (u'word[-2:]=TI', u'|B-ORG'): 0.25155
# (u'word[-2:]=G.', u'|B-PER'): 0.251443
# (u'+1:word.lower=when', u'|O'): 0.251251
# (u'word[-2:]=AD', u'|B-LOC'): 0.250759
# (u'-1:word.lower=le', u'|I-ORG'): 0.250725
# (u'-1:word.lower=southern', u'|B-LOC'): 0.250714
# (u'word[-3:]=One', u'|O'): 0.250385
# (u'word.lower=le', u'|B-ORG'): 0.250269
# (u'word[-3:]=War', u'|I-MISC'): 0.250242
# (u'-1:word.lower=d.', u'|I-PER'): 0.250009
# (u'word.lower=switzerland', u'|B-LOC'): 0.249909
# (u'word[-3:]=at', u'|O'): 0.249836
# (u'-1:word.lower=manchester', u'|I-ORG'): 0.249836
# (u'+1:word.lower=new', u'|O'): 0.249833
# (u'word[-3:]=PCT', u'|O'): 0.249825
# (u'word.lower=colorado', u'|B-LOC'): 0.249777
# (u'word.lower=marseille', u'|B-ORG'): 0.249612
# (u'+1:word.lower=corp', u'|I-ORG'): 0.249437
# (u'word.lower=european', u'|B-ORG'): 0.249103
# (u'word[-2:]=th', u'|B-LOC'): 0.249083
# (u'word[-3:]=qar', u'|B-PER'): 0.249035
# (u'word.lower=waqar', u'|B-PER'): 0.249035
# (u'word[-3:]=ITY', u'|I-LOC'): 0.248552
# (u'-1:word.isupper=True', u'|O'): 0.248457
# (u'word[-3:]=Net', u'|O'): 0.248364
# (u'word.lower=war', u'|I-MISC'): 0.248343
# (u'word[-2:]=OS', u'|B-ORG'): 0.248098
# (u'+1:word.lower=63', u'|B-ORG'): 0.247978
# (u'word.lower=oval', u'|I-LOC'): 0.247873
# (u'word[-2:]=os', u'|B-PER'): 0.247745
# (u'word[-3:]=ult', u'|O'): 0.24719
# (u'word.lower=rubin', u'|B-PER'): 0.247146
# ...
# (u'word[-3:]=ain', u'|B-PER'): -0.273091
# (u'word[-2:]=OW', u'|O'): -0.275695
# (u'word[-3:]=oft', u'|O'): -0.275762
# (u'word[-3:]=ese', u'|O'): -0.276446
# (u'+1:word.lower=francisco', u'|O'): -0.277269
# (u'-1:word.lower=kansas', u'|O'): -0.278649
# (u'word[-2:]=om', u'|B-LOC'): -0.279266
# (u'word[-3:]=tan', u'|B-MISC'): -0.280277
# (u'word[-3:]=ain', u'|B-ORG'): -0.280885
# (u'word.lower=western', u'|O'): -0.280929
# (u'word[-3:]=fat', u'|O'): -0.281221
# (u'-1:word.lower=said', u'|B-LOC'): -0.281656
# (u'word[-3:]=eld', u'|O'): -0.282065
# (u'+1:word.lower=and', u'|B-MISC'): -0.282099
# (u'-1:word.lower=bank', u'|O'): -0.282469
# (u'-1:word.lower=2', u'|B-PER'): -0.282543
# (u'+1:word.lower=angeles', u'|O'): -0.283743
# (u'+1:word.lower=de', u'|O'): -0.285089
# (u'word[-3:]=LES', u'|O'): -0.286023
# (u'+1:word.lower=on', u'|B-ORG'): -0.286462
# (u'word[-2:]=te', u'|B-MISC'): -0.286482
# (u'word[-3:]=pen', u'|I-PER'): -0.287127
# (u'word[-3:]=don', u'|B-PER'): -0.288206
# (u'+1:word.lower=was', u'|B-LOC'): -0.289569
# (u'+1:word.lower=minister', u'|I-ORG'): -0.289808
# (u'word[-2:]=ha', u'|O'): -0.291432
# (u'word[-2:]=sh', u'|I-ORG'): -0.291902
# (u'word[-2:]=AT', u'|B-ORG'): -0.292579
# (u'word[-2:]=ue', u'|I-PER'): -0.292895
# (u'+1:word.lower=the', u'|I-PER'): -0.293697
# (u'word[-3:]=ish', u'|B-ORG'): -0.294259
# (u'word[-3:]=cow', u'|O'): -0.294772
# (u'word[-2:]=ss', u'|B-LOC'): -0.2952
# (u'word[-3:]=ies', u'|I-PER'): -0.295427
# (u'word.lower=the', u'|B-ORG'): -0.295817
# (u'+1:word.lower=was', u'|B-MISC'): -0.296066
# (u'+1:word.lower=1996-08-28', u'|B-ORG'): -0.297379
# (u'+1:word.lower=first', u'|O'): -0.298602
# (u'word[-3:]=nce', u'|B-ORG'): -0.299196
# (u'+1:word.lower=)', u'|I-MISC'): -0.300356
# (u'word[-2:]=is', u'|B-ORG'): -0.302205
# (u'+1:word.lower=at', u'|O'): -0.303296
# (u'word[-2:]=nk', u'|O'): -0.304968
# (u'-1:word.lower=at', u'|I-ORG'): -0.306869
# (u'-1:word.lower=1', u'|B-LOC'): -0.307038
# (u'word[-3:]=ton', u'|B-MISC'): -0.307495
# (u'word[-2:]=ux', u'|O'): -0.308269
# (u'word[-2:]=id', u'|B-LOC'): -0.309619
# (u'+1:word.lower=:', u'|B-PER'): -0.309947
# (u'+1:word.lower=told', u'|O'): -0.311183
# (u'word[-3:]=dan', u'|O'): -0.312226
# (u'word[-2:]=of', u'|B-LOC'): -0.313378
# (u'-1:word.lower=by', u'|O'): -0.313607
# (u'+1:word.lower=2', u'|B-PER'): -0.31394
# (u'word[-2:]=sh', u'|B-LOC'): -0.31402
# (u'word[-2:]=EM', u'|O'): -0.315516
# (u'word.lower=van', u'|O'): -0.315624
# (u'word.isupper=False', u'|B-MISC'): -0.316237
# (u'word[-3:]=ank', u'|O'): -0.316269
# (u'word[-2:]=is', u'|B-LOC'): -0.31704
# (u'word[-2:]=ts', u'|B-PER'): -0.317765
# (u'word[-2:]=nd', u'|I-PER'): -0.317927
# (u'word[-3:]=van', u'|O'): -0.318218
# (u'word.istitle=False', u'|I-LOC'): -0.318443
# (u'word.isupper=False', u'|I-PER'): -0.319621
# (u'-1:word.lower=b', u'|O'): -0.319662
# (u'word.isdigit=False', u'|I-LOC'): -0.320355
# (u'word[-2:]=is', u'|I-ORG'): -0.321118
# (u'word[-3:]=ren', u'|O'): -0.321958
# (u'word[-2:]=at', u'|B-LOC'): -0.321982
# (u'-1:word.lower=central', u'|O'): -0.322314
# (u'-1:word.lower=/', u'|B-ORG'): -0.323553
# (u'word[-3:]=ens', u'|O'): -0.324725
# (u'word[-3:]=son', u'|I-ORG'): -0.325792
# (u'word[-2:]=at', u'|B-ORG'): -0.327597
# (u'word[-3:]=nda', u'|O'): -0.327844
# (u'word[-3:]=can', u'|I-PER'): -0.328011
# (u'word[-2:]=ce', u'|I-PER'): -0.328631
# (u'word[-2:]=re', u'|B-MISC'): -0.332058
# (u'word[-2:]=en', u'|B-LOC'): -0.33224
# (u'+1:word.isupper=True', u'|I-PER'): -0.332956
# (u'word[-3:]=pan', u'|O'): -0.335882
# (u'word[-2:]=ut', u'|B-PER'): -0.335947
# (u'+1:word.lower=-', u'|B-MISC'): -0.336215
# (u'word[-2:]=ea', u'|O'): -0.336906
# (u'word[-3:]=son', u'|B-LOC'): -0.337523
# (u'word[-2:]=io', u'|O'): -0.338918
# (u'word[-2:]=ty', u'|B-LOC'): -0.339052
# (u'+1:word.lower=0', u'|B-PER'): -0.339792
# (u'word[-3:]=ITY', u'|O'): -0.341574
# (u'word.isupper=False', u'|I-LOC'): -0.3416
# (u'word[-2:]=S.', u'|B-ORG'): -0.341964
# (u'+1:word.lower=to', u'|B-MISC'): -0.342998
# (u'word[-3:]=ank', u'|I-PER'): -0.343499
# (u'word[-3:]=ley', u'|O'): -0.344793
# (u'word.lower=hong', u'|B-PER'): -0.347771
# (u'word[-3:]=nch', u'|O'): -0.347779
# (u'word[-2:]=ng', u'|B-MISC'): -0.347901
# (u'word[-2:]=ex', u'|O'): -0.350898
# (u'word[-2:]=ry', u'|B-MISC'): -0.350958
# (u'+1:word.lower=1', u'|B-PER'): -0.351572
# (u'word.istitle=False', u'|I-ORG'): -0.35187
# (u'bias', u'|I-LOC'): -0.351933
# (u'word[-2:]=rd', u'|B-LOC'): -0.353361
# (u'word[-2:]=go', u'|O'): -0.353433
# (u'+1:word.lower=league', u'|B-ORG'): -0.353952
# (u'word[-2:]=us', u'|O'): -0.354272
# (u'word[-3:]=NTO', u'|O'): -0.355721
# (u'word[-2:]=st', u'|I-PER'): -0.356046
# (u'word[-2:]=me', u'|B-ORG'): -0.357601
# (u'word.lower=in', u'|B-ORG'): -0.358768
# (u'word[-2:]=ta', u'|B-PER'): -0.359734
# (u'word[-3:]=ity', u'|I-PER'): -0.360574
# (u'word.lower=south', u'|O'): -0.361955
# (u'word[-3:]=nia', u'|O'): -0.362107
# (u'word[-3:]=ana', u'|O'): -0.362195
# (u'-1:word.lower=hong', u'|O'): -0.363148
# (u'-1:word.lower=south', u'|O'): -0.363757
# (u'word[-3:]=and', u'|O'): -0.364632
# (u'word[-3:]=man', u'|B-LOC'): -0.365432
# (u'+1:word.lower=on', u'|B-PER'): -0.368135
# (u'word[-3:]=day', u'|B-ORG'): -0.368724
# (u'+1:word.lower=21', u'|O'): -0.36902
# (u'word[-2:]=er', u'|I-LOC'): -0.372864
# (u'word[-2:]=nt', u'|B-MISC'): -0.373685
# (u'word.lower=united', u'|O'): -0.373867
# (u'word[-2:]=as', u'|B-MISC'): -0.373958
# (u'word[-2:]=ma', u'|O'): -0.375109
# (u'word[-3:]=ang', u'|O'): -0.376286
# (u'word.lower=st', u'|O'): -0.377573
# (u'-1:word.istitle=False', u'|I-LOC'): -0.378466
# (u'word[-2:]=as', u'|I-ORG'): -0.380931
# (u'word[-3:]=nia', u'|B-PER'): -0.381587
# (u'word[-2:]=ni', u'|O'): -0.382906
# (u'word[-2:]=SH', u'|O'): -0.382924
# (u'word[-3:]=ine', u'|O'): -0.384359
# (u'word[-3:]=lem', u'|O'): -0.385979
# (u'+1:word.lower=on', u'|B-MISC'): -0.386612
# (u'word[-2:]=RN', u'|O'): -0.387329
# (u'-1:word.lower=new', u'|B-LOC'): -0.387851
# (u'+1:word.isupper=False', u'|I-PER'): -0.39005
# (u'word[-3:]=ers', u'|B-PER'): -0.391023
# (u'word[-3:]=tes', u'|I-PER'): -0.391286
# (u'word[-3:]=ers', u'|B-MISC'): -0.392218
# (u'word[-3:]=ERN', u'|O'): -0.393282
# (u'word[-2:]=er', u'|B-MISC'): -0.395533
# (u'-1:word.lower=to', u'|B-PER'): -0.396925
# (u'word[-3:]=ONG', u'|O'): -0.397852
# (u'word[-2:]=ay', u'|B-PER'): -0.398123
# (u'word[-3:]=ris', u'|O'): -0.398127
# (u'word[-3:]=ans', u'|O'): -0.398982
# (u'word[-2:]=in', u'|O'): -0.399334
# (u'word[-3:]=man', u'|B-ORG'): -0.399849
# (u'+1:word.lower=in', u'|B-MISC'): -0.400805
# (u'word[-2:]=ca', u'|I-PER'): -0.40169
# (u'+1:word.lower=of', u'|B-MISC'): -0.402465
# (u'-1:word.lower=with', u'|O'): -0.40344
# (u'word[-3:]=den', u'|O'): -0.404019
# (u'word[-2:]=pe', u'|O'): -0.406221
# (u'word[-2:]=TY', u'|O'): -0.407481
# (u'word[-3:]=ISH', u'|O'): -0.407649
# (u'word[-2:]=ce', u'|B-ORG'): -0.408318
# (u'word[-3:]=lic', u'|I-PER'): -0.408464
# (u'word[-2:]=AM', u'|O'): -0.40861
# (u'word.isdigit=False', u'|I-PER'): -0.408856
# (u"+1:word.lower='s", u'|O'): -0.410631
# (u'-1:word.lower=from', u'|O'): -0.411422
# (u'word[-2:]=an', u'|B-ORG'): -0.411758
# (u'-1:word.lower=against', u'|O'): -0.415099
# (u'+1:word.lower=to', u'|B-ORG'): -0.415201
# (u'-1:word.lower=de', u'|O'): -0.415896
# (u'word[-2:]=em', u'|O'): -0.415909
# (u'word[-2:]=me', u'|B-PER'): -0.416162
# (u'word[-2:]=ki', u'|O'): -0.41832
# (u'word.istitle=False', u'|B-MISC'): -0.418629
# (u'word[-2:]=ER', u'|B-ORG'): -0.421107
# (u'word[-2:]=an', u'|I-LOC'): -0.422306
# (u'+1:word.lower=in', u'|B-ORG'): -0.422914
# (u'+1:word.lower=of', u'|B-PER'): -0.423067
# (u'word[-2:]=NA', u'|O'): -0.425405
# (u'-1:word.lower=0', u'|B-PER'): -0.427069
# (u'word[-3:]=son', u'|O'): -0.430246
# (u'word[-2:]=AL', u'|O'): -0.430883
# (u'-1:word.lower=st', u'|O'): -0.431252
# (u'word[-3:]=ong', u'|B-PER'): -0.43174
# (u'word[-2:]=or', u'|B-PER'): -0.434807
# (u'-1:word.isupper=False', u'|B-LOC'): -0.436709
# (u'+1:word.lower=and', u'|O'): -0.437065
# (u'-1:word.lower=--', u'|O'): -0.439042
# (u'word[-2:]=ay', u'|I-PER'): -0.442516
# (u'word[-2:]=na', u'|B-MISC'): -0.442988
# (u'+1:word.lower=4', u'|I-PER'): -0.44455
# (u'word.lower=city', u'|O'): -0.447312
# (u'word[-2:]=ka', u'|O'): -0.448334
# (u'-1:word.lower=1', u'|B-PER'): -0.448716
# (u'word[-2:]=ce', u'|B-PER'): -0.44916
# (u'+1:word.lower=v', u'|O'): -0.449202
# (u'word[-2:]=ly', u'|B-MISC'): -0.451533
# (u'word[-2:]=rs', u'|B-MISC'): -0.45271
# (u'word[-2:]=OS', u'|O'): -0.453911
# (u'-1:word.lower=told', u'|O'): -0.456568
# (u'word[-2:]=rk', u'|O'): -0.457957
# (u'word[-2:]=al', u'|I-PER'): -0.458184
# (u'word[-2:]=rs', u'|B-PER'): -0.458614
# (u'word[-2:]=ce', u'|B-MISC'): -0.45967
# (u'+1:word.lower=:', u'|I-ORG'): -0.461264
# (u'word[-3:]=ton', u'|I-ORG'): -0.462154
# (u'word[-3:]=ham', u'|O'): -0.463269
# (u'word[-3:]=ian', u'|O'): -0.466344
# (u'word[-3:]=day', u'|B-PER'): -0.468313
# (u'-1:word.lower=,', u'|O'): -0.469256
# (u'word[-2:]=EN', u'|O'): -0.470155
# (u'word.lower=open', u'|O'): -0.475231
# (u'word[-3:]=ent', u'|I-PER'): -0.475914
# (u'word.isdigit=True', u'|I-LOC'): -0.47796
# (u'word.istitle=False', u'|B-LOC'): -0.478735
# (u'+1:word.lower=3', u'|B-PER'): -0.485901
# (u'bias', u'|I-PER'): -0.4867
# (u'+1:word.lower=2', u'|I-PER'): -0.487086
# (u'word[-2:]=ed', u'|B-ORG'): -0.487203
# (u'word[-2:]=om', u'|I-PER'): -0.487922
# (u'word.lower=french', u'|O'): -0.489385
# (u'+1:word.lower=city', u'|O'): -0.498842
# (u'word[-2:]=ic', u'|O'): -0.503724
# (u'word[-3:]=uth', u'|O'): -0.505183
# (u'word[-2:]=os', u'|O'): -0.505236
# (u'+1:word.lower=1', u'|B-MISC'): -0.507048
# (u'+1:word.isupper=True', u'|I-LOC'): -0.51054
# (u'+1:word.lower=)', u'|O'): -0.511341
# (u'word[-2:]=on', u'|O'): -0.515238
# (u'EOS', u'|I-ORG'): -0.516369
# (u'word[-2:]=ut', u'|B-ORG'): -0.517403
# (u'word[-2:]=up', u'|I-PER'): -0.519991
# (u'+1:word.lower=(', u'|O'): -0.520774
# (u'-1:word.lower=(', u'|O'): -0.522086
# (u'word[-2:]=ly', u'|B-ORG'): -0.524419
# (u'word[-2:]=ai', u'|O'): -0.52505
# (u'word[-2:]=RE', u'|O'): -0.525094
# (u'-1:word.lower="', u'|B-ORG'): -0.526498
# (u'word[-3:]=ter', u'|I-ORG'): -0.527964
# (u'word[-3:]=can', u'|B-PER'): -0.528291
# (u'+1:word.lower=cup', u'|O'): -0.530648
# (u'word[-2:]=es', u'|B-MISC'): -0.531624
# (u'word.lower=gmt', u'|O'): -0.531721
# (u'+1:word.lower=:', u'|B-ORG'): -0.539769
# (u'word[-2:]=ie', u'|O'): -0.540223
# (u'word[-2:]=nt', u'|I-PER'): -0.540664
# (u'word[-3:]=and', u'|I-PER'): -0.547019
# (u'word[-3:]=NEW', u'|O'): -0.551273
# (u'word.isupper=False', u'|I-ORG'): -0.55184
# (u'word[-3:]=ers', u'|B-LOC'): -0.553544
# (u'word[-3:]=ria', u'|O'): -0.554545
# (u'word[-2:]=EW', u'|O'): -0.556738
# (u'word[-2:]=ts', u'|B-LOC'): -0.560063
# (u'word[-2:]=TO', u'|O'): -0.562309
# (u'word[-3:]=AGO', u'|O'): -0.564928
# (u'word[-3:]=ish', u'|B-PER'): -0.565354
# (u'+1:word.lower=has', u'|O'): -0.565493
# (u'word[-2:]=AS', u'|O'): -0.566857
# (u'word[-3:]=lia', u'|O'): -0.570064
# (u'word[-3:]=ing', u'|B-PER'): -0.570853
# (u'word[-2:]=ew', u'|B-PER'): -0.571839
# (u'word[-2:]=MT', u'|O'): -0.573351
# (u'word[-3:]=tan', u'|O'): -0.574106
# (u'word[-2:]=co', u'|O'): -0.575599
# (u'word[-3:]=ica', u'|I-PER'): -0.576354
# (u'word[-3:]=est', u'|B-PER'): -0.57736
# (u'-1:word.lower=on', u'|B-PER'): -0.578778
# (u'word[-3:]=ish', u'|B-LOC'): -0.579312
# (u'word.lower=cup', u'|O'): -0.583963
# (u'+1:word.lower=.', u'|B-MISC'): -0.590382
# (u'word[-2:]=nd', u'|B-PER'): -0.599568
# (u'+1:word.lower=1', u'|I-PER'): -0.605519
# (u'+1:word.lower=0', u'|I-PER'): -0.60569
# (u'-1:word.lower=the', u'|O'): -0.609013
# (u'word[-2:]=in', u'|B-MISC'): -0.614114
# (u'-1:word.isupper=False', u'|O'): -0.62049
# (u'+1:word.lower=league', u'|O'): -0.630522
# (u'word[-3:]=ent', u'|B-PER'): -0.635812
# (u'word[-2:]=li', u'|O'): -0.639005
# (u'+1:word.lower=0', u'|B-LOC'): -0.640342
# (u'word[-2:]=la', u'|O'): -0.641611
# (u'-1:word.lower=)', u'|B-PER'): -0.641802
# (u'-1:word.lower=a', u'|B-PER'): -0.647015
# (u'word[-2:]=ay', u'|B-MISC'): -0.658588
# (u'word[-2:]=IS', u'|O'): -0.658894
# (u'word[-2:]=ay', u'|B-LOC'): -0.665799
# (u'word[-2:]=se', u'|B-LOC'): -0.670159
# (u'+1:word.lower=of', u'|B-LOC'): -0.6715
# (u'word[-3:]=ian', u'|B-LOC'): -0.672162
# (u'word[-2:]=sh', u'|B-PER'): -0.677843
# (u'+1:word.lower=-', u'|B-ORG'): -0.680717
# (u'word[-3:]=ish', u'|O'): -0.685798
# (u'word[-3:]=de', u'|O'): -0.690038
# (u'bias', u'|I-ORG'): -0.692314
# (u'+1:word.isupper=True', u'|I-ORG'): -0.698644
# (u'word[-3:]=don', u'|O'): -0.704104
# (u'word[-2:]=sh', u'|O'): -0.707394
# (u'word[-2:]=de', u'|O'): -0.70829
# (u'word[-2:]=ns', u'|B-LOC'): -0.708304
# (u'word.isupper=False', u'|B-LOC'): -0.708362
# (u'word[-2:]=ch', u'|B-PER'): -0.708606
# (u'word[-3:]=ire', u'|O'): -0.709358
# (u'+1:word.lower=2', u'|B-LOC'): -0.719135
# (u'word[-3:]=.S.', u'|B-PER'): -0.720129
# (u'+1:word.lower=3', u'|I-PER'): -0.724653
# (u'+1:word.lower=1', u'|B-LOC'): -0.727393
# (u'word[-3:]=AND', u'|O'): -0.743335
# (u'word[-2:]=ty', u'|I-PER'): -0.749633
# (u'word[-3:]=TON', u'|O'): -0.771449
# (u'+1:word.lower=,', u'|B-ORG'): -0.775071
# (u'word[-2:]=ca', u'|O'): -0.785127
# (u'word.lower=de', u'|O'): -0.785132
# (u'word[-3:]=ion', u'|B-LOC'): -0.7874
# (u'+1:word.lower=said', u'|B-MISC'): -0.794127
# (u'-1:word.lower=at', u'|B-PER'): -0.79873
# (u'word[-2:]=an', u'|I-ORG'): -0.802985
# (u'-1:word.isupper=True', u'|B-MISC'): -0.806706
# (u'+1:word.lower=4', u'|O'): -0.821553
# (u'word[-3:]=uth', u'|B-PER'): -0.821577
# (u'word[-2:]=rs', u'|B-LOC'): -0.824358
# (u'-1:word.istitle=True', u'|B-LOC'): -0.83169
# (u'word[-3:]=ion', u'|B-PER'): -0.840752
# (u'word[-2:]=ra', u'|O'): -0.860873
# (u'word[-2:]=ta', u'|O'): -0.868096
# (u'-1:word.isupper=True', u'|B-PER'): -0.877037
# (u'word.isdigit=True', u'|I-ORG'): -0.887176
# (u'word[-2:]=nt', u'|B-PER'): -0.899965
# (u'word.lower=the', u'|B-MISC'): -0.900703
# (u'word[-2:]=er', u'|I-ORG'): -0.927589
# (u'-1:word.lower=beat', u'|O'): -0.935587
# (u'-1:word.istitle=True', u'|B-MISC'): -0.936687
# (u'-1:word.lower=(', u'|B-MISC'): -0.937787
# (u'+1:word.lower=the', u'|B-LOC'): -0.943119
# (u'-1:word.istitle=True', u'|B-PER'): -0.949383
# (u'word[-2:]=GO', u'|O'): -0.970999
# (u'+1:word.lower=said', u'|B-LOC'): -0.971613
# (u'+1:word.lower=york', u'|O'): -0.975666
# (u'word[-2:]=IA', u'|O'): -0.976668
# (u'+1:word.lower=,', u'|O'): -0.979916
# (u'word[-2:]=da', u'|O'): -0.998512
# (u'-1:word.lower=)', u'|B-LOC'): -1.000674
# (u'+1:word.lower=,', u'|B-MISC'): -1.000997
# (u'+1:word.lower=said', u'|O'): -1.002557
# (u'word[-2:]=er', u'|B-LOC'): -1.023573
# (u'word[-2:]=th', u'|B-PER'): -1.026994
# (u'word[-2:]=el', u'|O'): -1.038239
# (u'word[-2:]=ia', u'|B-MISC'): -1.054649
# (u'word[-2:]=ia', u'|B-PER'): -1.07128
# (u'word[-3:]=and', u'|B-PER'): -1.075452
# (u'+1:word.lower=1', u'|O'): -1.08567
# (u'+1:word.lower=(', u'|B-ORG'): -1.096398
# (u'word[-2:]=al', u'|B-PER'): -1.096513
# (u'+1:word.lower=0', u'|O'): -1.115087
# (u'-1:word.istitle=False', u'|I-PER'): -1.127596
# (u'word[-3:]=ion', u'|I-PER'): -1.13202
# (u'word[-2:]=am', u'|O'): -1.137177
# (u'word[-2:]=es', u'|B-LOC'): -1.139823
# (u'-1:word.lower=in', u'|B-ORG'): -1.157056
# (u'-1:word.lower=,', u'|B-MISC'): -1.218302
# (u'word[-2:]=in', u'|B-ORG'): -1.253134
# (u'word.istitle=False', u'|B-PER'): -1.263998
# (u'-1:word.lower="', u'|B-LOC'): -1.272132
# (u'+1:word.lower=)', u'|I-PER'): -1.276129
# (u'word[-2:]=ON', u'|O'): -1.276702
# (u'-1:word.lower=new', u'|O'): -1.298775
# (u'+1:word.lower=2', u'|O'): -1.304941
# (u'+1:word.lower=(', u'|B-MISC'): -1.306219
# (u"+1:word.lower='s", u'|B-MISC'): -1.338485
# (u'word[-2:]=st', u'|B-PER'): -1.342369
# (u'-1:word.istitle=True', u'|B-ORG'): -1.347716
# (u'EOS', u'|B-MISC'): -1.358967
# (u'word[-2:]=an', u'|O'): -1.36301
# (u'+1:word.lower=1996-08-22', u'|O'): -1.363275
# (u'-1:word.lower=of', u'|B-PER'): -1.369085
# (u'word[-2:]=he', u'|B-PER'): -1.375686
# (u'word.istitle=False', u'|I-PER'): -1.464643
# (u'word[-2:]=ia', u'|O'): -1.471993
# (u'word.isupper=True', u'|O'): -1.625419
# (u'+1:word.lower=3', u'|O'): -1.631146
# (u'-1:word.lower=the', u'|I-PER'): -1.634822
# (u'word[-3:]=ton', u'|O'): -1.68507
# (u'-1:word.lower=of', u'|O'): -1.693466
# (u'-1:word.isupper=True', u'|B-LOC'): -1.787045
# (u'-1:word.lower=at', u'|O'): -1.788564
# (u'-1:word.isupper=True', u'|B-ORG'): -1.804862
# (u'word[-2:]=na', u'|O'): -1.811413
# (u'word[-2:]=AN', u'|O'): -1.829845
# (u'-1:word.lower=in', u'|B-PER'): -1.909869
# (u'word.istitle=True', u'|O'): -1.946293
# (u'+1:word.lower=)', u'|B-PER'): -1.985772
# (u'+1:word.lower=(', u'|B-LOC'): -2.3153
# (u'word.isupper=True', u'|I-PER'): -2.346248
# (u'-1:word.lower=the', u'|B-PER'): -2.976179

# %% [markdown]
# Save the trained model to disk.

# %%
import pickle

f = open("crf_ner_pol.mdl", "a")
pickle.dump(crf, f)
f.close()

# %% [markdown]
# Print the most likely and least likely transitions.

# %%
from collections import Counter

def print_transitions(trans_features):
    for (label_from, label_to), weight in trans_features:
        print("%-6s -> %-7s %0.6f" % (label_from, label_to, weight))

print("Top likely transitions:")
print_transitions(Counter(crf.transition_features_).most_common(20))

print("\nTop unlikely transitions:")
print_transitions(Counter(crf.transition_features_).most_common()[-20:])
# Out:
# Top likely transitions:
# |B-LOC -> |I-LOC  5.345479
# |B-PER -> |I-PER  5.174143
# |I-ORG -> |I-ORG  4.609703
# |I-MISC -> |I-MISC 4.569016
# |B-ORG -> |I-ORG  4.533346
# |B-MISC -> |I-MISC 3.129953
# |I-PER -> |I-PER  1.794438
# |O     -> |B-ORG  1.580775
# |O     -> |B-LOC  1.509977
# |O     -> |B-MISC 1.488459
# |I-LOC -> |I-LOC  1.441020
# |O     -> |B-PER  1.336434
# |O     -> |O      0.822066
# |B-LOC -> |O      0.562223
# |B-PER -> |O      0.368204
# |I-PER -> |O      0.046463
# |B-MISC -> |B-MISC 0.024453
# |B-MISC -> |O      0.021723
# |B-MISC -> |B-PER  -0.068634
# |B-LOC -> |B-MISC -0.095446
#
# Top unlikely transitions:
# |I-ORG -> |B-PER  -1.766387
# |B-PER -> |B-LOC  -1.771607
# |B-LOC -> |B-PER  -1.813408
# |B-PER -> |B-MISC -1.937413
# |B-MISC -> |I-PER  -2.015148
# |B-MISC -> |I-ORG  -2.102599
# |I-PER -> |I-ORG  -2.139164
# |I-ORG -> |I-PER  -2.330169
# |B-LOC -> |I-ORG  -2.514656
# |B-ORG -> |B-PER  -2.631615
# |B-ORG -> |B-LOC  -2.706786
# |B-LOC -> |I-PER  -2.823604
# |B-PER -> |B-ORG  -3.407979
# |B-ORG -> |I-PER  -3.809023
# |B-PER -> |I-ORG  -3.910227
# |B-PER -> |B-PER  -4.295979
# |O     -> |I-PER  -5.441871
# |O     -> |I-LOC  -5.690318
# |O     -> |I-MISC -6.705245
# |O     -> |I-ORG  -7.404266
